# %% [markdown]
# <a href="https://colab.research.google.com/github/roeil/FN-clasifier/blob/master/mlp3_roei_levy_FULL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


import numpy as np
import math
r=65
a,b=-12,10
n=100
a=12
p=.051
rng=np.linspace(-6,6,n)
rngy=np.linspace(a,-a,n)
rngx=np.linspace(-a,a,n)
psq=[]; psq2=[]
xy_1=[]

#####################################################
#SQUARE
a2=11.0
rr=1.0
for x in rngx:
    for y in rngy:


        # if np.random.choice([1,-1],p=[p,1-p])>0:
        #   if (x<-rr and x>-(a2) and y<(a2) and y>rr):# \
            
        #   #or ( x>rr and x<(a) and y<-rr and y>-(a)):
        #     #p.append((x+r1,y+r2))
        #     psq.append((x,y))
        #   if (x<(a2) and x>rr and y>rr and y<(a2) ) or ( x<-rr and x>-(a2) and y<-rr and y>-(a2)) or ( x>rr and x<(a2) and y<-rr and y>-(a2)):
        #     psq2.append((x,y))

            
        if np.random.choice([1,-1],p=[p,1-p])>0:
          if (x<-rr and x>-(a2) and y<(a2) and y>rr) \
          or ( x>rr and x<(a2) and y<-rr and y>-(a2)):
            #p.append((x+r1,y+r2))
            psq.append((x,y))
          if (x<(a2) and x>rr and y>rr and y<(a2) ) or ( x<-rr and x>-(a2) and y<-rr and y>-(a2)) :# or ( x>rr and x<(a) and y<-rr and y>-(a)):
            psq2.append((x,y))





from IPython.display import clear_output
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')


xs=[i[0] for i in psq]
ys=[i[1] for i in psq]


xs_2=[i[0] for i in psq2]
ys_2=[i[1] for i in psq2]


#######################################
##Spiral1
# theta1 = np.radians(np.linspace(0,360*5.1,1000))
# theta2 = np.radians(np.linspace(0,360*5,1000))
# r1 = 10*theta1**2
# r2 =10* theta2**2



# xs_2 = (r1*np.cos(theta1))[:700]+np.random.ranf(len((r1*np.cos(theta1))[:700]))*100

# ys_2 = (r1*np.sin(theta1))[:700]+np.random.ranf(len((r1*np.cos(theta1))[:700]))*100

# xs = (r2*np.cos(theta2))[700:]+np.random.ranf(len((r2*np.cos(theta2))[700:]))*100
# ys = (r2*np.sin(theta2))[700:]+np.random.ranf(len((r2*np.cos(theta2))[700:]))*100

# xs=[normalize(xs[i],xs)*20-10 for i in range(len(xs))]
# ys=[normalize(ys[i],ys)*20-10 for i in range(len(ys))]

# xs_2=[normalize(xs_2[i],xs_2)*10-6.5 for i in range(len(xs_2))]
# ys_2=[normalize(ys_2[i],ys_2)*10-3 for i in range(len(ys_2))]


#Waves 2
# nr=np.random.uniform(-10,10,500)
# xs=nr+3
# ys=np.sin(nr)

# nr2=np.random.uniform(-10,10,500)
# xs_2=nr
# ys_2=np.sin(nr)+2




# nr=np.random.uniform(-10,10,500)
# xs=nr-1+np.random.ranf(len(nr))
# ys=np.sin(nr)+np.random.ranf(len(nr))

# nr2=np.random.uniform(-10,10,500)
# xs_2=nr-np.random.ranf(len(nr))
# ys_2=np.sin(nr)+2+np.random.ranf(len(nr))


#####################################
####################################
#waves1
# nr=np.random.uniform(-10,10,500)
# xs=nr-1+np.random.ranf(len(nr))
# ys=np.sin(nr)+np.random.ranf(len(nr))

# nr2=np.random.uniform(-10,10,500)
# xs_2=nr-np.random.ranf(len(nr))
# ys_2=np.sin(nr)+4+np.random.ranf(len(nr))

# nr3=np.random.uniform(-10,10,500)
# xs_3=nr3-1+np.random.ranf(len(nr3))
# ys_3=np.sin(nr3)-4+np.random.ranf(len(nr3))


################################
##################


# # #Circle

# r=65
# a,b=-12,10
# n=500
# rng=np.linspace(-6,6,n)
# rngy=np.linspace(a,-a,n)
# rngx=np.linspace(-a,a,n)
# p=[]
# xy_1=[]
# for x in rngx:
#     for y in rngy:
#         #xy.append(((x,y)))
#         #z= rng[x]**2+rng[y]**2
#         # z=-1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w1+y*w2+b1))))*(w3)))) -\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w4+y*w5+b2))))*(w6))))-\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w7+y*w8+b3))))*(w9))))
#         z=x**2+y**2-r
#         xy_1.append(z)
#         r1=np.random.randint(-7,7)*0.17
#         r2=np.random.randint(-7,7)*0.17
#         if z<0.1 and z>-0.1:
#           p.append((x+r1,y+r2))


# r=4.25
# a,b=-6,6
# a=-12
# n=500
# rng=np.linspace(-6,6,n)
# rngy=np.linspace(a,-a,n)
# rngx=np.linspace(-a,a,n)
# p_2=[]
# xy_2=[]
# for x in rngx:
#     for y in rngy:
#         #xy.append(((x,y)))
#         #z= rng[x]**2+rng[y]**2
#         # z=-1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w1+y*w2+b1))))*(w3)))) -\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w4+y*w5+b2))))*(w6))))-\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w7+y*w8+b3))))*(w9))))
#         z=x**2+y**2-r
#         xy_2.append(z)
#         r1=np.random.randint(-5,5)*0.43
#         r2=np.random.randint(-5,5)*0.43
#         if z<0.1 and z>-0.1:
#           p_2.append((x+r1,y+r2))
#           #p_2.append((x,y))         
# xs=[i[0] for i in p]
# ys=[i[1] for i in p]


# xs_2=[i[0] for i in p_2]
# ys_2=[i[1] for i in p_2]

#####################



#####################################################
# #Circle2

# r=65
# a,b=-12,10

# r=14.25
# a,b=-6,6
# a=-12

# n=500
# rng=np.linspace(-6,6,n)
# rngy=np.linspace(a,-a,n)
# rngx=np.linspace(-a,a,n)
# p=[]
# xy_1=[]
# for x in rngx:
#     for y in rngy:
#         #xy.append(((x,y)))
#         #z= rng[x]**2+rng[y]**2
#         # z=-1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w1+y*w2+b1))))*(w3)))) -\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w4+y*w5+b2))))*(w6))))-\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w7+y*w8+b3))))*(w9))))
#         z=(x+10)**2+(y-0)**2-r
#         xy_1.append(z)
#         r1=np.random.randint(-7,7)*0.17
#         r2=np.random.randint(-7,7)*0.17
#         if z<0.1 and z>-0.1:
#           p.append((x+r1,y+r2))







# r=14.25
# a,b=-6,6
# a=-12
# n=500
# rng=np.linspace(-6,6,n)
# rngy=np.linspace(a,-a,n)
# rngx=np.linspace(-a,a,n)
# p_2=[]
# xy_2=[]
# for x in rngx:
#     for y in rngy:
#         #xy.append(((x,y)))
#         #z= rng[x]**2+rng[y]**2
#         # z=-1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w1+y*w2+b1))))*(w3)))) -\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w4+y*w5+b2))))*(w6))))-\
#         # 1/(1+ math.exp((-1)*((1/(1+math.exp((-1)*(x*w7+y*w8+b3))))*(w9))))
#         z=x**2+y**2-r
#         xy_2.append(z)
#         r1=np.random.randint(-5,5)*0.17#43
#         r2=np.random.randint(-5,5)*0.17#43
#         if z<0.1 and z>-0.1:
#           p_2.append((x+r1,y+r2))
#           #p_2.append((x,y))         
# xs=[i[0] for i in p]
# ys=[i[1] for i in p]


# xs_2=[i[0] for i in p_2]
# ys_2=[i[1] for i in p_2]
#####################################################


########################################
# #Circle3
# nr=np.random.normal(0,10,500)#. uniform(-10,10,500)
# xs=np.sin(nr)*10+np.random.ranf(len(nr))
# ys=np.cos(nr)*10+np.random.ranf(len(nr))

# nr2=np.random.uniform(-10,10,500)
# xs_2=np.sin(nr)*5-np.random.ranf(len(nr))
# ys_2=np.cos(nr)*5+4+np.random.ranf(len(nr))

# nr3=np.random.uniform(-10,10,500)
# xs_3=np.sin(nr3)*17+np.random.ranf(len(nr3))
# ys_3=np.cos(nr3)*17+np.random.ranf(len(nr3))

# nr4=np.random.uniform(-10,10,500)
# xs_4=np.sin(nr4)*11.7+np.random.ranf(len(nr4))*1.1
# ys_4=np.cos(nr4)*11.7+np.random.ranf(len(nr4))*1.1


# ss=[(xs[i],ys[i],1) for i in range(len(xs))]
# ss_2=[(xs_2[i],ys_2[i],0) for i in range(len(xs_2))]
# ss_3=[(xs_3[i],ys_3[i],1) for i in range(len(xs_3))]
# ss_4=[(xs_4[i],ys_4[i],0) for i in range(len(xs_4))]

##################################################


#circle 4
nr=np.random.normal(0,10,500)#. uniform(-10,10,500)
xs=np.sin(nr)*10+np.random.ranf(len(nr))
ys=np.cos(nr)*10+np.random.ranf(len(nr))

nr2=np.random.uniform(-10,10,500)
xs_2=np.sin(nr)*5+np.random.ranf(len(nr))
ys_2=np.cos(nr)*5+4+np.random.ranf(len(nr))

nr3=np.random.uniform(-10,10,500)
xs_3=np.sin(nr3)*13+np.random.ranf(len(nr3))
ys_3=np.cos(nr3)*13+np.random.ranf(len(nr3))

nr4=np.random.uniform(-10,10,500)
xs_4=np.sin(nr4)*17.0+np.random.ranf(len(nr4))
ys_4=np.cos(nr4)*17.0+np.random.ranf(len(nr4))


ss=[(xs[i],ys[i],1) for i in range(len(xs))]
ss_2=[(xs_2[i],ys_2[i],0) for i in range(len(xs_2))]
ss_3=[(xs_3[i],ys_3[i],1) for i in range(len(xs_3))]
ss_4=[(xs_4[i],ys_4[i],0) for i in range(len(xs_4))]
######################################################





# plt.scatter(x,y)
# plt.show()
axes = plt.gca()
axes.set_xlim([a,-a])
axes.set_ylim([a,-a])
#plt.contourCircle()  (x,y,'o', color='black')
# p
# xs
#ys
#plt.plot(-1.5,1.6,'ro') 
# plt.scatter(xs,ys,color='k') 
# #plt.scatter(xs_2,ys_2, color='g') 
# plt.scatter(xs_2,ys_2, color='g')


#p

#plt.imshow(xy4.T)
#plt.show()
#clear_output()
#xs_2


a=-12
N=50
rngy=np.linspace(a,-a,N)
rngx=np.linspace(-a,a,N)



# ss=[(xs[i],ys[i],1) for i in range(len(xs))]
# ss_2=[(xs_2[i],ys_2[i],0) for i in range(len(xs_2))]




# s=[[int(s[0]),int(s[1])] for s in ss]
# s2=[[int(s[0]),int(s[1])] for s in ss_2]
# l=[]
# for x in rngx:
#   for y in rngy:
#     if [int(x),int(y)] not in s+s2:
#       l.append((x,y,0))


# import pandas as pd 

# df_z=pd.DataFrame(l)
# df_z=df_z.sample(frac=1).reset_index(drop=True)



# plt.scatter(df_z[1],df_z[0], color='b',alpha=0.1)


import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


b1=3.7;b2=-3.5;b3=-3.9
w1=0.28;w2=1.9;w3=5.5
w4=-1.2;w5=1.2;w6=-5.7
w7=1.7;w8=0.55;w9=-5.6

def plot2(W,B,W1,W2,Bx,train, r=0.98, concave=False):


  #W1=W1.reshape(-1,1)
  import math
  xx=[];yy=[];zz=[]
  n_=100
  a=30#12
  rng=np.linspace(-6,6,n_)
  rngx=np.linspace(-a,a,n_)
  rngy=np.linspace(a,-a,n_)
  p3=[]; p4=[]; p5=[]
  xy_x=[]
  xy_x2=[]
  for x in rngx:
      for y in rngy:

          o=[]
          X=[[x,y]]
          z=forward2(W,B,X)[0][-1]
          # for i in range(0,n*2,2):
          #   #print(i,i+1,int(i/2))
          
          #   o.append(sigmoid(W1[i]*x+W1[i+1]*y+Bx[int(i/2)])*W2[int(i/2)])

         # z=sum(o)
          
          xy_x.append(z)





  xy4=np.array(xy_x).reshape(n_,n_)



#TAKE QUANTILES (r)
  if concave:
    r=1-r
  pp=[]
  A=np.sort(xy4.reshape(1,-1))[0]
  for i in range(n_):
    for j in range(n_):

      if concave:
        if xy4[i,j]<=max(set(list(A[:int(len(A)*r)]))):
          pp.append((rngx[i],rngy[j]))
      else:
        
        if xy4[i,j]>=min(set(list(A[int(len(A)*r):]))):
          pp.append((rngx[i],rngy[j]))


        


  pp_x=[i[0] for i in pp]

  pp_y=[i[1] for i in pp]



  plt.rcParams["axes.grid"] = False



  

  fig, ax = plt.subplots()
  
  df_2=pd.DataFrame([pp_x,pp_y])

  sns.kdeplot(df_2.T, ax=ax)


  
  R=30

  # sns.scatterplot(x=xs, y=ys, ax=ax).set(xlim=(-R,R),ylim=(-R,R))
  # sns.scatterplot(x=xs_2, y=ys_2, ax=ax).set(xlim=(-R,R),ylim=(-R,R))
  # sns.scatterplot(x=xs_3, y=ys_3, ax=ax).set(xlim=(-R,R),ylim=(-R,R))

  sns.scatterplot(df.iloc[np.where(df[2]==0)][0],df.iloc[np.where(df[2]==0)][1], ax=ax).set(xlim=(-R,R),ylim=(-R,R))
  sns.scatterplot(df.iloc[np.where(df[2]==1)][0],df.iloc[np.where(df[2]==1)][1], ax=ax).set(xlim=(-R,R),ylim=(-R,R))


  
  
  

  plt.show()

  #xy4=np.array(xy_x).reshape(100,100)

  plt.imshow(xy4.T)
  
  plt.show()



  ################### WIREFRAME
  x=np.array([[x]*100 for x in rngx])

  # arr=[]
  # for i in range(100):
  #   arr.append(rngy)
  y=np.array(rngy)

  z=xy4

  fig = plt.figure()
  ax = fig.add_subplot(111, projection = '3d')

  #x, y, z = axes3d.get_test_data()

  ax.plot_wireframe(x, y, z, rstride = 2, cstride = 2)
  


  plt.tight_layout()
  plt.show()
  #################


  print("max: ",max(xy_x),"min: ", min(xy_x))
  print("abs(max-min): ", np.abs(max(xy_x)-min(xy_x)))
  return max(xy_x)


#with batch option 
import copy

#n=4
N=[2,4,7,4]
#N=[2,4,40,20,40,4]


N=[2, 5,3,5,4, 7]
N=[2,5,7,5,14,15,5,5,12,6]
#N=[2, 8,6,5,4,13,5]

N=[2,8,7,10,12,5]
N=[2,80,52,40,17]

N=[2,8,18,28,180,8,8]
N=[2,8,8,8,18,8,8,7,10]
#N=[2, 784,5,5, 5, 5, 5, 5, 5, 5, 7]
#N=[2, 5,5,7]

W,B=generateWandB(N)

rho=0.999;rhof=0.9;e=1e-8; Ai=0;Fi=0

BATCH=10
eta= 0.010751053531253013#03073010730108035103103083040170713004103071020917108530725972087075341070509703508578570710510510107107#0.006512
import math
#import copy

#W1=W;W2=W; Bx=W
n=N[1]
W1=W[0]#np.array(np.random.normal(0, 1, n*2)).reshape(n,2)

W2=W[1]#np.random.normal(0, 1, n)

Bx=B[0]#np.random.normal(0, 1, n)


epochs=100000#13400
a2=[]

def relu(z):

  #return np.array([max(0,e) for e in z ])
  #leaky
  return np.array([e if e>0 else 0.01*e for e in z ])


def sigmoid(z):
  #print(z)
  # if z<-200:
  #     return 0
  try:
    sig= 1/(1+np.exp(-z))
  except:
    sig= 1/(1+np.exp(-z*0))

  return sig


def softmax(z):
  res=np.exp(z)/np.sum(np.exp(z))
  return res







#################    MAIN     ########################

ss=[(xs[i],ys[i],0) for i in range(len(xs))]
ss_2=[(xs_2[i],ys_2[i],1) for i in range(len(xs_2))]
#df=pd.concat([pd.DataFrame(ss), pd.DataFrame(ss_2)])

ss_3=[(xs_3[i],ys_3[i],1) for i in range(len(xs_3))]
#df=pd.concat([pd.DataFrame(ss), pd.DataFrame(ss_2),pd.DataFrame(ss_3)])

ss_4=[(xs_4[i],ys_4[i],0) for i in range(len(xs_4))]

df=pd.concat([pd.DataFrame(ss), pd.DataFrame(ss_2),pd.DataFrame(ss_3),pd.DataFrame(ss_4)])

# df[0]=[(i - min(df[0]) )/(max(df[0]) - min(df[0])) for i in df[0]]
# df[1]=[(i - min(df[1]) )/(max(df[1]) - min(df[1])) for i in df[1]]

test_acc=0; train_acc=0




for i in range(epochs):


  
  df=df.sample(frac=1).reset_index(drop=True)
  
  testfrac=0.803609170611490758505840
  thresh=int(len(df)*testfrac)
  test=df[:thresh]
  train=df[thresh:]
  
  
  if i%5==0:# and i>BATCH:
    test_acc=testAcuracy(test,W,B)
    train_acc=testAcuracy(train,W,B)


  #print('\r',i, end='')


  if i%25==0:
    clear_output(wait=True)
    plot2(W,B,W1,W2,B,train,.8078040608068248585025, True)

  err=[]
 
  Loss=[] 
  #for j in range(1):# list(range(0,len(train),BATCH)):
  for j in   list(range(0,len(train),BATCH)):
    w2up=[]; w1up=[]; bup=[]
    loss=[]; 
    Wup=[]; Bup=[]; 


    batch=train[j:j+BATCH]
    count=0
    #for row in [[1,1,1], [1,2,0]]:#[rrr]:#batch.iterrows():
    for row in batch.iterrows():
       #print("count: ",count)
       count+=1
       Wupx=[]; Bupx=[]
       x1=row[1][0]; x2=row[1][1]; y=row[1][2]
       #x1=row[0]; x2=row[1]; y=row[2]
       x1=np.array(x1)
       x2=np.array(x2)
       X=[[x1,x2]]
       y=np.array(y)
################################   FORWARD PASS    ########################
       A,I=forward2(W,B,X)  
################################   BACKWARD PASS   ########################

       lw=list(range(len(W)))[::-1]
       #lb=list(range(len(W)-1))[::-1]
       lb=lw[:len(lw)-1]
       for l in lw:
         Wupx.append(backward2(W,A,I,X, y, k=l)[0])
       for l in lb:
         Bupx.append(backward2(W,A,I,X, y, k=l)[1])
       
       Wup.append(Wupx); Bup.append(Bupx)

       An=sigmoid(I[-1])
       #dE_dI=np.abs(-1*((y*(1/I[-1])+(1-y)*(1/(1-I[-1])))) )
       dE_dAn=np.abs(-1*((y*(np.log(1/An))+(1-y)*((1-np.log(1/(1-An)))))) )

      #  dE_dAn=np.abs(((y*((An))+(1-y)*((1-((1-An)))))) )


       #L=-y*(np.log(1/An))-(1-y)*(np.log(1-(1-An)))
       #dE_dAn=-y*((An))-(1-y)*((1-(1-An)))
       #dE_dAn=y * -np.log(An) + (1 - y) * -np.log(1 - An)
       #L=np.max(An, 0) - An * y + np.log(1 + np.exp(-abs(An)))
       #L=-1*(y*(np.log(1/An))+(y-1)*np.log(1/(1-An)))

       L=y*(An+An*np.log(1/An)) + (1-y)*( An+(An-1)*np.log(1/(1-An)))
       L= An*y*(np.log(1/An)+1) - (y-1)*(An-1)*np.log(1/(1-An))
       #print("Loss",Loss)
       Loss.append(dE_dAn)


    if count>1:
      #print("count")
      #print("Wup:",Wup)
      Wup=sumMat(Wup); Bup=sumMat(Bup)
    else:
      Wup=Wup[0]
      Bup=Bup[0]

    Wup=[np.array(m) for m in Wup]
    for l in range(len(Wup)):
      Wup[l][[np.isnan(np.array(m)) for m in Wup][l]]=np.random.normal(0, 1, 1)*0

    Bup=[np.array(m) for m in Bup]
    for l in range(len(Bup)):
      Bup[l][[np.isnan(np.array(m)) for m in Bup][l]]=np.random.normal(0, 1, 1)*0



    #ADAM----###########
    #W,B=update3(Wup,Bup, W, B,eta, rho,rhof,e, Ai,Fi)

    #-------###########
    W,B=update2(Wup,Bup, W, B,eta)

    
  print("\rLoss = {}; epoch = {}; train acc. = {}; test acc. = {}.".format(round(np.nanmean(Loss),3),i,round(test_acc,3),round(train_acc,3)),end='')#Loss[~np.isnan(Loss)].mean(),end='\n')
  #print("\rLoss = {}; epoch = {}; train acc. = {}; test acc. = {}.".format(round(np.mean(np.array(Loss)>0.01),3),i,round(test_acc,3),round(train_acc,3)),end='')#Loss[~np.isnan(Loss)].mean(),end='\n')
  #print("LOSS2 = ", np.mean(Loss),end='\n')
# Out:
# max:  0.9743755784438706 min:  0.20670101726372203
# abs(max-min):  0.7676745611801485
# Loss = 0.233; epoch = 204; train acc. = 0.666; test acc. = 0.712.

# %%
def update3(Wup,Bup, W, B,eta, rho,rhof,e, Ai,Fi):
  AiW=Ai[0]; AiF=Ai[1]; FiW=Fi[0]; FiB=Fi[1]


  WC=copy.deepcopy(W); BC=copy.deepcopy(B)
  try:
    
    
    #ADAM######################
    #AiW=rho*AiW+(1-rho)*np.array([np.power(Wup[i],2) for i in range(len(W))])
    #FiW=rhof*FiW+(1-rhof)*np.array([Wup[i] for i in range(len(W))])
    AiW=rho*AiW+(1-rho)*np.power(Wup,2)
    FIW=rhof*FiW+(1-rhof)*np.array(Wup)

    AiB=rho*AiB+(1-rho)*np.power(Bup,2)
    FiB=rhof*FiB+(1-rhof)*np.array(Bup)
    
    
    
    # W=[W[i]-eta/np.sqrt(AiW+e)*FiW[i] for i in range(len(FiW))]
    # B=[B[i]-eta/np.sqrt(AiB+e)*FiB[i] for i in range(len(FiB))]
    
    W-=eta/((AiW+e)**0.5)*FiW
    B-=eta/((AiB+e)**0.5)*FiB
    #############################

    # W=[W[i]-eta*Wup[i] for i in range(len(W))]
    # B=[B[i]-eta*Bup[i] for i in range(len(B))]
    #W=W-Wup #eta*np.array([dE_dO2*dO2_dO1,dE_dO2*dO2_dO1]).T*dO1_dW1
    
    #B=B-Bup #eta*dE_dO2*dO2_dO1*dO1_dB
  except:
    W=WC; B=BC


  # W=[np.array(W[i]) for i in range(len(W))]
  # B=[np.array(B[i]) for i in range(len(B))]
  return (W,B)
# Out:
#   File "<ipython-input-61-1bf07e200c9e>", line 3
#     Ai=rho*Ai+(1-rho)*
#                       ^
# SyntaxError: invalid syntax

# %%
rho=0.1;rhof=0.1
e=1
Ai=[0,0]
Fi=[0,0]

AiW=Ai[0]; AiF=Ai[1]; FiW=Fi[0]; FiB=Fi[1]

aiw=rho*AiW+(1-rho)*np.array([np.power(sumMat(Wup)[i],2) for i in range(len(W))])
fiw=rhof*FiW+(1-rhof)*np.array([sumMat(Wup)[i] for i in range(len(W))])

# %%
rho*AiW+(1-rho)*np.power(Wup,2)
rhof*FiW+(1-rhof)*np.array(Wup)
# Out:
# array([[array([[ 4.75044580e-03, -1.20312777e-02],
#        [ 2.54065340e-03, -6.43461855e-03],
#        [-8.02874909e-03,  2.03341147e-02],
#        [-4.42097412e-05,  1.11968370e-04],
#        [-2.15084445e-05,  5.44736387e-05],
#        [-3.25528223e-03,  8.24453246e-03],
#        [ 3.00943178e-05, -7.62187615e-05],
#        [-4.16236886e-05,  1.05418771e-04]]),
#         array([[ 1.72324958e-03,  7.64035330e-04,  1.50222068e-03,
#         -2.12096789e-06, -3.82100598e-06,  1.11429330e-03,
#         -1.65737908e-06, -6.64010937e-06],
#        [-1.49110419e-02, -6.61109277e-03, -1.29985092e-02,
#          1.83524438e-05,  3.30626399e-05, -9.64182688e-03,
#          1.43410735e-05,  5.74559543e-05],
#        [-5.24143637e-03, -2.32389006e-03, -4.56915479e-03,
#          6.45113647e-06,  1.16219728e-05, -3.38923479e-03,
#          5.04108464e-06,  2.01965584e-05],
#        [-1.30624187e-02, -5.79147066e-03, -1.13869956e-02,
#          1.60771666e-05,  2.89636397e-05, -8.44646406e-03,
#          1.25631132e-05,  5.03327491e-05],
#        [ 9.05321406e-03,  4.01391387e-03,  7.89202301e-03,
#         -1.11426554e-05, -2.00739263e-05,  5.85401900e-03,
#         -8.70715872e-06, -3.48842862e-05],
#        [ 1.61016827e-03,  7.13898590e-04,  1.40364350e-03,
#         -1.98178792e-06, -3.57026786e-06,  1.04117229e-03,
#         -1.54862026e-06, -6.20437895e-06],
#        [-1.91100766e-03, -8.47281431e-04, -1.66589637e-03,
#          2.35205970e-06,  4.23732685e-06, -1.23570205e-03,
#          1.83796019e-06,  7.36358798e-06],
#        [ 9.55793270e-03,  4.23769043e-03,  8.33200499e-03,
#         -1.17638609e-05, -2.11930520e-05,  6.18038182e-03,
#         -9.19258470e-06, -3.68290927e-05]]),
#         array([[ 2.73082525e-04,  4.77806918e-04,  1.73266676e-04,
#          1.20691994e-03,  7.86680885e-04,  1.44641066e-03,
#          9.38595447e-04,  4.29207818e-04],
#        [-9.26496379e-04, -1.62107180e-03, -5.87847750e-04,
#         -4.09475836e-03, -2.66899902e-03, -4.90728669e-03,
#         -3.18440472e-03, -1.45618797e-03],
#        [ 7.68757195e-06,  1.34507877e-05,  4.87764656e-06,
#          3.39761172e-05,  2.21459278e-05,  4.07180431e-05,
#          2.64224890e-05,  1.20826698e-05],
#        [ 1.47401768e-06,  2.57905863e-06,  9.35241621e-07,
#          6.51459233e-06,  4.24626779e-06,  7.80729153e-06,
#          5.06625709e-06,  2.31673525e-06],
#        [-1.42634776e-05, -2.49565156e-05, -9.04995792e-06,
#         -6.30390962e-05, -4.10894297e-05, -7.55480276e-05,
#         -4.90241372e-05, -2.24181174e-05],
#        [ 6.61129516e-06,  1.15676481e-05,  4.19476544e-06,
#          2.92193869e-05,  1.90454498e-05,  3.50174286e-05,
#          2.27232831e-05,  1.03910698e-05],
#        [ 3.10138901e-03,  5.42643701e-03,  1.96778378e-03,
#          1.37069489e-02,  8.93430821e-03,  1.64268370e-02,
#          1.06595968e-02,  4.87449868e-03],
#        [-3.35323692e-06, -5.86709016e-06, -2.12757742e-06,
#         -1.48200200e-05, -9.65981760e-06, -1.77607763e-05,
#         -1.15252080e-05, -5.27033174e-06]]),
#         array([[-3.85772675e-03, -2.42104662e-03,  8.73525879e-07,
#          1.96276445e-05,  1.04527522e-05,  5.93770251e-06,
#         -3.25091678e-04,  6.90997756e-06],
#        [ 6.95792415e-05,  4.36668013e-05, -1.57552030e-08,
#         -3.54010718e-07, -1.88529312e-07, -1.07094375e-07,
#          5.86346153e-06, -1.24630651e-07],
#        [ 1.44013357e-05,  9.03804428e-06, -3.26097214e-09,
#         -7.32722447e-08, -3.90213210e-08, -2.21661234e-08,
#          1.21360446e-06, -2.57957375e-08],
#        [ 7.28109763e-03,  4.56949855e-03, -1.64869821e-06,
#         -3.70453392e-05, -1.97285900e-05, -1.12068569e-05,
#          6.13580069e-04, -1.30419349e-05],
#        [ 1.22640183e-05,  7.69669857e-06, -2.77700781e-09,
#         -6.23978334e-08, -3.32301255e-08, -1.88764256e-08,
#          1.03349214e-06, -2.19673648e-08],
#        [-2.75127204e-05, -1.72665362e-05,  6.22985369e-09,
#          1.39981375e-07,  7.45474387e-08,  4.23467911e-08,
#         -2.31850440e-06,  4.92809088e-08],
#        [-3.81016812e-03, -2.39119959e-03,  8.62756921e-07,
#          1.93856720e-05,  1.03238891e-05,  5.86450162e-06,
#         -3.21083899e-04,  6.82479031e-06],
#        [-1.85674121e-03, -1.16526061e-03,  4.20431927e-07,
#          9.44687343e-06,  5.03095656e-06,  2.85784287e-06,
#         -1.56468084e-04,  3.32580322e-06],
#        [ 4.73801158e-07,  2.97349907e-07, -1.07285352e-10,
#         -2.41064267e-09, -1.28379391e-09, -7.29261170e-10,
#          3.99273519e-08, -8.48674770e-10],
#        [-3.62472817e-05, -2.27482050e-05,  8.20766753e-09,
#          1.84421761e-07,  9.82142795e-08,  5.57907776e-08,
#         -3.05456825e-06,  6.49262944e-08],
#        [-8.51014943e-04, -5.34083149e-04,  1.92699904e-07,
#          4.32986053e-06,  2.30587828e-06,  1.30985782e-06,
#         -7.17152597e-05,  1.52434180e-06],
#        [ 9.03766651e-04,  5.67189263e-04, -2.04644758e-07,
#         -4.59825480e-06, -2.44881233e-06, -1.39105174e-06,
#          7.61606604e-05, -1.61883090e-06],
#        [ 8.11672433e-05,  5.09392429e-05, -1.83791367e-08,
#         -4.12969062e-07, -2.19927728e-07, -1.24930296e-07,
#          6.83998557e-06, -1.45387132e-07],
#        [-2.16712854e-03, -1.36005466e-03,  4.90714606e-07,
#          1.10260864e-05,  5.87197048e-06,  3.33558217e-06,
#         -1.82624509e-04,  3.88177041e-06],
#        [-1.28182658e-02, -8.04453532e-03,  2.90250907e-06,
#          6.52177774e-05,  3.47318939e-05,  1.97295075e-05,
#         -1.08019873e-03,  2.29601355e-05],
#        [ 1.01532862e-04,  6.37203745e-05, -2.29906337e-08,
#         -5.16586855e-07, -2.75109649e-07, -1.56276473e-07,
#          8.55620181e-06, -1.81866121e-07],
#        [-2.13048532e-05, -1.33705796e-05,  4.82417284e-09,
#          1.08396502e-07,  5.77268338e-08,  3.27918197e-08,
#         -1.79536575e-06,  3.81613491e-08],
#        [ 5.12048940e-05,  3.21353594e-05, -1.15946004e-08,
#         -2.60524273e-07, -1.38742867e-07, -7.88131060e-08,
#          4.31505029e-06, -9.17184370e-08]]),
#         array([[-1.30112004e-03,  5.79851048e-05,  6.73810205e-05,
#         -3.25752805e-03,  4.45462632e-05,  1.68559789e-05,
#         -1.05285964e-03, -1.76596708e-03,  3.10556841e-05,
#          6.92840596e-07, -2.61404938e-03, -8.11393941e-04,
#          5.56947977e-05, -1.85810936e-03, -2.00596616e-03,
#          1.26177748e-05,  9.92909253e-06,  6.82210086e-05],
#        [-5.12886519e-05,  2.28570598e-06,  2.65608214e-06,
#         -1.28408000e-04,  1.75596233e-06,  6.64443254e-07,
#         -4.15025129e-05, -6.96123860e-05,  1.22417926e-06,
#          2.73109774e-08, -1.03042813e-04, -3.19842136e-05,
#          2.19542471e-06, -7.32445284e-05, -7.90728731e-05,
#          4.97378135e-07,  3.91393379e-07,  2.68919350e-06],
#        [ 1.07256363e-05, -4.77993672e-07, -5.55447843e-07,
#          2.68530651e-05, -3.67212097e-07, -1.38950361e-07,
#          8.67912966e-06,  1.45575504e-05, -2.56004029e-07,
#         -5.71135330e-09,  2.15486212e-05,  6.68863444e-06,
#         -4.59113783e-07,  1.53171149e-05,  1.65359558e-05,
#         -1.04013204e-07, -8.18493543e-08, -5.62372190e-07],
#        [-1.51799165e-03,  6.76501032e-05,  7.86121367e-05,
#         -3.80049514e-03,  5.19712659e-05,  1.96655454e-05,
#         -1.22835103e-03, -2.06031972e-03,  3.62320675e-05,
#          8.08323757e-07, -3.04976098e-03, -9.46637658e-04,
#          6.49780460e-05, -2.16782034e-03, -2.34032202e-03,
#          1.47209145e-05,  1.15840807e-05,  7.95921346e-05],
#        [-1.42700952e-03,  6.35954359e-05,  7.39004505e-05,
#         -3.57270918e-03,  4.88563233e-05,  1.84868740e-05,
#         -1.15472875e-03, -1.93683268e-03,  3.40604673e-05,
#          7.59876175e-07, -2.86697093e-03, -8.89900114e-04,
#          6.10835308e-05, -2.03789016e-03, -2.20005280e-03,
#          1.38386038e-05,  1.08897788e-05,  7.48217114e-05],
#        [ 1.16216861e-05, -5.17926606e-07, -6.01851516e-07,
#          2.90964456e-05, -3.97890027e-07, -1.50558665e-07,
#          9.40420853e-06,  1.57737291e-05, -2.77391325e-07,
#         -6.18849581e-09,  2.33488536e-05,  7.24742175e-06,
#         -4.97469438e-07,  1.65967497e-05,  1.79174160e-05,
#         -1.12702759e-07, -8.86872794e-08, -6.09354342e-07],
#        [ 2.76821881e-06, -1.23367140e-07, -1.43357571e-07,
#          6.93060604e-06, -9.47751166e-08, -3.58622083e-08,
#          2.24002840e-06,  3.75721157e-06, -6.60730186e-08,
#         -1.47406412e-09,  5.56156268e-06,  1.72629419e-06,
#         -1.18494360e-07,  3.95325035e-06,  4.26782546e-06,
#         -2.68451491e-08, -2.11248000e-08, -1.45144701e-07],
#        [-3.81964172e-04,  1.70224359e-05,  1.97807541e-05,
#         -9.56298391e-04,  1.30772534e-05,  4.94833667e-06,
#         -3.09083440e-04, -5.18427300e-04,  9.11688257e-06,
#          2.03394211e-07, -7.67395147e-04, -2.38197402e-04,
#          1.63500803e-05, -5.45477110e-04, -5.88882790e-04,
#          3.70414546e-06,  2.91484065e-06,  2.00273458e-05]]),
#         array([[ 7.12937894e-06,  4.03250111e-06, -9.14653058e-08,
#          2.29113160e-05,  6.08982896e-06, -7.15113040e-08,
#         -2.94938690e-08,  9.52131781e-07],
#        [-1.11153336e-05, -6.28702664e-06,  1.42602518e-07,
#         -3.57207723e-05, -9.49458309e-06,  1.11492461e-07,
#          4.59835558e-08, -1.48445783e-06],
#        [-1.73267835e-05, -9.80033107e-06,  2.22291390e-07,
#         -5.56821873e-05, -1.48003282e-05,  1.73796469e-07,
#          7.16800003e-08, -2.31399978e-06],
#        [-1.88776301e-06, -1.06775169e-06,  2.42187744e-08,
#         -6.06660625e-06, -1.61250425e-06,  1.89352250e-08,
#          7.80957714e-09, -2.52111603e-07],
#        [ 5.31121747e-06,  3.00411727e-06, -6.81394739e-08,
#          1.70683846e-05,  4.53677750e-06, -5.32742179e-08,
#         -2.19722298e-08,  7.09315495e-07],
#        [-5.86367392e-06, -3.31659627e-06,  7.52271316e-08,
#         -1.88437853e-05, -5.00867910e-06,  5.88156376e-08,
#          2.42577133e-08, -7.83096303e-07],
#        [-4.60384073e-03, -2.60401264e-03,  5.90642892e-05,
#         -1.47951246e-02, -3.93254487e-03,  4.61788687e-05,
#          1.90458491e-05, -6.14845010e-04],
#        [-8.48541044e-04, -4.79949619e-04,  1.08862310e-05,
#         -2.72691243e-03, -7.24813462e-04,  8.51129911e-06,
#          3.51037007e-06, -1.13323040e-04]]),
#         array([[ 5.68756628e-05,  1.50180442e-05,  3.13897930e-05,
#          1.22760274e-05,  2.76694577e-05,  2.68308757e-05,
#         -3.42904015e-03, -1.15019047e-02],
#        [-2.71159237e-06, -7.15997177e-07, -1.49653330e-06,
#         -5.85269351e-07, -1.31916336e-06, -1.27918330e-06,
#          1.63482212e-04,  5.48362440e-04],
#        [ 1.06096152e-04,  2.80147364e-05,  5.85546804e-05,
#          2.28997643e-05,  5.16147479e-05,  5.00504528e-05,
#         -6.39654904e-03, -2.14557119e-02],
#        [-1.28191240e-05, -3.38489542e-06, -7.07490040e-06,
#         -2.76687619e-06, -6.23637936e-06, -6.04737257e-06,
#          7.72866439e-04,  2.59239780e-03],
#        [ 6.43218132e-07,  1.69842035e-07,  3.54993385e-07,
#          1.38832024e-07,  3.12919376e-07,  3.03435686e-07,
#         -3.87796941e-05, -1.30077318e-04],
#        [-2.06498008e-07, -5.45258913e-08, -1.13966667e-07,
#         -4.45704733e-08, -1.00459276e-07, -9.74146433e-08,
#          1.24497883e-05,  4.17598724e-05],
#        [ 1.24341447e-04,  3.28324147e-05,  6.86242956e-05,
#          2.68378237e-05,  6.04909069e-05,  5.86576008e-05,
#         -7.49655995e-03, -2.51454385e-02]]),
#         array([[-9.12866063e-05,  1.06684356e-06, -1.09058359e-04,
#         -5.67257890e-05,  1.02168500e-06,  1.36922973e-07,
#         -5.08897391e-05],
#        [-1.96117300e-04,  2.29197345e-06, -2.34297579e-04,
#         -1.21867917e-04,  2.19495622e-06,  2.94161049e-07,
#         -1.09329929e-04],
#        [-2.09691827e-02,  2.45061552e-04, -2.50514806e-02,
#         -1.30303172e-02,  2.34688312e-04,  3.14521808e-05,
#         -1.16897350e-02],
#        [ 1.57775008e-05, -1.84387675e-07,  1.88490778e-05,
#          9.80418946e-06, -1.76582707e-07, -2.36650525e-08,
#          8.79551704e-06],
#        [-4.04256207e-03,  4.72444039e-05, -4.82957141e-03,
#         -2.51206100e-03,  4.52445897e-05,  6.06353595e-06,
#         -2.25361570e-03],
#        [ 1.32188103e-05, -1.54484904e-07,  1.57922593e-05,
#          8.21421101e-06, -1.47945694e-07, -1.98272111e-08,
#          7.36911839e-06],
#        [ 2.68788135e-05, -3.14125919e-07,  3.21116033e-05,
#          1.67025807e-05, -3.00829244e-07, -4.03161781e-08,
#          1.49841895e-05],
#        [-1.36692633e-02,  1.59749235e-04, -1.63304069e-02,
#         -8.49412393e-03,  1.52987190e-04,  2.05028564e-05,
#         -7.62023337e-03],
#        [-1.17308665e-03,  1.37095679e-05, -1.40146413e-03,
#         -7.28959792e-04,  1.31292539e-05,  1.75954084e-06,
#         -6.53963114e-04],
#        [-2.28717006e-04,  2.67295800e-06, -2.73243823e-04,
#         -1.42125479e-04,  2.55981403e-06,  3.43058131e-07,
#         -1.27503357e-04]]),
#         array([ 5.63905671e-05,  1.49656341e-04, -1.57246220e-02,  1.13039382e-04,
#        -2.01340439e-02,  1.43495187e-05,  1.78172611e-04, -8.86534099e-03,
#        -3.19970754e-03,  1.65729790e-05])],
#        [array([[ 8.91300193e-03, -1.00504624e-02],
#        [ 1.87203898e-03, -2.11094505e-03],
#        [-8.31047029e-03,  9.37103679e-03],
#        [-3.83765482e-05,  4.32740907e-05],
#        [-8.56725182e-04,  9.66058830e-04],
#        [-7.51368055e-03,  8.47256225e-03],
#        [ 2.04221469e-05, -2.30283827e-05],
#        [-2.29930544e-05,  2.59273845e-05]]),
#         array([[-1.18869400e-03, -6.91200643e-04, -1.21253106e-03,
#          7.43255073e-06, -4.61646653e-04, -1.28304109e-03,
#          7.00441264e-07,  5.51985866e-06],
#        [-1.90648205e-03, -1.10857935e-03, -1.94471303e-03,
#          1.19206664e-05, -7.40410113e-04, -2.05780026e-03,
#          1.12339988e-06,  8.85300294e-06],
#        [-7.70369410e-05, -4.47953664e-05, -7.85817746e-05,
#          4.81689126e-07, -2.99184198e-05, -8.31513923e-05,
#          4.53942330e-08,  3.57731281e-07],
#        [-6.22799301e-03, -3.62144739e-03, -6.35288391e-03,
#          3.89417917e-05, -2.41873193e-03, -6.72231118e-03,
#          3.66986231e-06,  2.89205138e-05],
#        [ 2.06920403e-03,  1.20319877e-03,  2.11069809e-03,
#         -1.29381186e-05,  8.03605567e-04,  2.23343754e-03,
#         -1.21928426e-06, -9.60862408e-06],
#        [ 1.31959751e-03,  7.67318290e-04,  1.34605960e-03,
#         -8.25105152e-06,  5.12484940e-04,  1.42433446e-03,
#         -7.77576523e-07, -6.12772651e-06],
#        [-1.19363108e-03, -6.94071454e-04, -1.21756715e-03,
#          7.46342086e-06, -4.63564042e-04, -1.28837003e-03,
#          7.03350455e-07,  5.54278467e-06],
#        [ 6.99449070e-03,  4.06714973e-03,  7.13475230e-03,
#         -4.37344742e-05,  2.71641249e-03,  7.54964609e-03,
#         -4.12152322e-06, -3.24798478e-05]]),
#         array([[ 2.04267206e-04,  1.60285024e-04,  3.94899896e-05,
#          4.12592572e-04,  2.27489422e-04,  3.85682190e-04,
#          2.48461303e-04,  2.96954428e-05],
#        [-1.05379754e-03, -8.26897117e-04, -2.03725574e-04,
#         -2.12853079e-03, -1.17359902e-03, -1.98970236e-03,
#         -1.28179121e-03, -1.53196321e-04],
#        [ 1.07068022e-03,  8.40144667e-04,  2.06989420e-04,
#          2.16263155e-03,  1.19240101e-03,  2.02157898e-03,
#          1.30232653e-03,  1.55650648e-04],
#        [ 2.61392245e-06,  2.05110076e-06,  5.05336966e-07,
#          5.27977547e-06,  2.91108748e-06,  4.93541451e-06,
#          3.17945591e-06,  3.80000225e-07],
#        [-1.40789828e-03, -1.10475398e-03, -2.72182154e-04,
#         -2.84376715e-03, -1.56795587e-03, -2.65828911e-03,
#         -1.71250318e-03, -2.04673885e-04],
#        [ 1.07912168e-05,  8.46768536e-06,  2.08621366e-06,
#          2.17968217e-05,  1.20180214e-05,  2.03751751e-05,
#          1.31259433e-05,  1.56877829e-06],
#        [ 3.62650295e-03,  2.84565556e-03,  7.01094249e-04,
#          7.32505332e-03,  4.03878368e-03,  6.84729391e-03,
#          4.41111260e-03,  5.27204599e-04],
#        [-4.12575532e-04, -3.23741046e-04, -7.97612292e-05,
#         -8.33347668e-04, -4.59479380e-04, -7.78994522e-04,
#         -5.01838039e-04, -5.99783652e-05]]),
#         array([[-1.53413392e-03, -3.92476930e-04, -7.05576927e-05,
#          1.08726834e-05, -1.20366873e-04,  9.72528411e-06,
#         -1.68333909e-04, -4.06537744e-04],
#        [ 3.53884000e-05,  9.05340167e-06,  1.62757880e-06,
#         -2.50803965e-07,  2.77654447e-06, -2.24336507e-07,
#          3.88301676e-06,  9.37774734e-06],
#        [ 1.30178832e-05,  3.33036038e-06,  5.98716832e-07,
#         -9.22600827e-08,  1.02137230e-06, -8.25238336e-08,
#          1.42839627e-06,  3.44967332e-06],
#        [ 4.63022578e-03,  1.18454900e-03,  2.12952757e-04,
#         -3.28152441e-05,  3.63283669e-04, -2.93522362e-05,
#          5.08054739e-04,  1.22698646e-03],
#        [ 4.25120493e-06,  1.08758423e-06,  1.95520878e-07,
#         -3.01290551e-08,  3.33546008e-07, -2.69495220e-08,
#          4.66466413e-07,  1.12654785e-06],
#        [-1.29137329e-05, -3.30371566e-06, -5.93926766e-07,
#          9.15219511e-08, -1.01320076e-06,  8.18635973e-08,
#         -1.41696831e-06, -3.42207403e-06],
#        [-2.66302265e-03, -6.81280128e-04, -1.22477400e-04,
#          1.88733211e-05, -2.08938545e-04,  1.68816109e-05,
#         -2.92202009e-04, -7.05687558e-04],
#        [-8.33919741e-04, -2.13341388e-04, -3.83535310e-05,
#          5.91013941e-06, -6.54286503e-05,  5.28643967e-06,
#         -9.15024226e-05, -2.20984522e-04],
#        [ 2.67781738e-06,  6.85065060e-07,  1.23157838e-07,
#         -1.89781741e-08,  2.10099328e-07, -1.69753986e-08,
#          2.93825372e-07,  7.09608088e-07],
#        [-1.87939072e-05, -4.80803854e-06, -8.64366998e-07,
#          1.33195806e-07, -1.47455435e-06,  1.19139591e-07,
#         -2.06217452e-06, -4.98029054e-06],
#        [-1.36638151e-04, -3.49560891e-05, -6.28424450e-06,
#          9.68379185e-07, -1.07205158e-05,  8.66185683e-07,
#         -1.49927160e-05, -3.62084202e-05],
#        [ 3.82528351e-05,  9.78620909e-06,  1.75931954e-06,
#         -2.71104732e-07,  3.00128567e-06, -2.42494925e-07,
#          4.19731889e-06,  1.01368082e-05],
#        [ 5.09893893e-05,  1.30445972e-05,  2.34509753e-06,
#         -3.61370986e-07,  4.00058514e-06, -3.23235339e-07,
#          5.59484614e-06,  1.35119308e-05],
#        [-1.59136512e-03, -4.07118369e-04, -7.31898631e-05,
#          1.12782913e-05, -1.24857186e-04,  1.00880880e-05,
#         -1.74613643e-04, -4.21703725e-04],
#        [-7.15290720e-03, -1.82992568e-03, -3.28975601e-04,
#          5.06939417e-05, -5.61211158e-04,  4.53441866e-05,
#         -7.84857709e-04, -1.89548430e-03],
#        [ 6.03291174e-05,  1.54339765e-05,  2.77464912e-06,
#         -4.27563321e-07,  4.73337244e-06, -3.82442367e-07,
#          6.61965429e-06,  1.59869116e-05],
#        [-5.64413168e-06, -1.44393618e-06, -2.59584189e-07,
#          4.00009779e-08, -4.42833884e-07,  3.57796562e-08,
#         -6.19306268e-07, -1.49566640e-06],
#        [ 2.89394638e-05,  7.40357264e-06,  1.33098015e-06,
#         -2.05099192e-07,  2.27056629e-06, -1.83454980e-07,
#          3.17540276e-06,  7.66881181e-06]]),
#         array([[-1.37270575e-03,  5.34697421e-05,  3.58302922e-05,
#         -2.06843295e-03,  2.78569647e-05,  1.00338339e-06,
#         -2.22769300e-03, -2.89127194e-03,  5.27717775e-06,
#          9.15728839e-07, -2.44583606e-03, -6.59762741e-04,
#          3.27533898e-05, -2.96463903e-03, -1.25726245e-03,
#          7.35432426e-06,  1.59971759e-05,  4.97576886e-05],
#        [-5.41104779e-05,  2.10771558e-06,  1.41238881e-06,
#         -8.15352419e-05,  1.09808943e-06,  3.95522163e-08,
#         -8.78130896e-05, -1.13970606e-04,  2.08020262e-07,
#          3.60969750e-08, -9.64120375e-05, -2.60070866e-05,
#          1.29110086e-06, -1.16862652e-04, -4.95598361e-05,
#          2.89898983e-07,  6.30590229e-07,  1.96139071e-06],
#        [ 1.13157450e-05, -4.40771789e-07, -2.95362972e-07,
#          1.70508937e-05, -2.29635747e-07, -8.27127779e-09,
#          1.83637360e-05,  2.38338742e-05, -4.35018196e-08,
#         -7.54870740e-09,  2.01619737e-05,  5.43867974e-06,
#         -2.69998874e-07,  2.44386674e-05,  1.03641012e-05,
#         -6.06245425e-08, -1.31870915e-07, -4.10171894e-07],
#        [-1.60150932e-03,  6.23821166e-05,  4.18025107e-05,
#         -2.41320082e-03,  3.25001833e-05,  1.17062804e-06,
#         -2.59900645e-03, -3.37319120e-03,  6.15678148e-06,
#          1.06836317e-06, -2.85350975e-03, -7.69732462e-04,
#          3.82127480e-05, -3.45878716e-03, -1.46682384e-03,
#          8.58014823e-06,  1.86635965e-05,  5.80513354e-05],
#        [-1.50552147e-03,  5.86431907e-05,  3.92970411e-05,
#         -2.26856355e-03,  3.05522568e-05,  1.10046544e-06,
#         -2.44323276e-03, -3.17101608e-03,  5.78776947e-06,
#          1.00432990e-06, -2.68248218e-03, -7.23597883e-04,
#          3.59224340e-05, -3.25148177e-03, -1.37890849e-03,
#          8.06588965e-06,  1.75449778e-05,  5.45719785e-05],
#        [ 1.22610942e-05, -4.77595102e-07, -3.20038425e-07,
#          1.84753733e-05, -2.48820162e-07, -8.96228358e-09,
#          1.98978941e-05,  2.58250230e-05, -4.71360838e-08,
#         -8.17934763e-09,  2.18463616e-05,  5.89304233e-06,
#         -2.92555339e-07,  2.64803424e-05,  1.12299473e-05,
#         -6.56892871e-08, -1.42887782e-07, -4.44438806e-07],
#        [ 2.92052213e-06, -1.13760407e-07, -7.62313127e-08,
#          4.40072769e-06, -5.92675320e-08, -2.13476442e-09,
#          4.73956397e-06,  6.15137199e-06, -1.12275441e-08,
#         -1.94827357e-09,  5.20367773e-06,  1.40368880e-06,
#         -6.96849996e-08,  6.30746530e-06,  2.67490888e-06,
#         -1.56468105e-08, -3.40350481e-08, -1.05862768e-07],
#        [-4.02979277e-06,  1.56968804e-07,  1.05185436e-07,
#         -6.07220895e-06,  8.17784839e-08,  2.94558912e-09,
#         -6.53974179e-06, -8.48778173e-06,  1.54919820e-08,
#          2.68826546e-09, -7.18013491e-06, -1.93683688e-06,
#          9.61527066e-08, -8.70316229e-06, -3.69089088e-06,
#          2.15897710e-08,  4.69622159e-08,  1.46071490e-07]]),
#         array([[ 7.47538780e-06,  1.02456564e-05, -6.57829024e-08,
#          2.49821091e-05,  5.67018089e-06, -7.48790657e-08,
#         -6.18422063e-08, -1.19981447e-08],
#        [-1.16547921e-05, -1.59738864e-05,  1.02561375e-07,
#         -3.89493222e-05, -8.84031455e-06,  1.16743100e-07,
#          9.64174806e-08,  1.87061709e-08],
#        [-1.81677012e-05, -2.49003837e-05,  1.59874530e-07,
#         -6.07149094e-05, -1.37804425e-05,  1.81981260e-07,
#          1.50297316e-07,  2.91595183e-08],
#        [-1.97938147e-06, -2.71291109e-06,  1.74184218e-08,
#         -6.61492421e-06, -1.50138712e-06,  1.98269627e-08,
#          1.63749788e-08,  3.17694624e-09],
#        [ 5.56898583e-06,  7.63276996e-06, -4.90066952e-08,
#          1.86110761e-05,  4.22414968e-06, -5.57831201e-08,
#         -4.60709704e-08, -8.93833195e-09],
#        [-6.14825455e-06, -8.42670713e-06,  5.41042203e-08,
#         -2.05469428e-05, -4.66353269e-06,  6.15855081e-08,
#          5.08631306e-08,  9.86806965e-09],
#        [-4.82727810e-03, -6.61619626e-03,  4.24797177e-05,
#         -1.61323521e-02, -3.66155452e-03,  4.83536217e-05,
#          3.99349887e-05,  7.74787643e-06],
#        [-8.89723134e-04, -1.21944142e-03,  7.82950284e-06,
#         -2.97337890e-03, -6.74866808e-04,  8.91213121e-06,
#          7.36047988e-06,  1.42802315e-06]]),
#         array([[ 5.19031990e-05,  1.76016553e-05,  2.76765545e-05,
#          4.07618698e-07,  2.30630179e-05,  3.81009171e-05,
#         -3.33747047e-03, -1.28679495e-02],
#        [-2.47452622e-06, -8.39172888e-07, -1.31950171e-06,
#         -1.94335450e-08, -1.09954769e-06, -1.81649147e-06,
#          1.59116554e-04,  6.13489707e-04],
#        [ 9.68204928e-05,  3.28342177e-05,  5.16279862e-05,
#          7.60374003e-07,  4.30218715e-05,  7.10736456e-05,
#         -6.22573449e-03, -2.40039388e-02],
#        [-1.16983875e-05, -3.96721182e-06, -6.23797889e-06,
#         -9.18725932e-08, -5.19814050e-06, -8.58751102e-06,
#          7.52227680e-04,  2.90028867e-03],
#        [ 5.86983555e-07,  1.99060605e-07,  3.12999635e-07,
#          4.60984056e-09,  2.60824236e-07,  4.30890816e-07,
#         -3.77441144e-05, -1.45526189e-04],
#        [-1.88444524e-07, -6.39061873e-08, -1.00485042e-07,
#         -1.47993791e-09, -8.37347123e-08, -1.38332691e-07,
#          1.21173270e-05,  4.67195601e-05],
#        [ 1.13470658e-04,  3.84806996e-05,  6.05064218e-05,
#          8.91135089e-07,  5.04203184e-05,  8.32961401e-05,
#         -7.29637052e-03, -2.81318825e-02]]),
#         array([[-9.80811534e-05,  1.10620050e-06, -1.09929166e-04,
#         -5.73832932e-05,  1.12973201e-06,  1.47184507e-07,
#         -4.60869089e-05],
#        [-2.10714493e-04,  2.37652668e-06, -2.36168395e-04,
#         -1.23280479e-04,  2.42708104e-06,  3.16206608e-07,
#         -9.90116788e-05],
#        [-2.25299385e-02,  2.54102122e-04, -2.52515113e-02,
#         -1.31813506e-02,  2.59507477e-04,  3.38093281e-05,
#         -1.05864908e-02],
#        [ 1.69518349e-05, -1.91189924e-07,  1.89995837e-05,
#          9.91782906e-06, -1.95256987e-07, -2.54386025e-08,
#          7.96542093e-06],
#        [-4.34345373e-03,  4.89872980e-05, -4.86813451e-03,
#         -2.54117810e-03,  5.00293740e-05,  6.51796064e-06,
#         -2.04092580e-03],
#        [ 1.42026987e-05, -1.60184010e-07,  1.59183571e-05,
#          8.30942129e-06, -1.63591504e-07, -2.13131386e-08,
#          6.67364177e-06],
#        [ 2.88794287e-05, -3.25714343e-07,  3.23680076e-05,
#          1.68961790e-05, -3.32643060e-07, -4.33376274e-08,
#          1.35700239e-05],
#        [-1.46866793e-02,  1.65642547e-04, -1.64608017e-02,
#         -8.59257866e-03,  1.69166156e-04,  2.20394192e-05,
#         -6.90105723e-03],
#        [-1.26040058e-03,  1.42153278e-05, -1.41265452e-03,
#         -7.37409109e-04,  1.45177216e-05,  1.89140759e-06,
#         -5.92243919e-04],
#        [-2.45740626e-04,  2.77156614e-06, -2.75425616e-04,
#         -1.43772844e-04,  2.83052392e-06,  3.68768226e-07,
#         -1.15469950e-04]]),
#         array([ 5.83083865e-05,  1.43799847e-04, -1.50322478e-02,  1.14467130e-04,
#        -1.98967335e-02,  1.45698298e-05,  1.82544475e-04, -9.00591643e-03,
#        -2.23277174e-03,  1.59323870e-05])],
#        [array([[-2.00272480e-03, -2.89655349e-03],
#        [-1.76848832e-03, -2.55777579e-03],
#        [ 3.75159899e-03,  5.42596123e-03],
#        [ 2.67207835e-03,  3.86464374e-03],
#        [ 1.76584471e-05,  2.55395232e-05],
#        [ 2.22442552e-05,  3.21720064e-05],
#        [-1.71124451e-05, -2.47498371e-05],
#        [ 2.16002344e-05,  3.12405550e-05]]),
#         array([[-2.49593025e-04, -5.64247727e-05, -1.59630996e-04,
#         -1.66553695e-04,  2.93852316e-06,  7.63771986e-08,
#          3.41054539e-07,  6.41722785e-07],
#        [-6.00154082e-03, -1.35675096e-03, -3.83837625e-03,
#         -4.00483467e-03,  7.06576904e-05,  1.83651316e-06,
#          8.20076095e-06,  1.54304211e-05],
#        [-3.12821730e-03, -7.07187029e-04, -2.00069871e-03,
#         -2.08746278e-03,  3.68293104e-05,  9.57256213e-07,
#          4.27452934e-06,  8.04288628e-06],
#        [-5.84013916e-03, -1.32026335e-03, -3.73514938e-03,
#         -3.89713117e-03,  6.87574670e-05,  1.78712313e-06,
#          7.98021485e-06,  1.50154451e-05],
#        [ 3.11567799e-03,  7.04352302e-04,  1.99267900e-03,
#          2.07909528e-03, -3.66816818e-05, -9.53419094e-07,
#         -4.25739508e-06, -8.01064674e-06],
#        [ 1.72142770e-03,  3.89158176e-04,  1.10096513e-03,
#          1.14871056e-03, -2.02668130e-05, -5.26768827e-07,
#         -2.35223211e-06, -4.42592246e-06],
#        [-6.98605684e-04, -1.57931765e-04, -4.46803837e-04,
#         -4.66180328e-04,  8.22486518e-06,  2.13778190e-07,
#          9.54604557e-07,  1.79616872e-06],
#        [ 3.10590915e-03,  7.02143889e-04,  1.98643120e-03,
#          2.07257653e-03, -3.65666707e-05, -9.50429762e-07,
#         -4.24404652e-06, -7.98553031e-06]]),
#         array([[ 6.68991479e-04,  1.75115461e-03,  5.89476794e-04,
#          5.37098018e-04,  1.10746255e-03,  1.85157409e-03,
#          6.46432907e-04,  9.40316121e-04],
#        [-9.27791088e-04, -2.42858943e-03, -8.17516117e-04,
#         -7.44874591e-04, -1.53588486e-03, -2.56785623e-03,
#         -8.96505723e-04, -1.30407777e-03],
#        [ 3.00000412e-05,  7.85282205e-05,  2.64343100e-05,
#          2.40854528e-05,  4.96626985e-05,  8.30313999e-05,
#          2.89884318e-05,  4.21672372e-05],
#        [-2.24433474e-06, -5.87477903e-06, -1.97757862e-06,
#         -1.80185814e-06, -3.71531888e-06, -6.21166663e-06,
#         -2.16865517e-06, -3.15457551e-06],
#        [-1.76253163e-05, -4.61360942e-05, -1.55304145e-05,
#         -1.41504380e-05, -2.91773190e-05, -4.87817559e-05,
#         -1.70309860e-05, -2.47736625e-05],
#        [-9.02939706e-05, -2.36353836e-04, -7.95618509e-05,
#         -7.24922726e-05, -1.49474536e-04, -2.49907483e-04,
#         -8.72492337e-05, -1.26914735e-04],
#        [ 2.21152394e-03,  5.78889337e-03,  1.94866764e-03,
#          1.77551608e-03,  3.66100320e-03,  6.12085588e-03,
#          2.13695076e-03,  3.10845755e-03],
#        [-8.30221128e-07, -2.17318994e-06, -7.31543082e-07,
#         -6.66540810e-07, -1.37436550e-06, -2.29781092e-06,
#         -8.02225849e-07, -1.16693610e-06]]),
#         array([[-1.56096688e-03, -7.85906203e-04, -1.33158714e-03,
#          1.17633929e-05,  1.16171655e-05, -1.57042538e-05,
#         -3.58397038e-04,  4.19816302e-06],
#        [ 3.60073653e-05,  1.81287714e-05,  3.07161830e-05,
#         -2.71350270e-07, -2.67977191e-07,  3.62255477e-07,
#          8.26726895e-06, -9.68404846e-08],
#        [ 1.32455741e-05,  6.66880186e-06,  1.12991738e-05,
#         -9.98181924e-08, -9.85773804e-08,  1.33258341e-07,
#          3.04117568e-06, -3.56234844e-08],
#        [ 4.71121134e-05,  2.37197230e-05,  4.01891192e-05,
#         -3.55035271e-07, -3.50621927e-07,  4.73975836e-07,
#          1.08169123e-05, -1.26706296e-07],
#        [ 4.32556117e-06,  2.17780748e-06,  3.68993197e-06,
#         -3.25972807e-08, -3.21920730e-08,  4.35177140e-08,
#          9.93146188e-07, -1.16334377e-08],
#        [-1.31396022e-05, -6.61544776e-06, -1.12087741e-05,
#          9.90195917e-08,  9.77887068e-08, -1.32192201e-07,
#         -3.01684459e-06,  3.53384768e-08],
#        [-2.70960058e-03, -1.36421338e-03, -2.31143230e-03,
#          2.04194571e-05,  2.01656285e-05, -2.72601909e-05,
#         -6.22122629e-04,  7.28737111e-06],
#        [-8.48505521e-04, -4.27200448e-04, -7.23819991e-04,
#          6.39430851e-06,  6.31482265e-06, -8.53646939e-06,
#         -1.94816346e-04,  2.28202439e-06],
#        [ 2.72465409e-06,  1.37179243e-06,  2.32427374e-06,
#         -2.05328998e-08, -2.02776611e-08,  2.74116381e-08,
#          6.25578905e-07, -7.32785696e-09],
#        [-1.91226245e-05, -9.62774375e-06, -1.63126079e-05,
#          1.44107442e-07,  1.42316083e-07, -1.92384957e-07,
#         -4.39054282e-06,  5.14295951e-08],
#        [-1.39028038e-06, -6.99969989e-07, -1.18598254e-06,
#          1.04771053e-08,  1.03468673e-08, -1.39870462e-08,
#         -3.19207521e-07,  3.73910794e-09],
#        [ 3.89219012e-05,  1.95961643e-05,  3.32024359e-05,
#         -2.93314113e-07, -2.89668007e-07,  3.91577439e-07,
#          8.93644461e-06, -1.04679022e-07],
#        [ 5.18812257e-05,  2.61208470e-05,  4.42574237e-05,
#         -3.90975138e-07, -3.86115036e-07,  5.21955939e-07,
#          1.19118975e-05, -1.39532648e-07],
#        [-1.61919910e-03, -8.15224608e-04, -1.38126229e-03,
#          1.22022289e-05,  1.20505464e-05, -1.62901045e-05,
#         -3.71767119e-04,  4.35477642e-06],
#        [-7.27801604e-03, -3.66429167e-03, -6.20853179e-03,
#          5.48468793e-05,  5.41650931e-05, -7.32211631e-05,
#         -1.67102801e-03,  1.95739564e-05],
#        [ 6.13843115e-05,  3.09054034e-05,  5.23640574e-05,
#         -4.62590067e-07, -4.56839739e-07,  6.17562625e-07,
#          1.40938002e-05, -1.65090848e-07],
#        [-5.74285109e-06, -2.89137607e-06, -4.89895507e-06,
#          4.32779289e-08,  4.27399531e-08, -5.77764922e-08,
#         -1.31855508e-06,  1.54451868e-08],
#        [ 2.94456332e-05,  1.48251100e-05,  2.51186792e-05,
#         -2.21901282e-07, -2.19142889e-07,  2.96240555e-07,
#          6.76069928e-06, -7.91929473e-08]]),
#         array([[-1.44588776e-03,  5.23555555e-05,  5.81630266e-05,
#          1.67784122e-05,  4.64905321e-05,  2.07003585e-05,
#         -2.06528159e-03, -2.76685915e-03,  3.16338577e-06,
#          2.17545231e-05,  3.04752092e-07, -2.21938350e-03,
#          4.38190374e-05, -1.32754065e-03, -2.03145151e-03,
#          3.23942781e-05,  7.71510356e-06,  5.46583802e-05],
#        [-5.69952283e-05,  2.06379563e-06,  2.29271945e-06,
#          6.61385662e-07,  1.83260317e-06,  8.15984265e-07,
#         -8.14110190e-05, -1.09066397e-04,  1.24697020e-07,
#          8.57538218e-07,  1.20129761e-08, -8.74855386e-05,
#          1.72729593e-06, -5.23301216e-05, -8.00774760e-05,
#          1.27694509e-06,  3.04120487e-07,  2.15457032e-06],
#        [ 1.19190127e-05, -4.31587117e-07, -4.79460350e-07,
#         -1.38310948e-07, -3.83239457e-07, -1.70641071e-07,
#          1.70249159e-05,  2.28082913e-05, -2.60770138e-08,
#         -1.79330958e-07, -2.51218950e-09,  1.82952376e-05,
#         -3.61217292e-07,  1.09434316e-05,  1.67460414e-05,
#         -2.67038578e-07, -6.35985860e-08, -4.50570192e-07],
#        [-1.68688935e-03,  6.10822166e-05,  6.78576811e-05,
#          1.95750498e-05,  5.42396069e-05,  2.41507089e-05,
#         -2.40952419e-03, -3.22804119e-03,  3.69066115e-06,
#          2.53805824e-05,  3.55548386e-07, -2.58931191e-03,
#          5.11228256e-05, -1.54881606e-03, -2.37005528e-03,
#          3.77937793e-05,  9.00106248e-06,  6.37688777e-05],
#        [-1.58578419e-03,  5.74212013e-05,  6.37905725e-05,
#          1.84018023e-05,  5.09887092e-05,  2.27032154e-05,
#         -2.26510728e-03, -3.03456576e-03,  3.46945819e-06,
#          2.38593753e-05,  3.34238287e-07, -2.43411927e-03,
#          4.80587349e-05, -1.45598644e-03, -2.22800397e-03,
#          3.55285766e-05,  8.46157604e-06,  5.99468350e-05],
#        [ 1.29147605e-05, -4.67643117e-07, -5.19515815e-07,
#         -1.49865833e-07, -4.15256358e-07, -1.84896905e-07,
#          1.84472252e-05,  2.47137601e-05, -2.82555608e-08,
#         -1.94312770e-07, -2.72206486e-09,  1.98236731e-05,
#         -3.91394400e-07,  1.18576766e-05,  1.81450527e-05,
#         -2.89347731e-07, -6.89117906e-08, -4.88212092e-07],
#        [ 3.07622169e-06, -1.11389902e-07, -1.23745680e-07,
#         -3.56971798e-08, -9.89116769e-08, -4.40413797e-08,
#          4.39402297e-06,  5.88667555e-06, -6.73031212e-09,
#         -4.62841845e-08, -6.48380199e-10,  4.72188495e-06,
#         -9.32278956e-08,  2.82443039e-06,  4.32204722e-06,
#         -6.89209658e-08, -1.64143923e-08, -1.16289313e-07],
#        [-4.24463002e-06,  1.53697935e-07,  1.70746676e-07,
#          4.92556573e-08,  1.36480240e-07,  6.07691453e-08,
#         -6.06295765e-06, -8.12254848e-06,  9.28661449e-09,
#          6.38638105e-08,  8.94647506e-10, -6.51534794e-06,
#          1.28637649e-07, -3.89720354e-06, -5.96364413e-06,
#          9.50984781e-08,  2.26488951e-08,  1.60458237e-07]]),
#         array([[ 7.86187153e-06,  6.66352462e-06, -3.05601790e-09,
#          2.64460528e-05,  7.92117943e-06, -2.50945466e-08,
#         -4.37969420e-08, -2.97498711e-08],
#        [-1.22573545e-05, -1.03890255e-05,  4.76460276e-09,
#         -4.12317402e-05, -1.23498208e-05,  3.91246222e-08,
#          6.82833143e-08,  4.63826858e-08],
#        [-1.91069864e-05, -1.61946012e-05,  7.42714913e-09,
#         -6.42727840e-05, -1.92511245e-05,  6.09881702e-08,
#          1.06441268e-07,  7.23021712e-08],
#        [-2.08171712e-06, -1.76441109e-06,  8.09192158e-10,
#         -7.00255668e-06, -2.09742105e-06,  6.64469612e-09,
#          1.15968372e-08,  7.87736303e-09],
#        [ 5.85690700e-06,  4.96416710e-06, -2.27666053e-09,
#          1.97016793e-05,  5.90108997e-06, -1.86948394e-08,
#         -3.26276784e-08, -2.21629453e-08],
#        [-6.46612439e-06, -5.48052444e-06,  2.51347173e-09,
#         -2.17509872e-05, -6.51490314e-06,  2.06394189e-08,
#          3.60215088e-08,  2.44682664e-08],
#        [-5.07685236e-03, -4.30301241e-03,  1.97344254e-06,
#         -1.70777028e-02, -5.11515081e-03,  1.62049593e-05,
#          2.82821473e-05,  1.92111640e-05],
#        [-9.35722555e-04, -7.93094909e-04,  3.63728263e-07,
#         -3.14761797e-03, -9.42781401e-04,  2.98676125e-06,
#          5.21272655e-06,  3.54083952e-06]]),
#         array([[ 6.17927161e-05,  1.10635914e-05,  3.79863914e-05,
#          1.51147143e-05,  2.09247877e-05,  3.21655647e-05,
#         -3.67930360e-03, -1.24228653e-02],
#        [-2.94601679e-06, -5.27465501e-07, -1.81103137e-06,
#         -7.20606004e-07, -9.97605864e-07, -1.53351883e-06,
#          1.75413720e-04,  5.92269964e-04],
#        [ 1.15268449e-04,  2.06380799e-05,  7.08600088e-05,
#          2.81950654e-05,  3.90332059e-05,  6.00018089e-05,
#         -6.86339176e-03, -2.31736764e-02],
#        [-1.39273716e-05, -2.49360698e-06, -8.56169824e-06,
#         -3.40668376e-06, -4.71620786e-06, -7.24975047e-06,
#          8.29272959e-04,  2.79997177e-03],
#        [ 6.98826061e-07,  1.25120345e-07,  4.29595622e-07,
#          1.70935297e-07,  2.36642567e-07,  3.63766740e-07,
#         -4.16099730e-05, -1.40492643e-04],
#        [-2.24350314e-07, -4.01684916e-08, -1.37916884e-07,
#         -5.48768709e-08, -7.59714572e-08, -1.16783255e-07,
#          1.33584178e-05,  4.51035964e-05],
#        [ 1.35091098e-04,  2.41871988e-05,  8.30457644e-05,
#          3.30437548e-05,  4.57457242e-05,  7.03202860e-05,
#         -8.04368535e-03, -2.71588404e-02]]),
#         array([[-9.39425855e-05,  9.38711856e-07, -1.00246865e-04,
#         -5.88885527e-05,  1.10264081e-06,  1.63402375e-07,
#         -5.14298744e-05],
#        [-2.01823323e-04,  2.01669930e-06, -2.15367241e-04,
#         -1.26514331e-04,  2.36887915e-06,  3.51048569e-07,
#         -1.10490339e-04],
#        [-2.15792800e-02,  2.15628790e-04, -2.30274180e-02,
#         -1.35271194e-02,  2.53284436e-04,  3.75346876e-05,
#         -1.18138079e-02],
#        [ 1.62365464e-05, -1.62242060e-07,  1.73261453e-05,
#          1.01779903e-05, -1.90574686e-07, -2.82416140e-08,
#          8.88887120e-06],
#        [-4.16018021e-03,  4.15701832e-05, -4.43936074e-03,
#         -2.60783744e-03,  4.88296597e-05,  7.23615729e-06,
#         -2.27753520e-03],
#        [ 1.36034110e-05, -1.35930719e-07,  1.45163059e-05,
#          8.52739128e-06, -1.59668547e-07, -2.36615763e-08,
#          7.44733300e-06],
#        [ 2.76608513e-05, -2.76398280e-07,  2.95171101e-05,
#          1.73393939e-05, -3.24666213e-07, -4.81128847e-08,
#          1.51432292e-05],
#        [-1.40669699e-02,  1.40562784e-04, -1.50109732e-02,
#         -8.81797634e-03,  1.65109518e-04,  2.44678839e-05,
#         -7.70111327e-03],
#        [-1.20721754e-03,  1.20630001e-05, -1.28823125e-03,
#         -7.56752580e-04,  1.41695837e-05,  2.09981674e-06,
#         -6.60904171e-04],
#        [-2.35371516e-04,  2.35192625e-06, -2.51166780e-04,
#         -1.47544246e-04,  2.76264739e-06,  4.09401811e-07,
#         -1.28856657e-04]]),
#         array([ 5.22360118e-05,  1.46179968e-04, -1.39795965e-02,  1.05811490e-04,
#        -1.82639455e-02,  7.22615938e-06,  1.66703738e-04, -7.98700867e-03,
#        -3.17704670e-03,  1.80942000e-05])],
#        [array([[ 7.65677945e-03, -8.64318664e-03],
#        [ 1.60818877e-03, -1.81536843e-03],
#        [-7.13917024e-03,  8.05889490e-03],
#        [-3.29676542e-05,  3.72148094e-05],
#        [-7.35976029e-04,  8.30790311e-04],
#        [-6.45468218e-03,  7.28622565e-03],
#        [ 1.75437946e-05, -1.98039256e-05],
#        [-1.97523514e-05,  2.22970064e-05]]),
#         array([[-1.02244321e-03, -5.94121943e-04, -1.04264671e-03,
#          6.37794839e-06, -3.95783533e-04, -1.10274280e-03,
#          5.82532747e-07,  4.74104511e-06],
#        [-1.63984139e-03, -9.52880070e-04, -1.67224469e-03,
#          1.02292467e-05, -6.34775816e-04, -1.76862958e-03,
#          9.34292786e-07,  7.60390599e-06],
#        [-6.62625513e-05, -3.85038851e-05, -6.75719007e-05,
#          4.13342404e-07, -2.56499593e-05, -7.14666116e-05,
#          3.77528119e-08,  3.07257893e-07],
#        [-5.35694566e-03, -3.11281736e-03, -5.46279901e-03,
#          3.34163528e-05, -2.07365149e-03, -5.77766396e-03,
#          3.05209741e-06,  2.48400311e-05],
#        [ 1.77980507e-03,  1.03421025e-03,  1.81497405e-03,
#         -1.11023329e-05,  6.88955175e-04,  1.91958557e-03,
#         -1.01403650e-06, -8.25291427e-06],
#        [ 1.13503855e-03,  6.59548913e-04,  1.15746693e-03,
#         -7.08031235e-06,  4.39368723e-04,  1.22418104e-03,
#         -6.46683471e-07, -5.26314706e-06],
#        [-1.02668979e-03, -5.96589550e-04, -1.04697720e-03,
#          6.40443836e-06, -3.97427368e-04, -1.10732290e-03,
#          5.84952220e-07,  4.76073642e-06],
#        [ 6.01624095e-03,  3.49592108e-03,  6.13512199e-03,
#         -3.75290031e-05,  2.32886197e-03,  6.48873831e-03,
#         -3.42772816e-06, -2.78971679e-05]]),
#         array([[ 1.75471217e-04,  1.37671607e-04,  3.39639721e-05,
#          3.54580574e-04,  1.95190425e-04,  3.31843817e-04,
#          2.12958909e-04,  2.54196625e-05],
#        [-9.05241426e-04, -7.10236378e-04, -1.75217310e-04,
#         -1.82925172e-03, -1.00697118e-03, -1.71195467e-03,
#         -1.09863731e-03, -1.31137926e-04],
#        [ 9.19744115e-04,  7.21614931e-04,  1.78024430e-04,
#          1.85855779e-03,  1.02310366e-03,  1.73938155e-03,
#          1.11623836e-03,  1.33238860e-04],
#        [ 2.24543215e-06,  1.76172627e-06,  4.34622819e-07,
#          4.53742007e-06,  2.49777066e-06,  4.24646725e-06,
#          2.72514655e-06,  3.25284844e-07],
#        [-1.20942382e-03, -9.48892490e-04, -2.34094443e-04,
#         -2.44392327e-03, -1.34533716e-03, -2.28721167e-03,
#         -1.46780526e-03, -1.75203351e-04],
#        [ 9.26995561e-06,  7.27304287e-06,  1.79428011e-06,
#          1.87321103e-05,  1.03117002e-05,  1.75309518e-05,
#          1.12503900e-05,  1.34289342e-06],
#        [ 3.11526699e-03,  2.44418327e-03,  6.02986878e-04,
#          6.29512451e-03,  3.46535631e-03,  5.89146247e-03,
#          3.78081300e-03,  4.51293590e-04],
#        [-3.54413868e-04, -2.78066839e-04, -6.85998704e-05,
#         -7.16175992e-04, -3.94242400e-04, -6.70252664e-04,
#         -4.30130889e-04, -5.13422148e-05]]),
#         array([[-1.42234615e-03, -2.70899130e-04, -1.51617553e-04,
#          9.61035552e-06, -1.31174189e-04,  9.85503902e-06,
#         -2.11911108e-04, -4.15293070e-04],
#        [ 3.28097526e-05,  6.24892433e-06,  3.49741476e-06,
#         -2.21685409e-07,  3.02584057e-06, -2.27329608e-07,
#          4.88822714e-06,  9.57970950e-06],
#        [ 1.20693087e-05,  2.29871277e-06,  1.28654974e-06,
#         -8.15486078e-08,  1.11307770e-06, -8.36248680e-08,
#          1.79817030e-06,  3.52396658e-06],
#        [ 4.29283501e-03,  8.17610589e-04,  4.57602491e-04,
#         -2.90053660e-05,  3.95901624e-04, -2.97438543e-05,
#          6.39576679e-04,  1.25341123e-03],
#        [ 3.94143228e-06,  7.50682652e-07,  4.20144084e-07,
#         -2.66310459e-08,  3.63493923e-07, -2.73090830e-08,
#          5.87222235e-07,  1.15080954e-06],
#        [-1.19727476e-05, -2.28032180e-06, -1.27625663e-06,
#          8.08961739e-08, -1.10417247e-06,  8.29558228e-08,
#         -1.78378394e-06, -3.49577290e-06],
#        [-2.46897611e-03, -4.70239599e-04, -2.63184962e-04,
#          1.66821123e-05, -2.27698397e-04,  1.71068456e-05,
#         -3.67845384e-04, -7.20885470e-04],
#        [-7.73154491e-04, -1.47254506e-04, -8.24157976e-05,
#          5.22396714e-06, -7.13032571e-05,  5.35697144e-06,
#         -1.15189981e-04, -2.25743715e-04],
#        [ 2.48269280e-06,  4.72852071e-07,  2.64647117e-07,
#         -1.67747918e-08,  2.28963403e-07, -1.72018847e-08,
#          3.69888992e-07,  7.24890434e-07],
#        [-1.74244511e-05, -3.31864973e-06, -1.85739080e-06,
#          1.17731658e-07, -1.60694937e-06,  1.20729153e-07,
#         -2.59601698e-06, -5.08754766e-06],
#        [-1.26681735e-04, -2.41277217e-05, -1.35038681e-05,
#          8.55949529e-07, -1.16830730e-05,  8.77742347e-07,
#         -1.88739337e-05, -3.69882162e-05],
#        [ 3.54654648e-05,  6.75472958e-06,  3.78050520e-06,
#         -2.39629240e-07,  3.27076049e-06, -2.45730296e-07,
#          5.28389379e-06,  1.03551177e-05],
#        [ 4.72739442e-05,  9.00376496e-06,  5.03925136e-06,
#         -3.19415504e-07,  4.35978351e-06, -3.27547950e-07,
#          7.04320389e-06,  1.38029280e-05],
#        [-1.47540708e-03, -2.81005083e-04, -1.57273680e-04,
#          9.96887196e-06, -1.36067671e-04,  1.02226834e-05,
#         -2.19816499e-04, -4.30785670e-04],
#        [-6.63169613e-03, -1.26306857e-03, -7.06917612e-04,
#          4.48083315e-05, -6.11600321e-04,  4.59491695e-05,
#         -9.88036619e-04, -1.93630605e-03],
#        [ 5.59331141e-05,  1.06529849e-05,  5.96229120e-06,
#         -3.77922852e-07,  5.15836520e-06, -3.87544919e-07,
#          8.33330778e-06,  1.63312108e-05],
#        [-5.23286060e-06, -9.96647259e-07, -5.57806215e-07,
#          3.53568299e-08, -4.82594371e-07,  3.62570290e-08,
#         -7.79628287e-07, -1.52787755e-06],
#        [ 2.68307312e-05,  5.11016377e-06,  2.86007019e-06,
#         -1.81287000e-07,  2.47443240e-06, -1.85902639e-07,
#          3.99743058e-06,  7.83396978e-06]]),
#         array([[-1.40836905e-03,  5.23269554e-05,  3.25286254e-05,
#         -1.61174414e-03,  2.87376209e-05,  4.90801531e-07,
#         -2.33880245e-03, -2.92085820e-03,  2.07047900e-06,
#          2.15207869e-06, -2.29557497e-03, -7.35221438e-04,
#          3.06604436e-05, -3.03833675e-03, -1.33195387e-03,
#          8.71825534e-06,  1.62405337e-05,  4.76125358e-05],
#        [-5.55162842e-05,  2.06266825e-06,  1.28224091e-06,
#         -6.35330958e-05,  1.13280388e-06,  1.93468305e-08,
#         -9.21928960e-05, -1.15136862e-04,  8.16158948e-08,
#          8.48324604e-08, -9.04889183e-05, -2.89815814e-05,
#          1.20859933e-06, -1.19767731e-04, -5.25040857e-05,
#          3.43663573e-07,  6.40183115e-07,  1.87683126e-06],
#        [ 1.16097314e-05, -4.31351355e-07, -2.68146055e-07,
#          1.32862311e-05, -2.36895336e-07, -4.04586707e-09,
#          1.92796542e-05,  2.40777651e-05, -1.70677601e-08,
#         -1.77404179e-08,  1.89233133e-05,  6.06071500e-06,
#         -2.52745909e-07,  2.50461863e-05,  1.09798115e-05,
#         -7.18679546e-08, -1.33877008e-07, -3.92488569e-07],
#        [-1.64311700e-03,  6.10488493e-05,  3.79505198e-05,
#         -1.88039080e-03,  3.35276279e-05,  5.72608678e-07,
#         -2.72863570e-03, -3.40770891e-03,  2.41558790e-06,
#          2.51078869e-06, -2.67820303e-03, -8.57768668e-04,
#          3.57709481e-05, -3.54476887e-03, -1.55396488e-03,
#          1.01714203e-05,  1.89475174e-05,  5.55486270e-05],
#        [-1.54463537e-03,  5.73898339e-05,  3.56759226e-05,
#         -1.76768795e-03,  3.15181206e-05,  5.38288883e-07,
#         -2.56509257e-03, -3.20346494e-03,  2.27080756e-06,
#          2.36030240e-06, -2.51768262e-03, -8.06357563e-04,
#          3.36269854e-05, -3.33231009e-03, -1.46082666e-03,
#          9.56178746e-06,  1.78118816e-05,  5.22192722e-05],
#        [ 1.25796410e-05, -4.67387659e-07, -2.90547730e-07,
#          1.43962001e-05, -2.56686238e-07, -4.38387017e-09,
#          2.08903307e-05,  2.60892892e-05, -1.84936487e-08,
#         -1.92225023e-08,  2.05042201e-05,  6.56704416e-06,
#         -2.73861012e-07,  2.71386151e-05,  1.18970958e-05,
#         -7.78720054e-08, -1.45061470e-07, -4.25278167e-07],
#        [ 2.99639816e-06, -1.11329053e-07, -6.92067986e-08,
#          3.42909210e-06, -6.11411861e-08, -1.04421267e-09,
#          4.97595666e-06,  6.21431869e-06, -4.40508079e-09,
#         -4.57868952e-09,  4.88398733e-06,  1.56423216e-06,
#         -6.52321184e-08,  6.46426207e-06,  2.83381981e-06,
#         -1.85486639e-08, -3.45528080e-08, -1.01298814e-07],
#        [-4.13448798e-06,  1.53613975e-07,  9.54928757e-08,
#         -4.73152742e-06,  8.43637879e-08,  1.44082478e-09,
#         -6.86592098e-06, -8.57463680e-06,  6.07821545e-09,
#          6.31776412e-09, -6.73901993e-06, -2.15835771e-06,
#          9.00085353e-08, -8.91951350e-06, -3.91015924e-06,
#          2.55938043e-08,  4.76766310e-08,  1.39774058e-07]]),
#         array([[ 7.98357809e-06,  1.08017659e-05, -6.20731719e-08,
#          2.52800306e-05,  5.98746036e-06, -6.72495966e-08,
#         -6.35486600e-08, -1.33454007e-08],
#        [-1.24471058e-05, -1.68409105e-05,  9.67775765e-08,
#         -3.94138082e-05, -9.33498137e-06,  1.04848081e-07,
#          9.90779932e-08,  2.08066624e-08],
#        [-1.94027742e-05, -2.62519164e-05,  1.50858640e-07,
#         -6.14389586e-05, -1.45515382e-05,  1.63439090e-07,
#          1.54444572e-07,  3.24338025e-08],
#        [-2.11394337e-06, -2.86016135e-06,  1.64361354e-08,
#         -6.69380978e-06, -1.58539843e-06,  1.78067825e-08,
#          1.68268247e-08,  3.53368139e-09],
#        [ 5.94757549e-06,  8.04705830e-06, -4.62430343e-08,
#          1.88330205e-05,  4.46051533e-06, -5.00993474e-08,
#         -4.73422378e-08, -9.94200557e-09],
#        [-6.56622393e-06, -8.88408846e-06,  5.10530920e-08,
# ...
#          3.98243390e-05,  4.74196638e-06, -1.32863066e-07,
#         -7.37636733e-08, -2.43311011e-08],
#        [ 4.28645026e-03,  3.07670368e-03, -3.75074078e-05,
#          3.12679246e-02,  3.72313643e-03, -1.04316919e-04,
#         -5.79152606e-05, -1.91034692e-05],
#        [ 7.90042315e-04,  5.67072041e-04, -6.91304867e-06,
#          5.76303981e-03,  6.86217065e-04, -1.92268135e-05,
#         -1.06744518e-05, -3.52099012e-06]]),
#         array([[-1.22736210e-04, -4.13854771e-05, -5.87464155e-05,
#         -8.36106212e-06, -6.53376219e-05, -5.87277501e-05,
#          5.88471470e-03,  2.32507110e-02],
#        [ 5.85154623e-06,  1.97308548e-06,  2.80078200e-06,
#          3.98620274e-07,  3.11502299e-06,  2.79989211e-06,
#         -2.80558445e-04, -1.10849611e-03],
#        [-2.28952753e-04, -7.72006807e-05, -1.09585864e-04,
#         -1.55967680e-05, -1.21881134e-04, -1.09551045e-04,
#          1.09773769e-02,  4.33719952e-02],
#        [ 2.76633381e-05,  9.32781330e-06,  1.32407703e-05,
#          1.88448779e-06,  1.47263528e-05,  1.32365633e-05,
#         -1.32634740e-03, -5.24044438e-03],
#        [-1.38804810e-06, -4.68036556e-07, -6.64374845e-07,
#         -9.45569070e-08, -7.38916103e-07, -6.64163754e-07,
#          6.65514038e-05,  2.62946895e-04],
#        [ 4.45617363e-07,  1.50257917e-07,  2.13290135e-07,
#          3.03564405e-08,  2.37220775e-07,  2.13222367e-07,
#         -2.13655860e-05, -8.44161682e-05],
#        [-2.68325628e-04, -9.04768380e-05, -1.28431283e-04,
#         -1.82789354e-05, -1.42840964e-04, -1.28390477e-04,
#          1.28651502e-02,  5.08306527e-02]]),
#         array([[ 1.85635026e-04, -2.45281436e-06,  2.33763556e-04,
#          1.06554487e-04, -2.03849414e-06, -2.31303153e-07,
#          8.71018825e-05],
#        [ 3.98812505e-04, -5.26954994e-06,  5.02210338e-04,
#          2.28918339e-04, -4.37943729e-06, -4.96924484e-07,
#          1.87126970e-04],
#        [ 4.26416858e-02, -5.63428904e-04,  5.36971513e-02,
#          2.44763235e-02, -4.68256603e-04, -5.31319792e-05,
#          2.00079219e-02],
#        [-3.20841896e-05,  4.23931640e-07, -4.04024735e-05,
#         -1.84163217e-05,  3.52322694e-07,  3.99772303e-08,
#         -1.50542350e-05],
#        [ 8.22071438e-03, -1.08621130e-04,  1.03520519e-02,
#          4.71868925e-03, -9.02732552e-05, -1.02430947e-05,
#          3.85724457e-03],
#        [-2.68809884e-05,  3.55181217e-07, -3.38502682e-05,
#         -1.54296847e-05,  2.95185335e-07,  3.34939881e-08,
#         -1.26128390e-05],
#        [-5.46591605e-05,  7.22217011e-07, -6.88303277e-05,
#         -3.13743528e-05,  6.00222817e-07,  6.81058762e-08,
#         -2.56466458e-05],
#        [ 2.77970029e-02, -3.67284608e-04,  3.50037725e-02,
#          1.59554769e-02, -3.05244267e-04, -3.46353515e-05,
#          1.30426425e-02],
#        [ 2.38551940e-03, -3.15201090e-05,  3.00399935e-03,
#          1.36928790e-03, -2.61958501e-05, -2.97238172e-06,
#          1.11931048e-03],
#        [ 4.65105334e-04, -6.14548377e-06,  5.85690527e-04,
#          2.66970416e-04, -5.10741166e-06, -5.79526030e-07,
#          2.18232253e-04]]),
#         array([-1.23195109e-04, -2.85808288e-04,  3.29740741e-02, -2.39023025e-04,
#         4.28207392e-02, -4.45316498e-05, -3.81493240e-04,  1.95055223e-02,
#         4.16126906e-03, -2.73044707e-05])],
#        [array([[-3.05362312e-04,  1.12819569e-04],
#        [-1.40765476e-04,  5.20074013e-05],
#        [-2.57806130e-05,  9.52493985e-06],
#        [ 5.03539714e-03, -1.86038458e-03],
#        [-3.11216343e-05,  1.14982407e-05],
#        [-1.49207664e-05,  5.51264637e-06],
#        [ 2.81072741e-04, -1.03845512e-04],
#        [ 1.67274988e-02, -6.18016413e-03]]),
#         array([[ 2.97057283e-08,  4.98083177e-08,  6.49568871e-08,
#         -1.36933241e-05,  1.54224314e-07,  1.33132918e-07,
#          2.68891574e-09, -3.33356648e-06],
#        [-1.36037319e-07, -2.28097084e-07, -2.97469924e-07,
#          6.27085484e-05, -7.06269916e-07, -6.09681912e-07,
#         -1.23138838e-08,  1.52660605e-05],
#        [ 7.92542250e-08,  1.32887488e-07,  1.73303536e-07,
#         -3.65334855e-05,  4.11467055e-07,  3.55195677e-07,
#          7.17396764e-09, -8.89388154e-06],
#        [-6.87640182e-07, -1.15298303e-06, -1.50364823e-06,
#          3.16978591e-04, -3.57004665e-06, -3.08181450e-06,
#         -6.22441063e-08,  7.71667418e-05],
#        [-4.57855663e-05, -7.67697736e-05, -1.00118329e-04,
#          2.11055792e-02, -2.37706597e-04, -2.05198337e-04,
#         -4.14443736e-06,  5.13804031e-03],
#        [ 5.84053038e-07,  9.79295946e-07,  1.27713641e-06,
#         -2.69228463e-04,  3.03224949e-06,  2.61756536e-06,
#          5.28675612e-08, -6.55422286e-05],
#        [-5.16877635e-05, -8.66661313e-05, -1.13024538e-04,
#          2.38262901e-02, -2.68349250e-04, -2.31650365e-04,
#         -4.67869495e-06,  5.80038283e-03],
#        [-3.09162019e-05, -5.18379482e-05, -6.76038041e-05,
#          1.42513110e-02, -1.60508774e-04, -1.38557928e-04,
#         -2.79848590e-06,  3.46940541e-03]]),
#         array([[-1.49369835e-06, -2.05021941e-06, -1.15256375e-06,
#         -2.39450557e-06,  4.89283811e-05, -2.01266476e-06,
#          9.26035271e-05,  6.50593348e-05],
#        [ 5.70090451e-07,  7.82494343e-07,  4.39891754e-07,
#          9.13895872e-07, -1.86741873e-05,  7.68161093e-07,
#         -3.53434055e-05, -2.48307869e-05],
#        [-1.06553386e-04, -1.46252971e-04, -8.22184548e-05,
#         -1.70812719e-04,  3.49031964e-03, -1.43573999e-04,
#          6.60589829e-03,  4.64102569e-03],
#        [ 1.37684520e-06,  1.88982920e-06,  1.06239781e-06,
#          2.20718158e-06, -4.51006768e-05,  1.85521247e-06,
#         -8.53590830e-05, -5.99696938e-05],
#        [-6.73345943e-05, -9.24220691e-05, -5.19565496e-05,
#         -1.07942183e-04,  2.20564794e-03, -9.07291385e-05,
#          4.17448471e-03,  2.93281699e-03],
#        [-1.13094629e-06, -1.55231345e-06, -8.72657920e-07,
#         -1.81298800e-06,  3.70458808e-05, -1.52387913e-06,
#          7.01143007e-05,  4.92593523e-05],
#        [ 3.59308829e-07,  4.93179855e-07,  2.77248971e-07,
#          5.75997818e-07, -1.17697119e-05,  4.84146090e-07,
#         -2.22757593e-05, -1.56500095e-05],
#        [-2.08455053e-05, -2.86121087e-05, -1.60847561e-05,
#         -3.34168397e-05,  6.82826505e-04, -2.80880097e-05,
#          1.29234079e-03,  9.07944167e-04]]),
#         array([[ 2.34496093e-06,  1.60344716e-05, -7.71728417e-04,
#          2.19032882e-06, -9.11790314e-04,  1.15246271e-05,
#          1.23141399e-05, -1.60909015e-03],
#        [ 1.18739206e-05,  8.11919891e-05, -3.90771626e-03,
#          1.10909270e-05, -4.61693227e-03,  5.83559859e-05,
#          6.23537550e-05, -8.14777273e-03],
#        [ 5.06865182e-06,  3.46586387e-05, -1.66809715e-03,
#          4.73441327e-06, -1.97084206e-03,  2.49105737e-05,
#          2.66171120e-05, -3.47806125e-03],
#        [ 1.70439284e-07,  1.16543684e-06, -5.60916975e-05,
#          1.59200126e-07, -6.62718456e-05,  8.37646875e-07,
#          8.95031199e-07, -1.16953835e-04],
#        [-2.12038376e-06, -1.44988485e-05,  6.97819901e-04,
#         -1.98056078e-06,  8.24468054e-04, -1.04209123e-05,
#         -1.11348133e-05,  1.45498741e-03],
#        [-1.01775900e-06, -6.95927491e-06,  3.34945257e-04,
#         -9.50645633e-07,  3.95734866e-04, -5.00191402e-06,
#         -5.34457805e-06,  6.98376662e-04],
#        [-1.63786434e-05, -1.11994570e-04,  5.39022394e-03,
#         -1.52985980e-05,  6.36850202e-03, -8.04950543e-05,
#         -8.60094953e-05,  1.12388712e-02],
#        [-7.09295199e-06, -4.85004827e-05,  2.33429587e-03,
#         -6.62522644e-06,  2.75794997e-03, -3.48592702e-05,
#         -3.72473596e-05,  4.86711700e-03],
#        [ 2.60385467e-06,  1.78047460e-05, -8.56930543e-04,
#          2.43215051e-06, -1.01245587e-03,  1.27969953e-05,
#          1.36736737e-05, -1.78674061e-03],
#        [-1.05670421e-07, -7.22557613e-07,  3.47762157e-05,
#         -9.87022712e-08,  4.10877920e-05, -5.19331554e-07,
#         -5.54909183e-07,  7.25100503e-05],
#        [-1.74215769e-06, -1.19125984e-05,  5.73345414e-04,
#         -1.62727581e-06,  6.77402546e-04, -8.56206917e-06,
#         -9.14862726e-06,  1.19545223e-03],
#        [-5.81225163e-06, -3.97432565e-05,  1.91281641e-03,
#         -5.42897841e-06,  2.25997571e-03, -2.85650954e-05,
#         -3.05219924e-05,  3.98831246e-03],
#        [ 1.33923858e-07,  9.15750142e-07, -4.40744432e-05,
#          1.25092612e-07, -5.20735657e-05,  6.58186885e-07,
#          7.03277018e-07, -9.18972933e-05],
#        [-4.29758471e-08, -2.93862038e-07,  1.41433838e-05,
#         -4.01419210e-08,  1.67102832e-05, -2.11210603e-07,
#         -2.25679919e-07,  2.94896224e-05],
#        [-2.79074061e-08, -1.90826425e-07,  9.18434848e-06,
#         -2.60671276e-08,  1.08512267e-05, -1.37154715e-07,
#         -1.46550716e-07,  1.91497998e-05],
#        [ 1.37239502e-07,  9.38421988e-07, -4.51656241e-05,
#          1.28189614e-07, -5.33627862e-05,  6.74482063e-07,
#          7.20688523e-07, -9.41724567e-05],
#        [-3.86597164e-06, -2.64349020e-05,  1.27229419e-03,
#         -3.61104059e-06,  1.50320436e-03, -1.89998396e-05,
#         -2.03014536e-05,  2.65279341e-03],
#        [ 1.43367738e-05,  9.80325897e-05, -4.71824312e-03,
#          1.33913740e-05, -5.57456261e-03,  7.04600107e-05,
#          7.52869852e-05, -9.83775949e-03]]),
#         array([[ 7.60586851e-04,  1.17362317e-03,  1.18465944e-03,
#         -2.22682313e-05,  4.92344079e-04,  1.10592310e-03,
#          2.69496644e-03,  4.02875064e-03,  3.40289910e-03,
#         -4.13437163e-06,  2.28718741e-04,  4.09996954e-03,
#         -1.87194632e-05, -7.08469626e-06, -4.57619472e-05,
#         -8.39833588e-06,  2.64025229e-03,  4.33909723e-04],
#        [ 9.20356334e-04,  1.42015539e-03,  1.43350995e-03,
#         -2.69459138e-05,  5.95766271e-04,  1.33823420e-03,
#          3.26107325e-03,  4.87503323e-03,  4.11771481e-03,
#         -5.00284105e-06,  2.76763583e-04,  4.96121243e-03,
#         -2.26516887e-05, -8.57291324e-06, -5.53747385e-05,
#         -1.01624971e-05,  3.19486581e-03,  5.25057147e-04],
#        [ 5.55163371e-04,  8.56644570e-04,  8.64700104e-04,
#         -1.62539049e-05,  3.59369083e-04,  8.07229310e-04,
#          1.96709509e-03,  2.94064351e-03,  2.48382540e-03,
#         -3.01773780e-06,  1.66945126e-04,  2.99262722e-03,
#         -1.36636077e-05, -5.17122254e-06, -3.34023089e-05,
#         -6.13006714e-06,  1.92715844e-03,  3.16716998e-04],
#        [ 2.20958144e-03,  3.40949356e-03,  3.44155504e-03,
#         -6.46914557e-05,  1.43030916e-03,  3.21281805e-03,
#          7.82914906e-03,  1.17039265e-02,  9.88576476e-03,
#         -1.20107662e-05,  6.64450987e-04,  1.19108246e-02,
#         -5.43819268e-05, -2.05817565e-05, -1.32943068e-04,
#         -2.43980119e-05,  7.67019894e-03,  1.26055146e-03],
#        [ 4.76629917e-06,  7.35463562e-06,  7.42379559e-06,
#         -1.39546263e-07,  3.08532704e-06,  6.93038588e-06,
#          1.68882966e-05,  2.52465985e-05,  2.13246326e-05,
#         -2.59084838e-08,  1.43329055e-06,  2.56928994e-05,
#         -1.17307526e-07, -4.43970099e-08, -2.86772156e-07,
#         -5.26290736e-08,  1.65454245e-05,  2.71914187e-06],
#        [ 4.33836356e-07,  6.69430978e-07,  6.75726032e-07,
#         -1.27017294e-08,  2.80831520e-07,  6.30815072e-07,
#          1.53720041e-06,  2.29798674e-06,  1.94100298e-06,
#         -2.35823262e-09,  1.30460453e-07,  2.33860978e-06,
#         -1.06775232e-08, -4.04108855e-09, -2.61024713e-08,
#         -4.79038447e-09,  1.50599163e-06,  2.47500746e-07],
#        [-3.90365360e-04, -6.02353079e-04, -6.08017360e-04,
#          1.14289987e-05, -2.52691818e-04, -5.67606540e-04,
#         -1.38317083e-03, -2.06772533e-03, -1.74651183e-03,
#          2.12193449e-06, -1.17388137e-04, -2.10427788e-03,
#          9.60762075e-06,  3.63616595e-06,  2.34869680e-05,
#          4.31038140e-06, -1.35508921e-03, -2.22700833e-04],
#        [-4.86018630e-04, -7.49950811e-04, -7.57003040e-04,
#          1.42295062e-05, -3.14610218e-04, -7.06690145e-04,
#         -1.72209643e-03, -2.57439090e-03, -2.17446878e-03,
#          2.64188322e-06, -1.46152368e-04, -2.61990012e-03,
#          1.19618264e-05,  4.52715475e-06,  2.92421028e-05,
#          5.36657674e-06, -1.68713383e-03, -2.77270385e-04]]),
#         array([[-1.69990006e-05, -2.27196520e-05, -1.24233118e-04,
#         -4.64692453e-05,  2.51924834e-07,  2.98189567e-07,
#         -1.04404400e-05, -2.08680221e-05],
#        [ 5.51275473e-04,  7.36795485e-04,  4.02886457e-03,
#          1.50699184e-03, -8.16989100e-06, -9.67025053e-06,
#          3.38582171e-04,  6.76747358e-04],
#        [ 7.84647677e-06,  1.04870413e-05,  5.73440934e-05,
#          2.14494877e-05, -1.16284622e-07, -1.37639710e-07,
#          4.81914626e-06,  9.63235747e-06],
#        [ 6.71475528e-06,  8.97446306e-06,  4.90731783e-05,
#          1.83557621e-05, -9.95125330e-08, -1.17787511e-07,
#          4.12406596e-06,  8.24305291e-06],
#        [-7.76860748e-04, -1.03829668e-03, -5.67750044e-03,
#         -2.12366206e-03,  1.15130601e-05,  1.36273758e-05,
#         -4.77132053e-04, -9.53676491e-04],
#        [-2.19571742e-04, -2.93463932e-04, -1.60468741e-03,
#         -6.00231353e-04,  3.25404862e-06,  3.85163834e-06,
#         -1.34856493e-04, -2.69546902e-04],
#        [-6.19503814e-06, -8.27984620e-06, -4.52749503e-05,
#         -1.69350395e-05,  9.18103359e-08,  1.08670844e-07,
#         -3.80486628e-06, -7.60504666e-06],
#        [ 1.73382999e-03,  2.31731352e-03,  1.26712806e-02,
#          4.73967693e-03, -2.56953242e-05, -3.04141417e-05,
#          1.06488307e-03,  2.12845468e-03]]),
#         array([[-9.37917615e-06,  1.81605061e-03, -5.71145961e-06,
#         -8.57027723e-08,  1.27253424e-03,  1.34413141e-03,
#         -8.13673664e-06,  3.12281802e-03],
#        [ 4.71254333e-05, -9.12470035e-03,  2.86970843e-05,
#          4.30611411e-07, -6.39381610e-03, -6.75355428e-03,
#          4.08828274e-05, -1.56905202e-02],
#        [-7.56862656e-05,  1.46548147e-02, -4.60892345e-05,
#         -6.91587692e-07,  1.02688512e-02,  1.08466123e-02,
#         -6.56602670e-05,  2.51999142e-02],
#        [-1.33375307e-05,  2.58249023e-03, -8.12190397e-06,
#         -1.21872469e-07,  1.80959012e-03,  1.91140391e-03,
#         -1.15707364e-05,  4.44076118e-03],
#        [ 3.62929752e-07, -7.02725683e-05,  2.21006471e-07,
#          3.31629190e-09, -4.92410557e-05, -5.20115276e-05,
#          3.14853220e-07, -1.20838286e-04],
#        [-5.47565954e-06,  1.06022903e-03, -3.33440888e-06,
#         -5.00341602e-08,  7.42918582e-04,  7.84717748e-04,
#         -4.75031057e-06,  1.82313329e-03],
#        [-4.94462313e-08,  9.57406676e-06, -3.01103369e-08,
#         -4.51817840e-10,  6.70869396e-06,  7.08614826e-06,
#         -4.28961943e-08,  1.64632352e-05]]),
#         array([[ 2.23753349e-04,  3.78297258e-04,  5.26122634e-04,
#          4.58352136e-04, -4.01280288e-06,  2.19995543e-05,
#         -1.58131280e-06],
#        [ 4.80704722e-04,  8.12722038e-04,  1.13030547e-03,
#          9.84709444e-04, -8.62098064e-06,  4.72631568e-05,
#         -3.39724314e-06],
#        [ 5.13977357e-04,  8.68975705e-04,  1.20854111e-03,
#          1.05286745e-03, -9.21769360e-06,  5.05345409e-05,
#         -3.63238797e-06],
#        [-3.86723617e-05, -6.53829246e-05, -9.09322916e-05,
#         -7.92191922e-05,  6.93551916e-07, -3.80228821e-06,
#          2.73305856e-07],
#        [ 9.90875704e-03,  1.67526235e-02,  2.32989646e-02,
#          2.02977965e-02, -1.77704105e-04,  9.74234528e-04,
#         -7.00273064e-05],
#        [-3.24007344e-03, -5.47795553e-03, -7.61854954e-03,
#         -6.63719488e-03,  5.81076264e-05, -3.18565831e-04,
#          2.28982924e-05],
#        [-6.58828803e-05, -1.11387441e-04, -1.54913768e-04,
#         -1.34959137e-04,  1.18154661e-06, -6.47764160e-06,
#          4.65608414e-07],
#        [ 3.35048434e-04,  5.66462599e-04,  7.87816430e-04,
#          6.86336835e-04, -6.00877406e-06,  3.29421492e-05,
#         -2.36785898e-06],
#        [ 2.87536230e-05,  4.86134252e-05,  6.76098566e-05,
#          5.89009485e-05, -5.15668800e-07,  2.82707228e-06,
#         -2.03208007e-07],
#        [ 5.60610129e-04,  9.47817206e-04,  1.31819112e-03,
#          1.14839331e-03, -1.00540079e-05,  5.51195011e-05,
#         -3.96195175e-06]]),
#         array([-0.00075289, -0.00092621, -0.00012037, -0.00025212,  0.06247591,
#         0.0225786 , -0.00062485, -0.00019193, -0.00064914, -0.00045414])]],
#       dtype=object)

# %%
rhof*FiW+(1-rhof)*np.array(Wup)
# Out:
# array([[array([[-0.00029967, -0.00127301],
#        [ 0.0017444 , -0.00358731],
#        [-0.00197607,  0.00548286],
#        [ 0.00090377,  0.00052022],
#        [-0.00022603,  0.00015148],
#        [-0.0034869 ,  0.00625014],
#        [-0.00222641, -0.0064159 ],
#        [-0.00096445,  0.0042357 ]]),
#         array([[ 5.88009876e-04,  3.55209953e-04,  5.74472586e-04,
#         -2.46827009e-05,  1.70762612e-04,  6.55631068e-04,
#         -1.26730064e-05, -3.98154815e-06],
#        [-3.34269519e-03, -1.37279707e-03, -3.60960765e-03,
#         -6.59173423e-04, -6.01957082e-04, -2.21904569e-03,
#          2.93312211e-05,  5.16594330e-04],
#        [-1.31710471e-03, -4.82070339e-04, -8.25888355e-04,
#         -3.46141355e-04,  8.98065088e-05, -4.43016177e-04,
#         -2.12026245e-06, -1.22547090e-04],
#        [-3.67244062e-03, -1.50658468e-03, -3.19590098e-03,
#         -6.33568975e-04,  2.10571843e-03, -2.07255092e-03,
#          3.34277773e-04,  7.01752161e-04],
#        [ 2.20472471e-03,  9.46831436e-04,  2.15176856e-03,
#          2.26707543e-03,  3.37576997e-04,  1.46269893e-03,
#         -7.78695627e-06,  3.02051997e-04],
#        [-1.16198475e-03, -7.82305472e-04,  6.54253835e-04,
#          2.07627719e-04, -4.23982738e-03, -6.65396246e-04,
#         -6.74234024e-04, -2.34322556e-03],
#        [ 1.51372692e-02,  8.44744349e-03, -3.91763347e-04,
#          1.93038924e-03,  7.11805302e-03,  7.97395212e-03,
#          1.60586497e-03,  1.21057143e-02],
#        [ 2.43008229e-03,  9.94531395e-04,  1.97843147e-03,
#          1.66814198e-03, -3.87101905e-03,  1.30004003e-03,
#         -5.41220960e-04, -6.61254896e-04]]),
#         array([[-1.35819692e-04,  7.14714496e-03,  7.78501177e-05,
#          1.78901941e-05,  2.09434850e-04,  1.15742206e-02,
#          2.25804787e-02,  1.31202446e-05],
#        [-2.35432831e-04,  7.71550432e-03, -2.19584083e-04,
#         -3.90030451e-04, -4.11870524e-04,  1.25621921e-02,
#          2.63473665e-02, -6.88087357e-04],
#        [ 1.84473712e-04, -1.36771394e-04,  4.23895994e-05,
#          1.66424793e-03,  6.22346281e-04,  8.23184754e-04,
#          8.32211918e-04,  9.23559872e-04],
#        [ 5.99445725e-05,  5.37694708e-05,  1.68238558e-05,
#         -2.00402865e-03, -1.39962243e-06, -1.37739229e-03,
#         -1.52566282e-03, -7.32400439e-04],
#        [ 4.72409813e-04,  2.63888403e-04,  6.67883191e-05,
#          4.51443519e-04,  6.25174051e-04,  3.41332260e-04,
#          3.85717346e-04,  1.60458199e-04],
#        [-1.54786735e-05,  4.24834796e-05, -8.17328511e-06,
#         -1.79700142e-06, -1.34078192e-05,  9.09318000e-05,
#          2.24844682e-04, -3.95246369e-06],
#        [ 1.39983935e-03,  2.18135826e-03,  7.14719929e-04,
#          3.89024410e-03,  2.55396617e-03,  4.77203823e-03,
#          2.87492689e-03,  1.42822007e-03],
#        [ 7.45653331e-05,  3.43755614e-05, -3.37680827e-07,
#          1.19355805e-03,  1.30773388e-04,  8.27437329e-04,
#          9.94560444e-04,  4.50672841e-04]]),
#         array([[-1.32904277e-03, -2.88818495e-03, -4.04754935e-03,
#         -1.11483250e-05, -1.86102111e-04,  2.71022101e-05,
#         -2.30457576e-04, -2.26048018e-04],
#        [-9.96603662e-04, -4.17862426e-03, -5.69876643e-03,
#          9.64313932e-06, -4.10028112e-04,  4.24546355e-05,
#          6.90103878e-05, -7.09772736e-04],
#        [ 1.60546662e-03,  6.62612206e-03,  7.51707054e-03,
#         -9.87193691e-05, -6.30493505e-04, -5.48469979e-05,
#         -5.44120798e-04, -6.57724932e-04],
#        [ 4.89004249e-04, -3.58075864e-04,  1.44453729e-04,
#          3.52533077e-06,  3.83810889e-05, -6.10068219e-06,
#          2.37879927e-04,  8.08119412e-05],
#        [ 4.48052670e-04,  1.84877723e-03,  2.42586257e-03,
#         -4.15406281e-06,  7.01169190e-05, -1.73657559e-05,
#         -2.76550277e-05,  1.18548411e-04],
#        [ 7.03157457e-04,  2.93406997e-03,  3.77383753e-03,
#         -6.62548202e-06,  2.68402333e-05, -2.64922808e-05,
#         -4.62586450e-05,  4.03997905e-05],
#        [-7.45962315e-04, -8.04591703e-05,  1.27009090e-03,
#          1.41727004e-04,  1.28099446e-03, -8.72811480e-06,
#          5.02216376e-04,  1.45964146e-03],
#        [-3.08044765e-04,  1.88294908e-05,  2.24102146e-04,
#          6.89808455e-06,  2.78408205e-04, -3.43290752e-06,
#         -5.66369503e-05,  4.47373124e-04],
#        [ 2.77550084e-05,  1.11441711e-04, -6.94499167e-05,
#         -1.42575986e-05, -1.65087062e-04,  4.67006423e-07,
#         -7.57276079e-05, -2.12225569e-04],
#        [ 5.66004280e-04,  4.47283671e-04,  5.62909095e-07,
#         -5.43033993e-06,  1.46627062e-05, -1.03690476e-06,
#          1.01496367e-06,  7.08887442e-05],
#        [-1.23532919e-04, -4.80711621e-05,  3.03617876e-05,
#          2.77304741e-07,  6.03903751e-05, -2.97843580e-07,
#         -2.25519754e-05,  1.03864568e-04],
#        [ 5.22369450e-04,  1.67643524e-03,  2.99978825e-03,
#          7.60788789e-05,  6.13488414e-04, -1.88983345e-05,
#          4.20429608e-04,  6.31567990e-04],
#        [ 4.56821148e-04,  1.83182580e-03,  2.32751498e-03,
#         -5.57602221e-06, -1.74567857e-05, -1.61763542e-05,
#         -3.06554077e-05, -2.66584245e-05],
#        [ 1.66249072e-03,  8.61851914e-03,  1.08294959e-02,
#         -6.86570740e-06,  2.14246047e-05, -7.62449194e-05,
#         -2.11284869e-04, -5.36881033e-05],
#        [-2.15443637e-03,  4.93826173e-04, -3.52457246e-04,
#          2.60566529e-06, -6.57599345e-05, -2.97797139e-06,
#         -7.15208641e-04, -1.50691752e-04],
#        [ 1.38821166e-05, -1.85525351e-05, -2.86084415e-05,
#         -1.00675894e-06, -9.51843492e-06,  2.33445300e-07,
#          7.13265046e-07, -1.07405935e-05],
#        [ 1.82546830e-04,  1.94769647e-04,  3.51530033e-04,
#          1.46269227e-05,  2.25163901e-04, -2.91285516e-06,
#          8.59774019e-05,  3.17468452e-04],
#        [ 1.76159116e-03,  7.26828123e-03,  8.83439551e-03,
#         -1.54131391e-05, -5.30958097e-04, -5.80032490e-05,
#         -1.02375576e-04, -9.51590213e-04]]),
#         array([[-2.42866700e-04,  1.43201928e-04,  2.29458121e-04,
#         -4.95811662e-05,  5.46343096e-05,  1.24544658e-04,
#         -3.82518892e-04, -3.89244285e-04,  6.77257819e-04,
#          2.64891369e-06, -3.69876867e-04,  6.08402166e-04,
#          3.22179845e-05, -1.01429590e-03, -8.59481287e-04,
#          2.33450032e-06,  5.12264729e-04,  7.58126800e-05],
#        [ 1.00653599e-02,  4.72597434e-03,  6.75689759e-03,
#         -2.92636993e-04,  1.54869375e-04,  6.01619236e-03,
#          2.09564983e-04,  3.06158975e-04,  3.51486007e-04,
#         -8.08799005e-05, -9.45546189e-06,  7.81474757e-04,
#          6.86001723e-03,  1.35436476e-02, -1.40842088e-05,
#         -5.04616751e-05,  2.51585854e-04,  5.60253327e-03],
#        [ 3.03205099e-03,  1.38871936e-03,  2.03007925e-03,
#         -8.94188367e-05,  5.67734964e-05,  1.75453970e-03,
#          3.15681072e-04,  3.86160690e-04,  4.87903435e-04,
#         -2.49604247e-05,  1.11303705e-05,  7.66046572e-04,
#          1.95450613e-03,  3.92401532e-03,  1.06844122e-05,
#         -1.82101212e-05,  3.36449455e-04,  1.61178821e-03],
#        [ 2.72213022e-04,  4.15993321e-04,  6.93625987e-04,
#         -7.95020428e-05,  1.32590955e-04,  4.01044028e-04,
#          3.27058688e-04,  5.14888442e-04,  1.97027961e-03,
#         -2.59256908e-06, -3.99806322e-04,  2.30460884e-03,
#          1.25989771e-04, -9.02979436e-04, -1.01048782e-03,
#         -7.35116643e-06,  1.42831320e-03,  2.30986621e-04],
#        [-6.54022628e-04, -1.70871033e-05, -4.14600951e-05,
#         -3.96633485e-05,  1.63393524e-05, -4.69106776e-05,
#         -9.04410949e-04, -1.03435466e-03,  2.60862246e-06,
#          6.78578918e-06, -4.25487392e-04, -3.34443673e-04,
#         -4.69889595e-05, -1.34152369e-03, -9.37876731e-04,
#          9.07515046e-06,  4.09329669e-05, -2.80144326e-05],
#        [-2.42158369e-05, -1.34408867e-05, -1.92133408e-05,
#          1.17352289e-06, -4.06372479e-07, -1.70568941e-05,
#          7.81066200e-06,  9.07366419e-06,  4.81684665e-07,
#          1.82465253e-07,  3.53389707e-06,  2.29448803e-06,
#         -1.99927109e-05, -2.93851964e-05,  7.56205036e-06,
#          7.05791339e-08,  9.17229921e-08, -1.62391639e-05],
#        [ 6.20923043e-04,  2.86723209e-04,  3.93517126e-04,
#         -1.61441093e-05, -1.25081193e-05,  3.86514325e-04,
#         -2.30999075e-04, -2.92067552e-04, -3.50550274e-04,
#         -4.65307902e-06, -1.00510236e-05, -4.43847426e-04,
#          5.11716839e-04,  9.84653830e-04,  6.03884626e-06,
#         -9.45402130e-07, -2.48691254e-04,  3.93229723e-04],
#        [-1.56691491e-03, -6.81999163e-04, -1.00917697e-03,
#         -8.15232434e-05, -3.60346332e-05, -8.54532997e-04,
#         -3.54358675e-04, -4.48853871e-04, -4.29198843e-04,
#          1.26382493e-05, -1.33851112e-04, -6.63822596e-04,
#         -9.16156703e-04, -1.98447557e-03, -1.14383423e-04,
#          1.08173467e-05, -2.98945409e-04, -7.66394434e-04]]),
#         array([[-1.91906036e-04,  2.13358787e-02,  8.61970354e-03,
#         -3.87805130e-05, -2.76553046e-04, -8.01210737e-05,
#          3.54297725e-03,  1.20517657e-02],
#        [ 1.49700401e-04,  1.46314523e-03,  1.27099202e-03,
#          3.19086553e-04, -2.55035587e-05, -6.99917847e-06,
#          3.32661474e-04,  9.15835077e-04],
#        [ 6.05900726e-06, -1.43720345e-03, -5.68683336e-04,
#         -1.50622938e-05,  1.08426017e-05,  5.37728636e-06,
#         -2.36033792e-04, -8.05959609e-04],
#        [-1.23447942e-06,  2.56432093e-04,  1.12518755e-04,
#          1.20239108e-06, -4.24910215e-06, -9.81969503e-07,
#          4.38739081e-05,  1.46489650e-04],
#        [-2.34503980e-04, -3.83987598e-05, -9.69185929e-04,
#         -4.66598869e-04,  4.62036290e-06,  2.25930937e-06,
#         -1.31503186e-04, -1.44219718e-04],
#        [-5.88143827e-05, -1.28380409e-03, -7.87909671e-04,
#         -1.39147028e-04,  1.46064940e-05,  5.42093460e-06,
#         -2.48075361e-04, -7.57975204e-04],
#        [-2.41521566e-03, -2.66757914e-03, -6.84096480e-05,
#         -5.94548991e-03, -2.08890119e-03,  9.63057107e-06,
#         -2.10360341e-05, -1.92765682e-04],
#        [ 6.39495750e-05,  1.93488091e-03,  3.09739785e-03,
#         -4.25694798e-05, -4.20561057e-04, -1.20650054e-05,
#          6.77795905e-04,  1.60589969e-03]]),
#         array([[-1.52224673e-01,  1.92958912e-03,  6.44135094e-04,
#          1.07093013e-04,  2.25614300e-03,  3.32186533e-04,
#         -7.52137846e-04, -2.92030340e-03],
#        [ 9.12474824e-04, -1.86937134e-03,  3.17918728e-06,
#          2.43770322e-06, -1.17066037e-03, -1.32953485e-03,
#          6.75046616e-05, -2.80754011e-03],
#        [-2.34261165e-02,  3.23401537e-03,  1.08479488e-04,
#          1.85201084e-05,  2.18328055e-03,  2.16616500e-03,
#         -2.50011923e-03, -3.64828894e-03],
#        [ 4.86139792e-02,  2.87487432e-05, -2.07163598e-04,
#         -3.49363216e-05, -3.18465512e-04,  3.55585413e-04,
#          1.07955278e-04,  1.54310238e-03],
#        [-1.59317293e-01,  1.61353369e-03,  6.62913156e-04,
#          1.08448003e-04,  2.10421860e-03,  4.74190385e-05,
#          6.51327864e-04,  1.10611543e-03],
#        [-5.58199392e-04,  2.21791005e-04,  1.39753365e-06,
#         -1.40824233e-08,  1.41959405e-04,  1.54528728e-04,
#          6.78163392e-06,  3.72225330e-04],
#        [ 5.80379244e-04,  4.95809579e-06,  2.47526725e-05,
#          8.76351208e-06,  8.01313808e-06,  2.92028542e-05,
#         -3.03778100e-03, -1.01696581e-02]]),
#         array([[ 2.66013849e-03, -1.66296787e-05,  3.50924131e-03,
#          8.53453530e-03,  2.96978532e-03, -4.17338291e-05,
#         -2.07958244e-04],
#        [-8.69294415e-03,  4.61212574e-04, -1.11598355e-02,
#         -2.76757520e-02, -9.75753003e-03,  1.56383857e-04,
#          5.77277188e-04],
#        [ 3.70495439e-03, -1.53295522e-04,  7.02347940e-03,
#          3.22564245e-02,  1.31069795e-02, -1.76043302e-04,
#         -5.23160750e-03],
#        [ 5.97126444e-05, -1.50429639e-05,  6.76729860e-05,
#          1.83865531e-04,  6.85636355e-05, -1.65804450e-06,
#         -9.79651821e-07],
#        [ 3.94785908e-04,  3.31303991e-03,  3.02943907e-03,
#          3.00932766e-03,  1.12537909e-05,  1.56813900e-04,
#         -8.64487823e-04],
#        [-4.66640378e-04, -1.08417753e-03, -1.29727287e-03,
#         -7.80126861e-04,  1.84309239e-04, -5.31563899e-05,
#         -3.79013577e-06],
#        [-1.07540819e-02,  3.48797477e-04, -1.39736849e-02,
#         -3.43543721e-02, -1.20423582e-02,  1.82559803e-04,
#          7.69912605e-04],
#        [-5.02624331e-03,  1.56730277e-04, -5.07924284e-03,
#         -2.73672253e-03,  2.09271931e-04,  1.23187358e-05,
#         -2.88144716e-03],
#        [ 6.23802494e-03, -2.16581162e-04,  8.21980299e-03,
#          2.10635238e-02,  7.48806222e-03, -1.12835597e-04,
#         -7.21312530e-04],
#        [ 1.23166747e-04,  1.83964924e-04,  3.02258406e-04,
#          4.92258884e-04,  1.13573371e-04,  7.15021099e-06,
#         -5.60769336e-05]]),
#         array([-9.17007166e-03, -7.28555351e-02, -3.72296905e-02,  5.99878384e-05,
#         5.86898119e-03,  4.35294278e-03, -6.53517389e-02, -2.72359028e-03,
#        -2.38605868e-02,  2.39138338e-04])],
#        [array([[-0.00176417,  0.00098996],
#        [ 0.00294028, -0.00543519],
#        [-0.00195793,  0.00545483],
#        [ 0.00094717,  0.00045316],
#        [-0.00028258,  0.00023886],
#        [-0.00655774,  0.01099524],
#        [-0.00154187, -0.00747366],
#        [-0.00382645,  0.00865809]]),
#         array([[ 6.30437131e-04,  3.78872278e-04,  5.74413370e-04,
#         -2.50109623e-05,  1.70680140e-04,  6.77091779e-04,
#         -1.02728569e-05,  2.30142796e-05],
#        [-2.46033864e-03, -8.80693407e-04, -3.61083916e-03,
#         -6.66000252e-04, -6.03672229e-04, -1.77272884e-03,
#          7.92469547e-05,  1.07802460e-03],
#        [-1.54911472e-03, -6.11465849e-04, -8.25564538e-04,
#         -3.44346284e-04,  9.02574958e-05, -5.60372338e-04,
#         -1.52452854e-05, -2.70171590e-04],
#        [-3.53826376e-03, -1.43175221e-03, -3.19608825e-03,
#         -6.34607107e-04,  2.10545761e-03, -2.00468109e-03,
#          3.41868283e-04,  7.87126891e-04],
#        [ 1.91981985e-03,  7.87935666e-04,  2.15216621e-03,
#          2.26927976e-03,  3.38130802e-04,  1.31858731e-03,
#         -2.39042900e-05,  1.20771298e-04],
#        [-3.28414962e-03, -1.96586908e-03,  6.57215750e-04,
#          2.24046998e-04, -4.23570227e-03, -1.73883752e-03,
#         -7.94286872e-04, -3.69352732e-03],
#        [ 3.19221080e-02,  1.78086032e-02, -4.15190023e-04,
#          1.80052424e-03,  7.08542622e-03,  1.64641213e-02,
#          2.55539897e-03,  2.27856561e-02],
#        [ 2.48699281e-03,  1.02627126e-03,  1.97835204e-03,
#          1.66770166e-03, -3.87112968e-03,  1.32882672e-03,
#         -5.38001479e-04, -6.25043583e-04]]),
#         array([[-4.12595416e-04,  1.43787418e-02,  3.31703571e-05,
#         -2.04229493e-04,  1.30727546e-04,  2.32703602e-02,
#          4.63852105e-02, -2.29401669e-04],
#        [-5.65225571e-04,  1.63323298e-02, -2.72822352e-04,
#         -6.54697667e-04, -5.05654390e-04,  2.64987537e-02,
#          5.47119484e-02, -9.77064891e-04],
#        [ 1.96474099e-04, -4.50317532e-04,  4.43268156e-05,
#          1.67387855e-03,  6.25758856e-04,  3.16065856e-04,
#         -1.99908913e-04,  9.34075089e-04],
#        [ 5.99947971e-05,  5.24572023e-05,  1.68319635e-05,
#         -2.00398834e-03, -1.38533996e-06, -1.37951471e-03,
#         -1.52998250e-03, -7.32356431e-04],
#        [ 4.75023825e-04,  1.95589500e-04,  6.72102976e-05,
#          4.53541332e-04,  6.25917403e-04,  2.30867929e-04,
#          1.60893270e-04,  1.62748700e-04],
#        [-1.82006777e-05,  1.13604012e-04, -8.61269682e-06,
#         -3.98148029e-06, -1.41818814e-05,  2.05959739e-04,
#          4.58956903e-04, -6.33759218e-06],
#        [ 1.40025102e-03,  2.17060220e-03,  7.14786384e-04,
#          3.89057448e-03,  2.55408324e-03,  4.75464174e-03,
#          2.83952043e-03,  1.42858079e-03],
#        [ 7.45201729e-05,  3.55555053e-05, -3.44971002e-07,
#          1.19352181e-03,  1.30760546e-04,  8.29345730e-04,
#          9.98444544e-04,  4.50633270e-04]]),
#         array([[-2.03478856e-03, -5.82568999e-03, -7.80059639e-03,
#         -4.56326101e-06, -1.77716314e-04,  5.32747363e-05,
#         -1.86748418e-04, -2.03617338e-04],
#        [-2.06684641e-03, -8.63326427e-03, -1.13901519e-02,
#          1.96291952e-05, -3.97311297e-04,  8.21445020e-05,
#          1.35294040e-04, -6.75757270e-04],
#        [ 3.29578796e-03,  1.36616971e-02,  1.65059382e-02,
#         -1.14491159e-04, -6.50578204e-04, -1.17532430e-04,
#         -6.48807958e-04, -7.11448322e-04],
#        [ 4.95682434e-04, -3.30279452e-04,  1.79967282e-04,
#          3.46301900e-06,  3.83017375e-05, -6.34834212e-06,
#          2.37466325e-04,  8.05996888e-05],
#        [ 9.20769197e-04,  3.81635138e-03,  4.93969599e-03,
#         -8.56481323e-06,  6.45000170e-05, -3.48964104e-05,
#         -5.69319167e-05,  1.03524087e-04],
#        [ 1.45337319e-03,  6.05667094e-03,  7.76336884e-03,
#         -1.36254792e-05,  1.79260363e-05, -5.43139712e-05,
#         -9.27219725e-05,  1.65557248e-05],
#        [-7.57980399e-04, -1.30481687e-04,  1.20618059e-03,
#          1.41839141e-04,  1.28113726e-03, -8.28242514e-06,
#          5.02960696e-04,  1.46002343e-03],
#        [-2.88454137e-04,  1.00370988e-04,  3.28282078e-04,
#          6.71529134e-06,  2.78175426e-04, -4.15942440e-06,
#         -5.78502624e-05,  4.46750476e-04],
#        [ 5.54801903e-05,  2.26841423e-04,  7.79883151e-05,
#         -1.45162925e-05, -1.65416497e-04, -5.61179727e-07,
#         -7.74447195e-05, -2.13106757e-04],
#        [ 5.65207247e-04,  4.43966205e-04, -3.67558844e-06,
#         -5.42290310e-06,  1.46721767e-05, -1.00734686e-06,
#          1.06432654e-06,  7.09140762e-05],
#        [-1.24349664e-04, -5.14706724e-05,  2.60184683e-05,
#          2.84925492e-07,  6.04000798e-05, -2.67554688e-07,
#         -2.25013918e-05,  1.03890526e-04],
#        [ 9.37565226e-04,  3.40459245e-03,  5.20773521e-03,
#          7.22048342e-05,  6.08554984e-04, -3.42958366e-05,
#          3.94715168e-04,  6.18371845e-04],
#        [ 9.24727919e-04,  3.77938044e-03,  4.81577086e-03,
#         -9.94189450e-06, -2.30165373e-05, -3.35286393e-05,
#         -5.96344128e-05, -4.15298798e-05],
#        [ 3.86450332e-03,  1.77838917e-02,  2.25394586e-02,
#         -2.74119068e-05, -4.74010133e-06, -1.57906381e-04,
#         -3.47662751e-04, -1.23674550e-04],
#        [-1.97305724e-03,  1.24877521e-03,  6.12088935e-04,
#          9.13280888e-07, -6.79151136e-05, -9.70440192e-06,
#         -7.26442047e-04, -1.56456515e-04],
#        [ 8.75158488e-06, -3.99071969e-05, -5.58918160e-05,
#         -9.58887762e-07, -9.45747303e-06,  4.23710658e-07,
#          1.03101575e-06, -1.05775301e-05],
#        [ 1.99042728e-04,  2.63430037e-04,  4.39252665e-04,
#          1.44730053e-05,  2.24967893e-04, -3.52460419e-06,
#          8.49557567e-05,  3.16944164e-04],
#        [ 3.61666917e-03,  1.49896180e-02,  1.86994136e-02,
#         -3.27222147e-05, -5.53000464e-04, -1.26798668e-04,
#         -2.17266657e-04, -1.01055006e-03]]),
#         array([[-2.03171862e-04,  1.61465873e-04,  2.55703303e-04,
#         -5.07254387e-05,  5.48608271e-05,  1.47731426e-04,
#         -3.82745329e-04, -3.89648341e-04,  6.77148357e-04,
#          2.32940718e-06, -3.69953130e-04,  6.09748478e-04,
#          5.93896642e-05, -9.60546959e-04, -8.59312454e-04,
#          2.13744100e-06,  5.12093435e-04,  9.74876133e-05],
#        [ 2.07168542e-02,  9.62682088e-03,  1.37993852e-02,
#         -5.99684790e-04,  2.15651825e-04,  1.22380019e-02,
#          1.48804046e-04,  1.97736774e-04,  3.22113563e-04,
#         -1.66614516e-04, -2.99195198e-05,  1.14273668e-03,
#          1.41511160e-02,  2.79663420e-02,  3.12195555e-05,
#         -1.03339487e-04,  2.05621652e-04,  1.14186654e-02],
#        [ 6.07064154e-03,  2.78680170e-03,  4.03911534e-03,
#         -1.77011480e-04,  7.41131271e-05,  3.52945796e-03,
#          2.98347578e-04,  3.55230694e-04,  4.79524251e-04,
#         -4.94182507e-05,  5.29251421e-06,  8.69105077e-04,
#          4.03446444e-03,  8.03842988e-03,  2.36083820e-05,
#         -3.32947672e-05,  3.23337079e-04,  3.27097742e-03],
#        [ 4.66343845e-04,  5.05314626e-04,  8.21980178e-04,
#         -8.50982005e-05,  1.33698758e-04,  5.14440794e-04,
#          3.25951278e-04,  5.12912372e-04,  1.96974428e-03,
#         -4.15514153e-06, -4.00179294e-04,  2.31119309e-03,
#          2.58875072e-04, -6.40115890e-04, -1.00966213e-03,
#         -8.31490099e-06,  1.42747547e-03,  3.36989639e-04],
#        [-7.44924639e-04, -5.89119210e-05, -1.01562112e-04,
#         -3.70429404e-05,  1.58206226e-05, -1.00008861e-04,
#         -9.03892403e-04, -1.03342936e-03,  2.85929286e-06,
#          7.51746576e-06, -4.25312747e-04, -3.37526755e-04,
#         -1.09212675e-04, -1.46460989e-03, -9.38263363e-04,
#          9.52642043e-06,  4.13252347e-05, -7.76504835e-05],
#        [-5.51007505e-05, -2.76513080e-05, -3.96336326e-05,
#          2.06383409e-06, -5.82616362e-07, -3.50975601e-05,
#          7.98684350e-06,  9.38804359e-06,  5.66852566e-07,
#          4.31060062e-07,  3.59323434e-06,  1.24697835e-06,
#         -4.11338720e-05, -7.12050256e-05,  7.43068824e-06,
#          2.23902848e-07,  2.25000104e-07, -3.31035338e-05],
#        [ 1.41217606e-03,  6.50785708e-04,  9.16672794e-04,
#         -3.89533500e-05, -7.99285638e-06,  8.48705399e-04,
#         -2.35512740e-04, -3.00121764e-04, -3.52732225e-04,
#         -1.10219294e-05, -1.15712091e-05, -4.17010855e-04,
#          1.05334075e-03,  2.05605285e-03,  9.40426518e-06,
#         -4.87346400e-06, -2.52105734e-04,  8.25284798e-04],
#        [-2.99670518e-03, -1.33985829e-03, -1.95451667e-03,
#         -4.03070587e-05, -4.41936908e-05, -1.68970997e-03,
#         -3.46202505e-04, -4.34299950e-04, -4.25256069e-04,
#          2.41467303e-05, -1.31104145e-04, -7.12316148e-04,
#         -1.89486842e-03, -3.92048828e-03, -1.20464718e-04,
#          1.79153350e-05, -2.92775461e-04, -1.54711581e-03]]),
#         array([[-3.91982229e-04,  4.37913413e-02,  1.76416649e-02,
#         -8.17790279e-05, -5.73269589e-04, -1.66536372e-04,
#          7.21797487e-03,  2.48926404e-02],
#        [ 1.36547410e-04,  2.93936533e-03,  1.86409496e-03,
#          3.16259835e-04, -4.50096776e-05, -1.26801124e-05,
#          5.74255488e-04,  1.75999303e-03],
#        [ 1.94588542e-05, -2.94112932e-03, -1.17291765e-03,
#         -1.21825233e-05,  3.07148123e-05,  1.11648403e-05,
#         -4.82162053e-04, -1.66596075e-03],
#        [-3.64128046e-06,  5.26558337e-04,  2.21047739e-04,
#          6.85143782e-07, -7.81843077e-06, -2.02149563e-06,
#          8.80820067e-05,  3.00957956e-04],
#        [-2.34997596e-04,  1.70020105e-05, -9.46927487e-04,
#         -4.66704952e-04,  3.88832165e-06,  2.04611073e-06,
#         -1.22436452e-04, -1.12539482e-04],
#        [-4.70530459e-05, -2.60383250e-03, -1.31825926e-03,
#         -1.36619391e-04,  3.20487651e-05,  1.05007965e-05,
#         -4.64107484e-04, -1.51281690e-03],
#        [-2.41344977e-03, -2.86577250e-03, -1.48038058e-04,
#         -5.94511040e-03, -2.08628235e-03,  1.03932780e-05,
#         -5.34717990e-05, -3.06100066e-04],
#        [ 4.34848495e-05,  4.23173028e-03,  4.02020611e-03,
#         -4.69675683e-05, -4.50910608e-04, -2.09039648e-05,
#          1.05369179e-03,  2.91932420e-03]]),
#         array([[-3.10090190e-01,  3.56608114e-03,  1.33433826e-03,
#          2.09202966e-04,  4.38254300e-03,  3.84389378e-04,
#         -7.20593155e-05, -1.72671113e-03],
#        [ 1.84669360e-03, -1.87905580e-03, -9.05306728e-07,
#          1.83343551e-06, -1.18324401e-03, -1.32984378e-03,
#          6.34800833e-05, -2.81460356e-03],
#        [-4.77344168e-02,  3.48600415e-03,  2.14757706e-04,
#          3.42431076e-05,  2.51070588e-03,  2.17420325e-03,
#         -2.39540002e-03, -3.46449833e-03],
#        [ 9.90319868e-02, -4.93902871e-04, -4.27595959e-04,
#         -6.75474990e-05, -9.97580582e-04,  3.38913226e-04,
#         -1.09243545e-04,  1.16190106e-03],
#        [-3.24520198e-01,  3.32608778e-03,  1.38519609e-03,
#          2.15303897e-04,  4.32945097e-03,  1.02048206e-04,
#          1.36301558e-03,  2.35518436e-03],
#        [-1.13544430e-03,  2.27774938e-04,  3.92130368e-06,
#          3.59288856e-07,  1.49734716e-04,  1.54719611e-04,
#          9.26838261e-06,  3.76589773e-04],
#        [ 1.13818810e-03, -8.24356028e-07,  2.23138787e-05,
#          8.40271235e-06,  4.99624180e-07,  2.90183984e-05,
#         -3.04018402e-03, -1.01738756e-02]]),
#         array([[ 3.30433563e-03, -1.11088873e-04,  6.40325527e-03,
#          1.69000556e-02,  3.70824040e-03, -8.87027717e-05,
#         -4.03369887e-04],
#        [-1.08090678e-02,  7.71501651e-04, -2.06663840e-02,
#         -5.51556555e-02, -1.21832817e-02,  3.10672170e-04,
#          1.21918504e-03],
#        [ 6.52753354e-03, -5.67172796e-04,  1.97037337e-02,
#          6.89103334e-02,  1.63425542e-02, -3.81839868e-04,
#         -6.08781253e-03],
#        [ 7.45689992e-05, -1.72213643e-05,  1.34414199e-04,
#          3.76789607e-04,  8.55937497e-05, -2.74123353e-06,
#         -5.48619888e-06],
#        [ 4.00903860e-04,  3.31214283e-03,  3.05692357e-03,
#          3.08877516e-03,  1.82669129e-05,  1.56367835e-04,
#         -8.66343651e-04],
#        [-4.29152379e-04, -1.08967443e-03, -1.12886046e-03,
#         -2.93309089e-04,  2.27282425e-04, -5.58896707e-05,
#         -1.51617968e-05],
#        [-1.33659628e-02,  7.31779870e-04, -2.57073906e-02,
#         -6.82721604e-02, -1.50364055e-02,  3.72994181e-04,
#          1.56220412e-03],
#        [-4.99401062e-03,  1.52003969e-04, -4.93443957e-03,
#         -2.31815002e-03,  2.46220858e-04,  9.96862399e-06,
#         -2.89122467e-03],
#        [ 7.86097506e-03, -4.54555771e-04,  1.55108014e-02,
#          4.21390942e-02,  9.34847994e-03, -2.31166223e-04,
#         -1.21362045e-03],
#        [ 1.48007617e-04,  1.80322486e-04,  4.13854405e-04,
#          8.14841498e-04,  1.42048919e-04,  5.33904279e-06,
#         -6.36121970e-05]]),
#         array([-0.01699195, -0.14161477, -0.07957983,  0.00015112,  0.006114  ,
#         0.00448959, -0.07920193, -0.00264254, -0.05285622,  0.00057433])],
#        [array([[ 1.67760881e-03, -2.75346032e-03],
#        [-4.74400678e-04, -3.08741878e-03],
#        [-1.99373462e-03,  5.50921690e-03],
#        [ 8.97762629e-04,  6.25794802e-04],
#        [-1.85124454e-04,  5.27224122e-05],
#        [-4.34510047e-04,  1.86252078e-03],
#        [-1.95978127e-05, -2.04984094e-03],
#        [ 2.35341426e-03,  7.01596679e-04]]),
#         array([[ 5.60759510e-04,  3.42604199e-04,  5.74523733e-04,
#         -2.43779768e-05,  1.70776309e-04,  6.34979457e-04,
#         -5.51135880e-06, -1.52622657e-05],
#        [ 2.54197231e-04,  1.49786414e-03, -3.61023986e-03,
#         -6.55535167e-04, -6.21989256e-04, -2.65413621e-03,
#          3.15056330e-03,  4.83228253e-03],
#        [ 1.37787967e-02,  1.08333204e-02, -8.32256196e-04,
#         -3.57497050e-04,  1.67958633e-05, -3.50189502e-04,
#          1.06288893e-02,  1.62741469e-02],
#        [-3.86687100e-03, -1.62790143e-03, -3.19569513e-03,
#         -6.32535107e-04,  2.10628997e-03, -2.13771636e-03,
#          2.79649406e-04,  5.47772780e-04],
#        [ 2.47031822e-03,  1.09363405e-03,  2.15139146e-03,
#          2.26497562e-03,  3.37081939e-04,  1.60126623e-03,
#          3.09001213e-06,  4.68078535e-04],
#        [ 5.67293400e-03,  3.96542111e-03,  6.49466703e-04,
#          1.88838598e-04, -4.26721346e-03,  3.60214527e-04,
#          2.87377747e-03,  4.20108434e-03],
#        [-4.01457680e-04, -1.19693899e-04, -3.69590684e-04,
#          2.05402695e-03,  7.14668977e-03, -1.89725295e-04,
#          1.04244922e-03,  2.44292751e-03],
#        [ 2.39549188e-03,  9.79098969e-04,  1.97849928e-03,
#          1.66854946e-03, -3.87101026e-03,  1.27233601e-03,
#         -5.30213706e-04, -6.74241901e-04]]),
#         array([[ 2.53573882e-04, -1.35807107e-03, -1.47543782e-03,
#          2.85920367e-04,  2.89426836e-04, -6.76518947e-04,
#         -4.71004624e-03,  3.21206089e-04],
#        [-9.75394995e-05,  1.62525659e-03,  1.71765751e-03,
#         -2.14956241e-04, -3.27622472e-04,  7.49122255e-04,
#          5.56345803e-03, -5.21024219e-04],
#        [ 9.60730319e-05,  1.11895529e-03,  9.40529323e-04,
#          1.62097958e-03,  6.16450899e-04,  1.96500404e-03,
#          4.58899071e-03,  8.66330091e-04],
#        [-2.34946920e-04,  3.71168095e-03,  3.44193452e-03,
#         -2.13453836e-03, -1.14195459e-05,  1.14216902e-03,
#          9.08828048e-03, -9.13312075e-04],
#        [ 4.72821980e-04,  2.93494335e-04,  3.39486298e-05,
#          4.50721881e-04,  6.24557362e-04,  4.22113625e-04,
#          4.96293531e-04,  1.60057336e-04],
#        [-1.18392668e-05, -3.88043483e-05, -2.12403793e-05,
#          7.54845544e-07, -1.26275761e-05, -2.79267753e-05,
#         -3.67064437e-05, -1.03918608e-06],
#        [ 1.39994690e-03,  2.18549189e-03,  7.09052788e-04,
#          3.89014932e-03,  2.55387050e-03,  4.78439598e-03,
#          2.89080648e-03,  1.42818309e-03],
#        [ 7.28860798e-05,  5.46018740e-05,  1.96542340e-05,
#          1.19283058e-03,  1.30727295e-04,  8.40319300e-04,
#          1.05282103e-03,  4.49654009e-04]]),
#         array([[-1.68757388e-03, -2.98339090e-03, -1.03835813e-02,
#         -2.05941092e-03, -1.85764381e-04,  6.14709111e-05,
#         -1.97404198e-04, -2.16191560e-04],
#        [ 1.12864634e-05,  2.66877286e-06, -3.75468177e-04,
#         -4.04069448e-06, -4.22022153e-04,  5.42550920e-06,
#          6.69328024e-06, -7.41667610e-04],
#        [ 2.50021568e-05,  5.39876989e-05, -7.80948036e-04,
#         -5.44294803e-05, -6.11642052e-04,  2.98235784e-06,
#         -4.46522896e-04, -6.07694272e-04],
#        [ 4.91824827e-04, -3.58769799e-04,  1.98903849e-04,
#          2.17670509e-05,  3.83825040e-05, -6.39303114e-06,
#          2.37608612e-04,  8.07359437e-05],
#        [ 1.18080297e-06, -2.79009186e-06,  5.82892314e-05,
#         -1.49015601e-06,  7.54282480e-05, -9.12884946e-07,
#         -7.22428176e-09,  1.32687287e-04],
#        [-1.67768384e-04, -4.55300167e-04, -1.53994403e-03,
#         -3.24731305e-04,  3.65730295e-05,  8.91108257e-06,
#          9.33934527e-06,  6.77210747e-05],
#        [-7.39539155e-04, -4.71521724e-05,  1.28276338e-03,
#          1.31817726e-04,  1.28089923e-03, -8.86269371e-06,
#          5.01871313e-04,  1.45943108e-03],
#        [-3.08445814e-04, -7.39194415e-06,  3.00346595e-04,
#          4.31201090e-05,  2.78482281e-04, -3.79207360e-06,
#         -5.68041734e-05,  4.47412087e-04],
#        [ 1.71713833e-03,  4.78573204e-03,  1.63016508e-02,
#          3.40521120e-03, -1.78603632e-04, -9.71390925e-05,
#         -1.98432514e-04, -2.63189327e-04],
#        [ 5.70192792e-04,  4.59982102e-04,  3.76119607e-05,
#          1.41150574e-06,  1.46260635e-05, -1.26200991e-06,
#          7.19414205e-07,  7.07612022e-05],
#        [-1.23595638e-04, -4.71994414e-05,  2.64186412e-05,
#         -1.39113855e-06,  6.03879272e-05, -2.78305538e-07,
#         -2.25392470e-05,  1.03865342e-04],
#        [ 1.35501335e-04,  6.58587243e-05,  9.74463369e-04,
#          8.96353174e-05,  6.18108092e-04, -4.77082151e-06,
#          4.44305352e-04,  6.43816528e-04],
#        [ 5.07562760e-04,  1.37371403e-03,  4.72904516e-03,
#          9.79781862e-04, -1.61737322e-05, -2.82205198e-05,
#         -3.90207280e-05, -2.75488808e-05],
#        [ 6.69939096e-04,  3.02974279e-03,  1.02814906e-02,
#          2.17614866e-03,  3.73877165e-05, -6.21776582e-05,
#         -1.61418989e-04, -2.07048505e-05],
#        [-2.02841046e-03,  6.12754233e-04,  1.60198920e-03,
#          5.96546145e-04, -6.61198306e-05, -1.37575807e-05,
#         -7.26158865e-04, -1.54247784e-04],
#        [ 1.56735332e-05, -6.98401706e-06, -3.23469740e-05,
#         -7.13173449e-06, -9.55142717e-06,  2.30613210e-07,
#          6.34848632e-07, -1.08017086e-05],
#        [ 1.69871891e-04,  1.38295514e-04,  2.97003008e-04,
#          2.05378473e-05,  2.25325716e-04, -2.50643524e-06,
#          8.67306569e-05,  3.17873716e-04],
#        [ 1.44778318e-03,  4.01632905e-03,  1.33996838e-02,
#          2.86477229e-03, -5.21720403e-04, -7.61652570e-05,
#         -9.82211641e-05, -9.39573523e-04]]),
#         array([[-2.74710356e-04,  1.26072839e-04,  2.04748250e-04,
#         -4.86178627e-05,  5.42591267e-05,  1.04701962e-04,
#         -3.82315333e-04, -3.88889626e-04,  6.78189344e-04,
#          2.89091437e-06, -3.69814227e-04,  6.07142599e-04,
#          9.27876774e-06, -1.06014845e-03, -8.58649880e-04,
#          2.50458826e-06,  5.12393376e-04,  5.76388284e-05],
#        [ 1.19067959e-02,  1.28041884e-04,  8.74776413e-05,
#         -2.48883250e-04,  5.06059300e-05,  4.75922144e-03,
#          2.49380029e-04,  3.52452707e-04,  2.19075234e-03,
#         -1.27846083e-04, -1.03149706e-05,  4.29467517e-04,
#          5.74514482e-03,  1.04031853e-02,  1.97707777e-03,
#         -3.44617168e-05,  2.24961033e-04,  5.56055294e-03],
#        [ 1.47326740e-03,  7.73729279e-05,  1.35277128e-04,
#         -3.38484707e-05,  2.77500428e-05,  5.79770966e-04,
#          3.30010384e-04,  4.09174065e-04,  6.93686784e-04,
#         -1.59040720e-05,  1.44304393e-05,  6.68441827e-04,
#          6.25031407e-04,  1.18940074e-03,  2.23929426e-04,
#         -7.69807889e-06,  3.41123538e-04,  6.29681201e-04],
#        [ 1.65234414e-04,  3.32214581e-04,  5.72597714e-04,
#         -7.57989435e-05,  1.30739246e-04,  3.23095622e-04,
#          3.27984701e-04,  5.16393507e-04,  1.98229591e-03,
#         -1.93434737e-06, -3.99582914e-04,  2.29838301e-03,
#          3.74650959e-05, -1.08420995e-03, -9.98122009e-04,
#         -6.65847753e-06,  1.42865533e-03,  1.64801181e-04],
#        [-6.26383806e-04,  2.21458753e-05,  1.52956706e-05,
#         -4.09330934e-05,  1.72141768e-05, -1.92048423e-05,
#         -9.04812545e-04, -1.03495374e-03, -6.45396922e-06,
#          6.71950142e-06, -4.25553806e-04, -3.31498102e-04,
#         -1.64343189e-05, -1.27647267e-03, -9.47489449e-04,
#          8.81487822e-06,  4.09049559e-05, -7.47520310e-06],
#        [-6.04213679e-05, -1.04013998e-07,  2.40842592e-07,
#          1.68481062e-06, -9.33859686e-08, -2.55002029e-05,
#          7.73921826e-06,  9.08467625e-06, -9.57459497e-06,
#          6.51206913e-07,  3.58889576e-06,  3.35683388e-06,
#         -3.17396561e-05, -4.75112336e-05, -3.46591203e-06,
#          1.12272852e-07,  3.50638258e-07, -3.04853867e-05],
#        [-6.26539297e-03, -5.37503233e-05, -7.56144958e-05,
#          1.32308513e-04, -1.78265622e-05, -2.45729772e-03,
#         -2.18029107e-04, -2.55580427e-04, -1.28860323e-03,
#          6.75266896e-05,  1.83216020e-06, -4.60514937e-04,
#         -2.97948017e-03, -5.44487275e-03, -1.04160776e-03,
#          2.02859830e-05, -2.09322824e-04, -2.87909212e-03],
#        [-4.04996551e-03, -6.44553431e-05, -1.05539391e-04,
#         -4.11700410e-05, -2.12663539e-05, -1.56143068e-03,
#         -3.56515701e-04, -4.44546882e-04, -1.01822553e-03,
#          4.30324811e-05, -1.29932295e-04, -6.13552795e-04,
#         -1.85159001e-03, -3.53554496e-03, -7.62281979e-04,
#          1.50504176e-05, -2.82208513e-04, -1.80153861e-03]]),
#         array([[-1.01213478e-04,  8.07443264e-03,  3.58003100e-03,
#         -1.43559347e-05, -9.48653666e-05, -1.17877280e-05,
#          5.29669808e-03,  3.40182412e-03],
#        [ 1.55662522e-04,  5.91338956e-04,  9.39684403e-04,
#          3.20692223e-04, -1.35594269e-05, -2.50695044e-06,
#          4.47950924e-04,  3.47188694e-04],
#        [-1.50106495e-08, -5.49035083e-04, -2.31157719e-04,
#         -1.66980987e-05, -1.32569803e-06,  8.00748003e-07,
#         -3.53486999e-04, -2.26640847e-04],
#        [-1.43500349e-07,  9.69045571e-05,  5.18944051e-05,
#          1.49620465e-06, -2.06350431e-06, -1.59958824e-07,
#          6.49701566e-05,  4.24358499e-05],
#        [-2.34280229e-04, -7.11166039e-05, -9.81619507e-04,
#         -4.66538610e-04,  5.06861185e-06,  2.42789730e-06,
#         -1.27176511e-04, -1.65560334e-04],
#        [-6.41456802e-05, -5.04239416e-04, -4.91656102e-04,
#         -1.40582810e-04,  3.92611290e-06,  1.40400744e-06,
#         -3.51166594e-04, -2.49494538e-04],
#        [-2.32883794e-03, -9.60425485e-03, -3.17104914e-03,
#         -5.93417184e-03, -2.00472798e-03,  1.93624696e-05,
#         -4.66736194e-03, -3.09208084e-03],
#        [ 7.32260324e-05,  5.78438409e-04,  2.58191666e-03,
#         -4.00712201e-05, -4.01977195e-04, -5.07555231e-06,
#          8.57174644e-04,  7.21143361e-04]]),
#         array([[-6.06895612e-02,  7.79581424e-04,  1.72853131e-04,
#          1.84252374e-04,  1.03784011e-03,  5.70401953e-04,
#         -2.82220270e-03, -3.54397762e-03],
#        [ 3.70787051e-04, -1.86256581e-03,  5.96814631e-06,
#          1.98108847e-06, -1.16345068e-03, -1.33094457e-03,
#          7.97549205e-05, -2.80384932e-03],
#        [-9.33144254e-03,  3.05693596e-03,  3.59109892e-05,
#          3.04011889e-05,  1.99568497e-03,  2.20284566e-03,
#         -2.81887002e-03, -3.74432296e-03],
#        [ 1.93801220e-02,  3.96030326e-04, -5.66487924e-05,
#         -5.95789499e-05,  7.06277220e-05,  2.79505804e-04,
#          7.69078416e-04,  1.74228718e-03],
#        [-6.35277457e-02,  4.10075099e-04,  1.69726606e-04,
#          1.89193633e-04,  8.29290537e-04,  2.96706408e-04,
#         -1.51495097e-03,  4.53453634e-04],
#        [-2.23495664e-04,  2.17585932e-04, -3.25737638e-07,
#          2.68055493e-07,  1.37504606e-04,  1.55399777e-04,
#         -7.87684667e-07,  3.69944827e-04],
#        [ 2.56945113e-04,  9.02158282e-06,  2.64179206e-05,
#          8.49087385e-06,  1.23179423e-05,  2.83611335e-05,
#         -3.03046654e-03, -1.01674544e-02]]),
#         array([[ 2.14345407e-03,  3.93516750e-05,  1.90642736e-03,
#          3.67212854e-03,  2.49008683e-03, -1.71382410e-05,
#         -9.53332913e-05],
#        [-6.99568711e-03,  2.77319385e-04, -5.89475074e-03,
#         -1.17032285e-02, -8.18176811e-03,  7.55897917e-05,
#          2.07315401e-04],
#        [ 1.44107798e-03,  9.19893340e-05,  6.76897970e-07,
#          1.09515673e-02,  1.10051587e-02, -6.82766101e-05,
#         -4.73813613e-03],
#        [ 4.77969640e-05, -1.37519323e-05,  3.07091881e-05,
#          7.17296088e-05,  5.75009180e-05, -1.09082561e-06,
#          1.61768392e-06],
#        [ 3.89878946e-04,  3.31357156e-03,  3.01421711e-03,
#          2.96314929e-03,  6.69808525e-06,  1.57047485e-04,
#         -8.63418222e-04],
#        [-4.96707983e-04, -1.08091979e-03, -1.39054600e-03,
#         -1.06308667e-03,  1.56393970e-04, -5.17250898e-05,
#          2.76388917e-06],
#        [-8.65919812e-03,  1.21822508e-04, -7.47511668e-03,
#         -1.46398680e-02, -1.00974330e-02,  8.28376191e-05,
#          3.13277611e-04],
#        [-5.05209584e-03,  1.59531329e-04, -5.15944035e-03,
#         -2.98001520e-03,  1.85270004e-04,  1.35493870e-05,
#         -2.87581192e-03],
#        [ 4.93632240e-03, -7.55452289e-05,  4.18177340e-03,
#          8.81347922e-03,  6.27953974e-03, -5.08710048e-05,
#         -4.37572243e-04],
#        [ 1.03242892e-04,  1.86123620e-04,  2.40452338e-04,
#          3.04759741e-04,  9.50757298e-05,  8.09864083e-06,
#         -5.17340057e-05]]),
#         array([-4.53095209e-03, -3.27889686e-02, -1.29818188e-02,  1.18757548e-05,
#         5.72392213e-03,  4.27444233e-03, -5.51611340e-02, -2.77010245e-03,
#        -7.49604913e-03,  3.74699404e-05])]], dtype=object)

# %%
np.array(sumMat(Wup)).shape
# Out:
# (9,)

# %%
eta/np.sqrt(aiw+e)*fiw
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'numpy.ndarray' object has no attribute 'sqrt'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-fb5845440327> in <module>()
# ----> 1 eta/np.sqrt(aiw+e)*fiw
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.ndarray which has no callable sqrt method

# %%
W-eta/((aiw+e)**0.5)*fiw
# Out:
# array([array([[ 0.25670841,  1.21915919],
#        [-0.16521535,  0.43078249],
#        [-0.07432152,  0.94397395],
#        [ 0.9831271 ,  0.24916661],
#        [-1.28507538, -0.75526198],
#        [-0.70441089,  0.44388504],
#        [-0.08101202, -0.14619009],
#        [ 0.06448053, -0.40680051]]),
#        array([[-0.41356989,  0.18559468,  0.45007143, -0.4296167 , -1.02434911,
#         -0.4246777 ,  0.78119928,  0.40530359],
#        [-0.3950334 ,  0.32134968, -0.47634634, -0.49526424, -0.89743378,
#          0.45169104,  0.63893848,  0.19790901],
#        [-0.45786957,  0.05350962,  0.35121109, -0.15063211, -0.1387787 ,
#         -0.01509453,  0.07819864, -0.39848352],
#        [ 0.23183306,  0.09296214, -0.38067721, -0.44838957,  0.4015864 ,
#         -1.37927252, -0.4052643 , -0.31927431],
#        [-0.7513493 , -0.08107338,  0.39288411, -0.13482683, -0.26899096,
#         -0.27243762, -0.18951398,  0.92824289],
#        [-0.50878851, -0.42377171, -0.19788637, -0.40075865,  0.179344  ,
#         -0.41106243,  0.23612396, -0.13250556],
#        [ 0.1445803 , -0.42367759, -0.86555793,  0.21654348,  0.04273952,
#          0.08134526,  1.31404496, -0.14960273],
#        [-1.05781094, -0.06516913,  0.71136931,  0.15607657,  0.12800781,
#          0.1940915 , -0.1433177 , -0.07362128]]),
#        array([[ 0.51677171, -0.39329893,  0.15460853,  0.08840472,  0.17487886,
#         -0.70645295, -0.54064466,  0.2614769 ],
#        [-0.16241982, -0.33831995, -0.83189812, -0.36335466, -0.46966839,
#          0.1805762 , -0.68542273, -0.58923088],
#        [ 0.39615779, -0.61060546, -0.45525475,  0.99289604,  0.68038776,
#         -0.72321091,  0.57858151, -0.47782064],
#        [ 1.08201135,  0.73175001, -0.56674147,  0.26655136,  0.10142943,
#          0.03694281, -0.21036786,  0.0286786 ],
#        [-0.39056016,  1.05944145,  0.40405491,  0.0117366 , -0.27222613,
#         -0.03856291, -0.02201139,  1.34355269],
#        [-0.612028  , -0.15219963, -0.50831053,  0.45630896, -0.29427863,
#         -0.24593626, -0.18810332, -0.80488486],
#        [-0.21640829,  0.97242257,  0.10531631,  0.78345967, -0.78421027,
#          0.00603425, -0.02540793, -0.85130688],
#        [-0.91457966,  0.75445014,  0.41871999, -0.25452876,  0.62715354,
#         -0.24438553,  0.78864552,  0.28737531]]),
#        array([[-0.0258862 ,  0.01872408,  0.03794761, -0.22774141, -0.05667019,
#         -0.33851856,  0.47185807,  0.15947065],
#        [-0.74973986,  0.66289011, -0.18425303, -0.53775941, -0.03848584,
#         -0.59065421,  0.20608733,  0.40567327],
#        [-0.4787547 , -0.39668032, -0.48638231,  0.38701227,  0.27757458,
#         -0.22224369,  0.57872087,  0.34704612],
#        [ 0.50471984, -0.06605629, -0.85116325, -0.45468582, -0.60990741,
#         -0.95023776, -0.74454693,  0.27010419],
#        [-0.70753504,  0.24434791, -0.26642191, -0.72050208, -0.55011247,
#          0.10716916, -1.21305649,  0.53072568],
#        [ 0.04695402, -0.41249642, -0.28185756,  0.63585996,  0.32011521,
#         -0.17513884, -0.2276357 ,  0.17896982],
#        [ 0.12475706, -0.28564962,  0.21036409, -0.81610259, -0.2807822 ,
#         -0.06436643,  0.30477048,  0.60393006],
#        [ 0.30808887, -0.35130842,  0.38424944, -0.33310711,  0.04324226,
#          0.28207781, -0.43185135,  0.61151403],
#        [ 0.2389592 , -0.72789633,  0.4021097 ,  1.36930492,  0.15503848,
#          0.53628453, -0.14102814,  0.44832871],
#        [ 0.04214603, -0.01338924, -0.53898001, -0.03642217,  0.20645067,
#          0.37958153, -0.04238805,  0.06096737],
#        [ 0.43904385, -0.20836279, -0.54596284, -0.78977373, -0.55583508,
#          0.32902449,  0.42544629,  0.62664636],
#        [-0.45138389,  0.60769598,  0.38322763, -0.04374527,  0.30674245,
#          1.07887954,  0.51658526,  0.50428009],
#        [-0.56366148, -0.30401166, -0.25403936,  0.01671446, -0.05324274,
#         -0.72376269, -0.1085786 , -0.2494616 ],
#        [ 0.64064148, -0.95759752, -0.21618069,  0.23167723,  0.38457098,
#          0.53415434,  0.2821008 , -0.28399243],
#        [ 0.19010662, -0.22328174, -0.07488437,  0.18921512, -1.0929856 ,
#         -0.12207001,  1.16086658, -0.30924959],
#        [-0.15602   ,  0.0165852 , -0.57919564, -0.43274933, -0.33394284,
#         -0.13970131, -0.32874499,  0.287255  ],
#        [-0.6330007 ,  0.84927038,  0.0806636 , -0.45736325,  0.43663   ,
#         -0.31389437,  0.15483684,  0.277733  ],
#        [-0.63322459,  0.16604945, -0.17296667, -0.10763338, -0.83417878,
#          0.04166795,  0.13899448,  0.69002597]]),
#        array([[ 3.80224256e-01, -1.77066542e-01, -4.43441154e-01,
#         -1.78224591e-01,  4.10409209e-03,  2.22551568e-01,
#          2.38705216e-01, -1.88762290e-01,  1.10117202e-01,
#          1.69105942e-01,  1.65131918e-01,  7.95482468e-02,
#         -2.50131231e-01,  2.62986044e-01,  5.74332865e-01,
#         -4.74641950e-01,  1.34677316e-01,  7.71033158e-02],
#        [-7.40735735e-04, -6.60643698e-01,  6.40468910e-01,
#         -5.84917018e-01,  1.29443440e-01,  2.94346820e-01,
#         -1.33659622e-01,  7.48378274e-01, -1.02395266e-01,
#          6.72656854e-02,  2.13991909e-01, -4.93883005e-01,
#          6.87903827e-01,  3.43526228e-01, -1.83506258e-01,
#         -1.20019177e-01,  2.13628280e-01, -6.72821145e-01],
#        [ 1.72409236e-02,  3.17624465e-01, -8.14743262e-02,
#         -9.16029941e-02, -2.34377519e-01,  7.66854655e-01,
#          2.81782586e-01,  2.33297644e-01,  2.42891039e-01,
#          2.51102760e-01, -2.65555212e-01,  5.63804531e-01,
#         -3.73498109e-01, -3.97308254e-01, -6.80192336e-01,
#         -4.76453754e-01,  9.19158182e-02, -2.92882750e-01],
#        [-8.98086467e-02, -4.57818892e-01, -2.21400995e-01,
#         -4.60865575e-01,  7.33790967e-02, -2.01179015e-01,
#          5.44679895e-01,  7.30065225e-02, -3.94370928e-02,
#          4.15724702e-01,  3.06597680e-02,  2.40919247e-01,
#         -6.11712140e-01,  4.68985244e-02,  3.34929264e-01,
#         -4.77145611e-01,  1.39771678e-01, -3.91563488e-01],
#        [ 6.60644463e-02, -4.84965036e-02,  3.41586542e-01,
#         -2.84359979e-01, -1.75020820e-01,  2.73889298e-01,
#         -2.41193603e-01,  2.37614163e-01, -1.05339361e-01,
#         -2.12890119e-01, -1.63854523e-01, -3.15597263e-01,
#         -1.93783753e-01,  1.85675760e-02,  5.93129024e-01,
#         -3.01431934e-01, -1.66806118e-01, -2.30529232e-01],
#        [ 3.62936809e-01,  4.07700644e-01, -7.99119498e-01,
#         -6.28239765e-01, -3.05337770e-02,  2.55066960e-01,
#          2.10571264e-01, -2.94361190e-01,  2.83854239e-01,
#         -1.93658656e-01,  2.50601087e-01, -2.12531887e-01,
#          2.95795080e-01, -5.84941333e-01,  1.63381083e-01,
#         -1.27846035e-01, -3.01299282e-01, -5.38086113e-01],
#        [ 1.19615748e-01, -3.09823617e-02,  2.92060447e-01,
#          1.25765714e-01,  1.12088733e-01,  4.22870373e-01,
#         -6.30577365e-01, -1.31472670e-01,  5.94381285e-01,
#         -8.65325364e-02, -2.37859937e-01,  2.22101115e-02,
#          7.51473433e-01,  7.68701100e-02,  1.88737706e-01,
#         -5.85359860e-01, -1.07601957e-01,  1.67698358e-01],
#        [ 6.37470107e-01, -5.50724904e-01,  3.27859725e-01,
#          1.43127903e-01, -2.51222799e-01,  3.01542853e-01,
#         -2.61143000e-01,  2.32714537e-01,  1.85411017e-01,
#          2.59094443e-01,  2.97239096e-01, -3.98508448e-01,
#          1.10893888e-01, -2.08064059e-01,  5.22990653e-01,
#         -1.29333502e-01,  5.71569559e-01, -1.80516813e-01]]),
#        array([[ 0.05372302,  0.7037362 , -0.20255082, -0.91739505, -0.60929959,
#         -0.04734241, -0.29979604,  0.79009626],
#        [ 0.52011043, -0.33356327,  0.48788338,  0.19644306, -0.21588166,
#          0.21666279,  0.01858955,  0.50714565],
#        [-0.09576544,  0.5138955 , -0.14282811, -0.61295444, -0.71173263,
#         -0.42968241,  0.30040121,  0.37138414],
#        [-0.22465387,  0.87270088, -0.0694901 , -0.14711832, -1.24450494,
#         -0.45678329, -0.16853208, -0.04726584],
#        [ 0.38453259,  0.13430074,  0.42117684,  0.03726426, -0.33645598,
#         -0.32015496, -0.1582842 , -0.12243108],
#        [ 0.47968052, -0.77516705,  0.77081692, -0.44686452,  0.02954984,
#         -0.1420252 , -0.1672973 , -0.30136336],
#        [ 0.36853066, -0.09716339, -0.47363857,  0.31803441,  0.4758779 ,
#         -0.3798815 , -0.03828588,  0.2367297 ],
#        [ 0.53677115,  0.63279733,  0.46825572,  1.24682254,  0.2174512 ,
#         -0.20185116, -0.34100701, -0.54499276]]),
#        array([[ 0.41580015, -0.21868589,  0.9905854 ,  0.38865855, -0.25978621,
#          0.37913201,  0.19611428,  0.40446788],
#        [ 0.34139154,  0.97915715,  0.39322115, -0.00715344,  0.91590391,
#          0.23655967,  0.71661528, -0.37467258],
#        [-0.37912891,  0.8177486 ,  0.35772103, -0.00291695,  0.28370083,
#         -0.16941146,  0.12675648,  0.23289363],
#        [-0.05109178, -0.12624267, -0.11300567,  0.93040291,  0.34133861,
#          1.24745479,  0.67471072,  0.1016596 ],
#        [-0.0273573 , -0.11467663, -0.44810884,  0.54600829,  0.44094736,
#         -0.37630596, -0.17129658, -0.57488761],
#        [ 0.37073228,  0.13532991,  0.32284602, -0.06527218,  0.30294684,
#         -0.27487138, -0.21326766, -0.05477588],
#        [-0.07300472, -0.26264401, -0.25004996, -0.02705573, -0.22591554,
#          0.27826516,  1.2396515 , -0.12785204]]),
#        array([[ 0.25139787, -0.22631228, -0.52394149, -0.726009  ,  0.47963339,
#         -0.81859187,  0.48505453],
#        [ 0.42122819, -0.03938975, -0.61908926, -1.18121661, -0.62890394,
#         -1.22599846, -0.76386174],
#        [ 0.05295533, -0.91533509,  0.17990932,  0.18035913,  0.63211909,
#          0.36702877,  0.54324668],
#        [-0.2080653 ,  0.35739659, -0.73877694,  0.16092626,  0.04412903,
#          0.2832944 , -0.14815669],
#        [ 0.00437828, -0.41465161,  0.82860041,  0.48163623, -0.51975362,
#          0.37728907,  0.07561648],
#        [-0.17729189,  0.03485966, -0.19203217,  0.69790618, -0.30852537,
#          0.70303052,  0.0572794 ],
#        [-0.4925996 ,  0.02053777, -1.18412417,  0.41338096,  0.79139439,
#         -0.28719242, -0.07226214],
#        [ 0.37954473, -0.66265675,  0.3777619 , -0.43724393, -0.34307489,
#         -0.71445616,  0.04621517],
#        [-0.00591576, -0.37244609, -0.14957201, -0.68806728,  0.7643456 ,
#         -1.25514528,  1.57085188],
#        [ 0.02216795, -0.78370235,  0.00494711, -0.24258763, -0.04632548,
#          0.04147277, -0.14767533]]),
#        array([ 0.87326308,  1.87607525,  2.00645585, -0.15092659,  0.3861128 ,
#        -0.12690557, -0.25711644,  1.30791545,  0.11235944,  2.18792003])],
#       dtype=object)

# %%
#df.iloc[:,:2]
#for row in df.iloc[np.where(df[2]==0)].iloc[:,:2]:
#df2=df.iloc[np.where(df[2]==0)].iloc[:,:2]
#test=df[:thresh]

#agg=[]
# for row in test0.iterrows():
#   x1=row[1][0]; x2=row[1][1]
#   print(forward2(W, B, [[x1,x2]])[0][-1])


def testAcuracy(test, W, B):

  test0=test.iloc[np.where(test[2]==0)]
  test1=test.iloc[np.where(test[2]==1)]


  pred0=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]
  pred1=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]

  mp0=np.mean(pred0)+2*np.std(pred0)
  mp1=np.mean(pred1)-0.5*np.std(pred1)
  
  
  acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp1)/len(pred1)))/2

  mp=np.array(0.85)

  acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp0)/len(pred1)))/2



  return acc
  
  
  #print(forward2(W, B, [[x1,x2]])[0][-1])

#forward2(W, B, [[8,8]])[0][-1]

# %%
1-np.log(1/(1-An))
-1*((y*(np.log(1/An))+(1-y)*((1-np.log(1/(1-An)))))) 

mp0=np.array(.95)
mp1=np.array(.65)
#sum(pred0<mp0)
#len(pred1)

testAcuracy(test,W,B)
# Out:
# 0.9676874076232904

# %%
test0=test.iloc[np.where(test[2]==0)]
test1=test.iloc[np.where(test[2]==1)]


pred0=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]
pred1=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]

mp0=np.mean(pred0)+2.5*np.std(pred0)

mp1=np.mean(pred1)#-1.5*np.std(pred1)

#mp0=np.array(.85)
acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp1)/len(pred1)))/2
acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp0)/len(pred1)))/2
acc
#testAcuracy(test)
# sum(pred0<=mp0)/len(pred0)
# sum(pred1>=mp0)/len(pred1)
# Out:
# 0.974004413264775

# %%
plt.hist([pred1,pred0])
plt.axvline(mp0, 0, 1, label='pyplot vertical line')
plt.axvline(mp1, 0, 1, label='pyplot vertical line')
np.mean(pred0)
# Out:
# 0.655340569692142

# %%
mp0=np.mean(pred0)
mp1=np.mean(pred1)

#np.mean(pred0)#+np.std(pred0)
#np.median(pred1)-np.std(pred1)
sum(pred0>=mp0)/len(pred0)
#sum(pred1>=mp0)/len(pred1)
-np.log(mp1)
-np.log(pred0)

# %%
#mp0=np.mean(pred0)+2.5*np.std(pred0)
#sum(pred0<=mp0)/len(pred0)
mp1
testAcuracy(test,W,B)
# Out:
# 0.9393872277593207

# %%
#mp1=np.mean(pred1)-2.5*np.std(pred1)
#sum(pred1>=mp1)/len(pred1)
pred1
np.mean(pred1)-2.5*np.std(pred1)
sum(pred0<=mp0)/len(pred0)
sum(pred1>=mp1)/len(pred1)
((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp1)/len(pred1)))/2
# Out:
# 0.9463660961490058

# %%
np.mean(pred1)-2.5*np.std(pred1)
np.mean(pred0)+2.5*np.std(pred0)
# Out:
# 0.8702642152238127

# %%
test1.iloc[:,:2]
# Out:
#               0          1
# 0     -1.572586   9.456758
# 1    -13.153614  10.585119
# 2    -15.375017  -5.332812
# 3    -13.011498  10.123971
# 4     -9.004814 -13.965195
# ...         ...        ...
# 1828   0.669163  -0.412784
# 1829 -13.766481  -8.964978
# 1830  -1.059057   9.551282
# 1831  15.084860  -8.872088
# 1832  -2.022924   0.294973
#
# [1373 rows x 2 columns]

# %%
def normalize(a,b):
  res=(a - min(b)) / ( max(b) - min(b) )

  return res

# %%
#Loss[~np.isnan(Loss)]
np.nanmean
# Out:
# <function numpy.nanmean>

# %%
N
# Out:
# [2, 80, 52, 40, 17]

# %%
W=[([[-0.53666105, -0.53579372],
        [-1.19712349,  0.32678271],
        [ 1.03608261, -0.75358774],
        [-0.00931657, -0.00218147],
        [ 0.71620007, -0.15213732],
        [-1.72005796,  1.7488977 ],
        [ 0.26172566, -1.22377013]]),
 ([-0.77196721,  0.41079926, -0.07902365, -1.53676624,  0.15160013,
         0.05588476,  0.46094505])]
B= [([ 473.6134765 ,   -8.51873646,   -6.12254349,   78.14056371,
         -5.09917034,   -6.18954292,    5.73742657])]

# %%
0.53666105+ 0.01090818
# Out:
# 0.54756923

# %%
#Wa,Ba=update2(Wup,Bup, W, B)
print("Wa=",Wa)
# Out:
# Wa= [array([[-0.54756923, -0.54507226],
#        [-1.1910333 ,  0.33196306],
#        [ 1.0381697 , -0.75192554],
#        [-0.00931657, -0.00218147],
#        [ 0.71047067, -0.15691535],
#        [-1.71994285,  1.74876742],
#        [ 0.2685241 , -1.21801534]]), array([-0.78481259,  0.39777004, -0.09216963, -1.53676624,  0.13152498,
#         0.04955998,  0.44995559])]

# %%
N=[2,8]
Wupx=[]; Bupx=[]
W,B=generateWandB(N)

A,I=forward2(W,B,[[1,2]])
for i in lw:
  Wupx.append(backward2(W,A,I,X, y, eta,k=i)[0])
for i in lb:
  Bupx.append(backward2(W,A,I,X, y, eta,k=i)[1])

# %%
sumMat(Wupx)
#a=[]
sumMat(a)
# Out:
# [array([[-0.47584519,  3.21011604],
#         [-1.55772484, -2.91079209],
#         [ 2.07223403,  2.49687171],
#         [ 0.69894641, -2.84037206],
#         [ 0.93667328,  2.08229861],
#         [ 3.12316908, -3.1305517 ],
#         [-1.31614699,  0.81718305],
#         [ 2.30658177, -1.22444818]]),
#  array([ 1.35875968,  3.50496053, -0.28271224,  1.22416366,  0.30820082,
#          3.65323422, -1.22485323,  0.45678918])]

# %%
i=1
np.dot(W[i],A[i-1])==np.dot(A[i-1],W[i])
# Out:
# True

# %%
A
# Out:
# [array([0.0578546 , 4.05309956, 1.08946277, 0.21658867, 0.        ,
#         0.49942415, 3.35685041, 0.05366979]), 0.0005960675703298483]

# %%
I
# Out:
# [array([ 1.98418772, 11.31557956,  5.54535927, 11.13685615, -5.25574083,
#         -3.66530172,  1.25343529]), 3.48354621382529]

# %%
A
# Out:
# [array([4.4189709 , 0.        , 9.16243825, 0.        , 2.29722941,
#         7.11538818, 0.        ])]

# %%
i=0
n=1
n-i
#np.array([0 if e==0 else 1 for e in A[n-i] ])  
n-
# Out:
# 1

# %%
n=len(N)-1

# %%
for i in range(0):
  print(i)

# %%
W2= [([[  5.17962104,  55.32601734],
       [  7.12644327,   0.40215257],
       [ -4.18731366,  18.18822724],
       [ 12.38295856,   3.74009811],
       [         float('nan'),          float('nan')],
       [ 15.03125264,   5.62789978],
       [ -7.38068363, -23.927293  ],
       [  3.52038849,  -6.73506455],
       [ -3.85261355,  -7.2477493 ],
       [ -0.48533834, -11.42604759],
       [-31.39707354,  -8.15871285],
       [         float('nan'),          float('nan')]]), ([ 4.83440445e+01, -6.78489918e+01,  1.64341689e+01, -6.44509734e+01,
       -3.79068927e+01, -6.07105530e+01, -2.70925282e+01, -1.75164434e+01,
       -5.20448097e+00, -8.60342158e+00, -2.01139530e+01,  2.31933166e-02])]
# [np.isnan(W2[i][j]).all() for i in range(len(W2)) for j in range(len(W2[i]))]
# [np.array(W2[i]).reshape(1,-1) for i in range(len(W2))]
#mask = np.isnan(np.array(W2))
#np.where(~np.isnan(W2))
W2[0]=np.array(W2[0])
#np.random.normal(0, 1, n)
W2=[np.array(m) for m in W2]
for i in range(len(W2)):
  W2[i][[np.isnan(np.array(m)) for m in W2][i]]=np.random.normal(0, 1, 1)

W2

#data[mask] = np.interp(np.flatnonzero(mask), np.flatnonzero(~mask), data[~mask])
# Out:
# [array([[  5.17962104,  55.32601734],
#         [  7.12644327,   0.40215257],
#         [ -4.18731366,  18.18822724],
#         [ 12.38295856,   3.74009811],
#         [  1.58058491,   1.58058491],
#         [ 15.03125264,   5.62789978],
#         [ -7.38068363, -23.927293  ],
#         [  3.52038849,  -6.73506455],
#         [ -3.85261355,  -7.2477493 ],
#         [ -0.48533834, -11.42604759],
#         [-31.39707354,  -8.15871285],
#         [  1.58058491,   1.58058491]]),
#  array([ 4.83440445e+01, -6.78489918e+01,  1.64341689e+01, -6.44509734e+01,
#         -3.79068927e+01, -6.07105530e+01, -2.70925282e+01, -1.75164434e+01,
#         -5.20448097e+00, -8.60342158e+00, -2.01139530e+01,  2.31933166e-02])]

# %%
W
# Out:
# [array([[ 0.50249191,  1.07612011],
#         [-0.03024765,  0.05618928],
#         [ 0.41401701,  0.85937095],
#         [ 0.47082558,  0.880133  ],
#         [-1.91532779,  2.75324428],
#         [ 0.31773293,  0.62363629],
#         [-0.44047427, -0.17779913]]),
#  array([-0.9774981 , -3.10955673, -2.56058225, -2.35661475,  2.61793388,
#         -0.31744641, -1.75989496])]

# %%
W= [([[ 5.25690102e+01, -2.99017938e+02],
       [-3.93124362e-01,  3.74232614e+00],
       [ 3.55535850e-01,  2.98175079e+00],
       [-7.33530260e-01, -3.99309186e+01],
       [ 1.56215513e+00, -7.55701781e+00],
       [ 1.25519994e+00,  6.26572120e+00],
       [-3.89350967e+00, -1.14012696e+01],
       [-1.92453636e+01, -6.15222912e+00],
       [-3.52942322e+00, -1.99839083e+00],
       [ 6.49105427e+01, -3.96102811e+02],
       [-3.52485643e+01,  1.75726881e+02],
       [ 2.90790726e-01, -5.41969682e+00]]), ([ 91.66921954,   9.59869369,   8.40171912,  18.30586395,
        12.02739338,  12.74332438, 332.19986084,   9.40837568,
        10.48705351,  76.56089432, 271.51414078,  11.13278863])]
B= [([ 473.6134765 ,   -8.51873646,   -6.12254349,   78.14056371,
         -5.09917034,   -6.18954292,    5.73742657,  -15.66589371,
        -10.1384674 ,  631.24745678, -302.34998825,   28.17929415])]
I= [([ 3043.62500887,   -40.89621579,   -32.45714999,   427.57099049,
          59.66448883,   -61.93622393,   108.46889347,    53.54561206,
          10.1558277 ,  4039.48609115, -1809.19515638,    75.29270394]), 561.7910424459094]
A= [([1.00000000e+00, 1.73380061e-18, 8.01749805e-15, 1.00000000e+00,
       1.00000000e+00, 1.26310576e-27, 1.00000000e+00, 1.00000000e+00,
       9.99961152e-01, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00])]
X= [[(-0.80356713), (-8.73611222)]]

W,B=update2(Wup,Bup, W, B)
# Wupx=[]; Bupx=[]
# lw=list(range(len(W)))[::-1]
#        #lb=list(range(len(W)-1))[::-1]
# lb=lw[:len(lw)-1]
# for i in lw:
#   Wupx.append(backward2(W,A,I,X, y, eta,k=i)[0])
# for i in lb:
#   Bupx.append(backward2(W,A,I,X, y, eta,k=i)[1])        

# [np.array(W[i]) for i in range(len(W))]
# update2(W,B, wx, bx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-305-e1c2b2e40b48> in update2(Wup, Bup, W, B)
#       5   try:
# ----> 6     W=[W[i]-Wup[i] for i in range(len(W))]
#       7     B=[B[i]-Bup[i] for i in range(len(B))]
#
# <ipython-input-305-e1c2b2e40b48> in <listcomp>(.0)
#       5   try:
# ----> 6     W=[W[i]-Wup[i] for i in range(len(W))]
#       7     B=[B[i]-Bup[i] for i in range(len(B))]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-348-be733350bc85> in <module>()
#      24 X= [[(-0.80356713), (-8.73611222)]]
#      25
# ---> 26 W,B=update2(Wup,Bup, W, B)
#      27 # Wupx=[]; Bupx=[]
#      28 # lw=list(range(len(W)))[::-1]
#
# <ipython-input-305-e1c2b2e40b48> in update2(Wup, Bup, W, B)
#      10     #B=B-Bup #eta*dE_dO2*dO2_dO1*dO1_dB
#      11   except:
# ---> 12     W=WC; B=BC
#      13
#      14
#
# NameError: name 'BC' is not defined

# %%
a=sigmoid(-10000e-19)
a
# Out:
# 0.4999999999999998

# %%
W= [([[  3.50379596,   0.1833965 ],
       [  0.90225437,  -2.97565262],
       [-29.07891312,  99.36081975],
       [  6.12780972,   9.62438371],
       [  0.48351167,  -2.94907987],
       [  0.19648614,  -3.01878483],
       [  1.92964851,  -1.49532292],
       [-10.30542027,  -5.50825516],
       [ -4.6026333 ,  -0.15679252],
       [  2.73696337,  -3.41366433],
       [ -0.60866238,  -1.08640186],
       [  0.91071083,  -1.62541488]]), ([-7.82090756e+00, -7.36352318e+00,  2.47974678e+02, -1.81165912e+01,
       -8.94466258e+00, -1.13621301e+01, -7.86586793e+00, -8.83142682e+00,
       -5.22907589e+00,  1.62162621e-01, -2.01987375e+01, -8.21909915e+00])]

# %%
#A=np.array(A); B=np.array(B); W=np.array(W); I=np.array(I); X=np.array(X)
i=1
backward2(W,A,I,X, y, eta,k=i)[0]
# np.array(W)
# W
# np.array(generateWandB(N)[0])
# Out:
# [-16.21569346, -5.22802748, -115.88039638, -51.82676648, -4.36298027, -3.87752154, -9.36454643, 15.97468127, -11.6125263, -7.32924219, -8.72890355, -5.11458211]
# array([[ 2.33934947e-07,  4.04624960e-07],
#        [ 1.28872321e-02,  2.22903668e-02],
#        [-3.85846750e-49, -6.67378808e-49],
#        [ 1.85447938e-22,  3.20759533e-22],
#        [ 3.66415376e-02,  6.33769383e-02],
#        [ 7.44560133e-02,  1.28782646e-01],
#        [ 2.22292898e-04,  3.84488321e-04],
#        [ 3.36154608e-07,  5.81428926e-07],
#        [ 1.56093641e-05,  2.69986951e-05],
#        [-3.50393360e-05, -6.06056945e-05],
#        [ 1.07768848e-03,  1.86402102e-03],
#        [ 1.60920125e-02,  2.78335068e-02]])

# %%
# I[0]
np.exp(-np.array(I[0]))/(1+np.exp(-np.array(I[0])))**2
#np.exp(-np.array([1,2]))
# Out:
# array([9.07013459e-08, 5.30700836e-03, 4.71827545e-51, 3.10399707e-23,
#        1.24218279e-02, 1.98708205e-02, 8.56948488e-05, 1.15420772e-07,
#        9.05182282e-06, 6.55210565e-04, 1.61787437e-04, 5.93692992e-03])

# %%
Wupx=[]; Bupx=[]
lw=list(range(len(W)))[::-1]
       #lb=list(range(len(W)-1))[::-1]
lb=lw[:len(lw)-1]
for i in lw:
  Wupx.append(backward2(W,A,I,X, y, eta,k=i)[0])
for i in lb:
  Bupx.append(backward2(W,A,I,X, y, eta,k=i)[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-7e33634692ef> in <module>()
#       4 lb=lw[:len(lw)-1]
#       5 for i in lw:
# ----> 6   Wupx.append(backward2(W,A,I,X, y, eta,k=i)[0])
#       7 for i in lb:
#       8   Bupx.append(backward2(W,A,I,X, y, eta,k=i)[1])
#
# <ipython-input-83-0c808d04d2db> in backward2(W, A, I, X, y, eta, k)
#      17       derives=np.sum(derives, axis=0)
#      18     #derives.append(dA_dI(I[n-i-1]) ) #dA_(n-1)/dI_(n-1)
# ---> 19     derives*=dA_dI(I[n-i-1])  #dA_(n-1)/dI_(n-1)
#      20   #derives.append(A[n-k-1]) #dI_(k)/dW_(k)
#      21   if k<n:
#
# <ipython-input-11-faa39f910033> in dA_dI(I)
#       1 def dA_dI(I):
# ----> 2   da_di=np.exp(-I)/(1+np.exp(-I))**2
#       3   return da_di
#       4
#       5
#
# TypeError: bad operand type for unary -: 'list'

# %%
W= [([[  7.31688296,   2.40826151],
       [  8.4270951 , -40.93640126],
       [203.37108812, -84.36465254],
       [  5.82945695,   4.67045255],
       [  3.91133609,   4.79442617],
       [ 31.38016353,  24.10641624],
       [-36.21745172, -16.16372546],
       [  4.63005582,   8.66471389],
       [-24.4102104 , -30.38972844],
       [  9.43486724,  34.34724982],
       [ 10.62440627,  -1.76477218],
       [ 11.08353351,   0.45419425]]), ([ 29.57344436,  12.33983818,  15.02089068,  16.60625931,
         5.37154854,  23.37301086, -13.08608978,  15.07938593,
       -28.76867722,  15.97697532,  40.00060001,  15.80259817])]
B= [([-24.64447976,  -6.69794373, -53.02875142, -20.02897599,
        -8.915959  , -59.53868934,  -8.41431738, -16.35984854,
         9.25755971, -38.91102907, -24.86494388, -31.87005734])]
Wupx=[]; Bupx=[]
lw=list(range(len(W)))[::-1]
       #lb=list(range(len(W)-1))[::-1]
lb=lw[:len(lw)-1]
for i in lw:
  Wupx.append(backward2(W,A,I,X, y, eta,k=i)[0])
for i in lb:
  Bupx.append(backward2(W,A,I,X, y, eta,k=i)[1])

# %%
A
# Out:
# [array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])]

# %%
# print(-1*((y*(1/I[-1])+(1-y)*(1/(1-I[-1])))) )
# dE_dO2
# print(Wup)
# # w1up

# w2up
n
#[np.dot(W1[i],X[0])+B[i] for i in range(n)]
# np.array(Wup).shape
# np.array(w2up).shape
# w2up
# sumMat(B)
# Wup
# w2up
# Bup
# lb[0]+1
# lw=list(range(len(W)))[::-1]
# lb=list(range(len(W)-1))[::-1]
# lw[:len(lw)-1]
# B
# backward2(W,A,I,X, y, eta,k=1)
# print("Wup: ", Wup)
# print("W: ", W)
# [B[i]-Bup[i] for i in range(len(B))]
# Wx,Bx=update2(Wup,Bup, W, B)
# print("Bx: ", Bx)
# print("B: ", B)
#forward2(Wx,Bx,X)
#Wx=copy.deepcopy(W); Bx=copy.deepcopy(B)
#[np.dot(W1[i],X[0])+Bx[i] for i in range(n)]
lw
# Out:
# [1, 0]

# %%
def update2(Wup,Bup, W, B,eta):

  WC=copy.deepcopy(W); BC=copy.deepcopy(B)
  try:
    W=[W[i]-eta*Wup[i] for i in range(len(W))]
    B=[B[i]-eta*Bup[i] for i in range(len(B))]
    #W=W-Wup #eta*np.array([dE_dO2*dO2_dO1,dE_dO2*dO2_dO1]).T*dO1_dW1
    
    #B=B-Bup #eta*dE_dO2*dO2_dO1*dO1_dB
  except:
    W=WC; B=BC


  # W=[np.array(W[i]) for i in range(len(W))]
  # B=[np.array(B[i]) for i in range(len(B))]
  return (W,B)

# %%
def dA_dI(I):
  da_di=np.exp(-np.array(I))/(1+np.exp(-np.array(I)))**2
  return da_di

# %%
backward2(B,A,I,X, y, eta,k=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-626885f57b79> in <module>()
# ----> 1 backward2(B,A,I,X, y, eta,k=1)
#
# NameError: name 'A' is not defined

# %%
def backward2(W,A,I,X, y, k=1):
#  k=1
  
  #dE_dIn=-1*((y*(1/I[-1])+(1-y)*(1/(1-I[-1])))) 
  #dE_dAn=-1*((y*(np.log(I[-1]))+(1-y)*((1-np.log(I[-1]))))) 
  #si=sigmoid

  #---
  #print("I[-]=",I[-1])
  An=A[-1]
  dE_dAn  =-1*((y*(np.log(1/An))+(1-y)*((1-np.log(1/(1-An)))))) 
  #dE_dAn  =-1*((y*(np.log(An))+(1-y)*((np.log((1-An)))))) 
  #dE_dAn  =-1*((y*((An))+(1-y)*((1-((An)))))) 
  #dE_dAn  =-1*((y*(np.log(1/An))+(y-1)*((np.log(1/(1-An)))))) 
  #dE_dAn  =-1*((y*(np.abs(np.log(An)))+(y-1)*(np.abs(np.log((1-An)))))) 


  #dE_dAn=-1*(y*((1/An))+(y-1)*(1/(1-An)))
  
  dAn_dIn=sigmoid(I[-1])*(1-sigmoid(I[-1]))

  #---


  #print(dE_dIn)
  n=len(N)-1
  #derives=[]
  derives=dE_dAn*dAn_dIn
  for i in range(k): #k<n
    #print(i)
    #derives.append(W[n-i]) #dI_(n)/dA_(n-1)
    #try:
    if i==0:
      derives*=W[n-i] #dI_(n)/dA_(n-1)
    #except:
    else:
      # print("derives: ",derives)
      # print(" W[n-i].T: ", W[n-i].T)
      derives=np.array([derives*x for x in W[n-i].T]).T
      derives=np.sum(derives, axis=0)
    #derives.append(dA_dI(I[n-i-1]) ) #dA_(n-1)/dI_(n-1)
    #print(I[n-i-1])
    
    #---sigmoid
    #derives*=dA_dI(I[n-i-1])  #dA_(n-1)/dI_(n-1)
    #----
    #----relu sep 9 20
    # print("nnnnnnnn:",n)
    # print("iiiiiiiiii:",i)
    #print("da_di########################:",np.array([0 if e==0 else 1 for e in A[n-i-1] ]))
    #derives*=np.array([0 if e==0 else 1 for e in A[n-i-1] ])

    #leaky
    derives*=np.array([0.01 if e<0 else 1 for e in A[n-i-1] ])
    #-----

  #derives.append(A[n-k-1]) #dI_(k)/dW_(k)
  if k<n:
    
    derivesW=np.array([derives*x for x in A[n-k-1] ]).T#dI_(k)/dW_(k)

    #derivesW=derives*A[n-k-1] #dI_(k)/dW_(k)
    #print("derivesW:",derivesW)
  if k==n:
    derivesW=np.array([derives*x for x in X[0]]).T#dI_(k)/dW_(k)
  
  # derivesW=[np.array(derivesW[i]) for i in range(len(derivesW))]
  # derives=[np.array(derives[i]) for i in range(len(derives))]
  #return (eta*dE_dIn*derivesW, eta*dE_dIn*derives, dE_dIn)
  #return (eta*dE_dAn*dAn_dIn*derivesW, eta*dE_dAn*dAn_dIn*derives, dE_dAn)
  return (derivesW, derives, dE_dAn)

#   #print(derivesW, derives)
#   #W[4]
#   W[n-k]
#   #W[0]
# backward2(W,A,I,X)

# %%
  k=0
  n=len(N)-1
  derives=[]
  derives=1
  for i in range(k): #k<n
    #print(i)
    #derives.append(W[n-i]) #dI_(n)/dA_(n-1)
    #try:
    if i==0:
      derives*=W[n-i] #dI_(n)/dA_(n-1)
    #except:
    else:
      derives=np.array([derives*x for x in W[n-i].T]).T
      derives=np.sum(derives, axis=0)
    #derives.append(dA_dI(I[n-i-1]) ) #dA_(n-1)/dI_(n-1)
    derives*=dA_dI(I[n-i-1])  #dA_(n-1)/dI_(n-1)
  #derives.append(A[n-k-1]) #dI_(k)/dW_(k)
  print(derives)
  if k<n:
    derives=np.array([derives*x for x in A[n-k-1] ]).T#dI_(k)/dW_(k)
  if k==n:
    derives=np.array([derives*x for x in X[0]]).T#dI_(k)/dW_(k)

  #print(derives.shape)
  #W[4]
  #W[n-k].shape
  #W[0]
#derives*2
derives
# Out:
# 1
# array([9.07013540e-08, 5.33547566e-03, 4.71827543e-51, 3.10399706e-23,
#        1.25800864e-02, 2.02821876e-02, 8.57021937e-05, 9.99999885e-01,
#        9.05190471e-06, 6.55640430e-04, 1.61813620e-04, 5.97260189e-03])

# %%
#der1=[]#copy.deepcopy(derives)
# der1.append(derives)
# der1
#der2=[]
sumMat(der2)
# Out:
# [array([[ 0.00897384,  0.00897384],
#         [ 0.1223951 ,  0.1223951 ],
#         [ 0.36896472,  0.36896472],
#         [-0.01582186, -0.01582186],
#         [-0.13596978, -0.13596978],
#         [-0.36224705, -0.36224705],
#         [-0.32948113, -0.32948113],
#         [ 0.58005722,  0.58005722],
#         [-0.61223003, -0.61223003],
#         [-0.97656702, -0.97656702],
#         [ 0.19492806,  0.19492806],
#         [ 0.69451828,  0.69451828]]),
#  array([0.30693136, 1.73339193, 0.31254957, 1.89510818, 0.3088725 ,
#         0.60977134, 0.50442423, 0.89560904, 0.96273349, 0.80657637,
#         1.33042519, 0.80745325])]

# %%
def backward2_(W,A,I,X, y, eta, k=1):
#  k=1
  dE_dIn=-1*((y*(1/I[-1])+(1-y)*(1/(1-I[-1])))) 
  print(dE_dIn)
  n=len(N)-1
  derives=[]
  derives=1
  for i in range(k): #k<n
    #print(i)
    #derives.append(W[n-i]) #dI_(n)/dA_(n-1)
    #try:
    if i==0:
      derives*=W[n-i] #dI_(n)/dA_(n-1)
    #except:
    else:
      derives=np.array([derives*x for x in W[n-i].T]).T
      derives=np.sum(derives, axis=0)
    #derives.append(dA_dI(I[n-i-1]) ) #dA_(n-1)/dI_(n-1)
    derives*=dA_dI(I[n-i-1])  #dA_(n-1)/dI_(n-1)
  #derives.append(A[n-k-1]) #dI_(k)/dW_(k)
  if k<n:
    derives=eta*dE_dIn*np.array([derives*x for x in A[n-k-1] ]).T#dI_(k)/dW_(k)
  if k==n:
    derives=eta*dE_dIn*np.array([derives*x for x in X[0]]).T#dI_(k)/dW_(k)
  
  return (derives, dE_dIn)

#   #print(derivesW, derives)
#   #W[4]
#   W[n-k]
#   #W[0]
# backward2(W,A,I,X)
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9327e3dd90f7> in <module>()
#      31 #   #W[0]
#      32 # backward2(W,A,I,X)
# ---> 33 n
#
# NameError: name 'n' is not defined

# %%
list(range(len(W)))[::-1]
list(range(len(W)-1))[::-1]
derives
eta
W
# Out:
# [array([[ 1.09900611, -3.06487066],
#         [ 0.09791463,  1.07131979],
#         [-0.91092507, -0.79508418],
#         [ 0.79080539,  0.37243724],
#         [-0.07154348, -0.9301618 ],
#         [-0.99162626,  0.91524152],
#         [ 0.97705202, -1.52160513],
#         [ 0.48286777, -0.72634456],
#         [-0.91795222,  0.52019285],
#         [ 0.29968825, -1.05974455],
#         [ 0.81364552, -0.99363916],
#         [-0.17597009, -0.9369542 ]]),
#  array([ 0.03453762,  0.52969268,  1.39915204, -0.15918858, -0.52061517,
#         -0.85463684, -0.87348647,  1.17289605, -1.22616295, -2.02904614,
#          0.43763775,  1.44251679])]

# %%
def backward(eta,y, A1,A2_sum,W1,W2,X,B, A2, i,O2,O1,Z1):
  #print("A1 BCK: ", A1)
  #eta=0.1
  # if sum(np.isnan(W1))[0]==n:
  #   W1=np.array(np.random.normal(0, 1, n*2)).reshape(n,2)
  # if sum(np.isnan(B))==n:
  #   B=np.array(np.random.normal(0, 1, n))
  # if sum(np.isnan(W2))==n:
  #   W2=np.array(np.random.normal(0, 1, n))


  y=np.array(y)
  W2C=copy.deepcopy(W2)
  O2=np.array(O2)


  #########################
  #O1=I[0]; A1=A[0]; O2=I[1]
  
  ###########
  dE_dO2=-1*((y*(1/O2)+(1-y)*(1/(1-O2)))) 
  
  dO2_dW2=A1
    
  dO2_dA1=W2
  try:
    dA1_dO1=np.exp(-O1)/(1+np.exp(-O1))**2
  except:
    dA1_dO1=np.exp(-O1*0)/(1+np.exp(-O1*0))**2

  dO1_dW1=X[0]

  dO1_dB=1
  #############



  w2up=eta*dE_dO2*dO2_dW2
  
  w1up=eta*np.array([dE_dO2*dO2_dA1*dA1_dO1*x for x in dO1_dW1]).T#dE_dO2*dO2_dA1*dA1_dO1*dO1_dW1
  bup=eta*dE_dO2*dO2_dA1*dA1_dO1*dO1_dB#dE_dO2*dO2_dA1*dO1*dO1_dB

  #######################
    
  return ((w2up, w1up, bup, dE_dO2))

# %%
# row=next(batch.iterrows())
# rrr=row
# rrr
#np.dot(W[0],X[0])+B[0]
# for i in range(1, len(N)-1):
#   print(i)
row=[1,1,1]
row[0]
list(range(0,len(train),BATCH))
W
-1*((y*(1/I[-1])+(1-y)*(1/(1-I[-1])))) 
-1*((y*(1/O2)+(1-y)*(1/(1-O2))))
# Out:
# -2.745036268559168

# %%
#[np.dot(W1[i],X[0])+B[i] for i in range(n)]
X=[[1,1]]
i=0
np.dot(W[i],X[0])+B[i]
[np.dot(W1[i],X[0])+B[i] for i in range(n)]
#[np.dot(W1[i],X[0]) for i in range(12)]
# Out:
# 1.3243669276975834

# %%
import numpy as np
N=[2,12,2,3,4]
N=[2,12,2,3,4,7,8,9,2]
N=[2, 12]
#N=[12]
#N=[2,3]
x1,x2=1,2
X=[[x1,x2]]
lx=len(X) # = 2


W=[]; B=[]

for i in range(1,len(N)):
  W.append(np.array(np.random.normal(0, 1, N[i]*N[i-1])).reshape(N[i],N[i-1]))
  B.append(np.random.normal(0, 1, N[i]))
W.append(np.random.normal(0, 1, N[-1]))

# W[0]=np.array([1,2,3,4,5,6]).reshape(-1,2); W[1]=[1,2,3]
# B[0]=[1,1,1]

# %%
def generateWandB(N):
  #lx=len(X) # = 2


  W=[]; B=[]

  for i in range(1,len(N)):
    #W.append(np.array(np.random.normal(0, 1, N[i]*N[i-1]) ).reshape(N[i],N[i-1]))
    
    #---He et al weight initialization
    W.append(np.array(np.random.normal(0, 1, N[i]*N[i-1])*np.sqrt(2/N[i-1]) ).reshape(N[i],N[i-1]))
    #----

    B.append(np.random.normal(0, 1, N[i]))
  W.append(np.random.normal(0, 1, N[-1]))
  
  W=[np.array(W[i]) for i in range(len(W))]
  B=[np.array(B[i])*0 for i in range(len(B))]
  return (W,B)

# %%
# # W1=W[0]; W2=W[1]; #B=B[0]
# # B=np.random.normal(0, 1, n)
# a=np.empty(2)
# wx,bx=generateWandB(N)
wx
# Out:
# [array([[-0.22318639,  0.78212822],
#         [-0.10507607,  0.52852882],
#         [-1.18586516,  0.55048063],
#         [ 0.24550696,  0.7645367 ],
#         [ 0.86527411, -0.05128995],
#         [-0.32344119, -0.74301602],
#         [-1.0475786 ,  0.04186394],
#         [ 1.2545116 , -0.12566899],
#         [-0.32895305, -2.37913569],
#         [-1.10811516,  0.97857568],
#         [-0.09671618,  0.68659197],
#         [ 0.20398852,  0.95704838]]),
#  array([-0.0329766 ,  0.39380896, -0.71218715,  0.44097862,  0.22895401,
#         -0.10685313, -0.85548007, -1.1084808 ,  1.2168497 , -0.39121173,
#          0.53517774, -0.19897337])]

# %%
def forward2(W, B, X):
  I=[]
  A=[]
  #I.append(X[0])
  I.append(np.dot(W[0],X[0])+B[0])  #12x2*2*1+12 => 12x1

  for i in range(1, len(N)):
    #print(i)
    #---sigmoid
    #A.append(sigmoid(I[i-1])) #12x1
    #----

    #---relu sep 9 20
    A.append(relu(I[i-1]))
    #print("A:",A)
    #----

    #print(A[i-1])
    if i<len(N)-1:
      I.append(np.dot(W[i],A[i-1])+B[i]) #12x1*2x12
    else:
      I.append(np.dot(W[i],A[i-1]))
  A.append(sigmoid(I[-1]))
  #---relu sep 9 20
  #A.append(relu(I[-1]))
  
  #-----

  #I.append(np.dot(W[-1],A[-1]))
  #print("A={}, I={}".format(A,I))
  return(A,I)

# %%
sigmoid(I[1])
# Out:
# array([6.66652818e-07, 9.99403057e-01, 9.99972880e-01, 5.47991546e-01,
#        5.58163150e-02, 9.99755913e-01, 1.67818469e-02])

# %%
def forward2(W, B, X):
  I=[]
  A=[]
  #I.append(X[0])
  I.append(np.dot(W[0],X[0])+B[0])  #12x2*2*1+12 => 12x1

  for i in range(1, len(N)-1):
    #print(i)
    A.append(sigmoid(I[i-1])) #12x1
    #print(A[i-1])
    I.append(np.dot(W[i],A[i-1])+B[i]) #12x1*2x12
  A.append(sigmoid(I[-1]))
  I.append(np.dot(W[-1],A[-1]))
  print("A={}, I={}".format(A,I))
  return(A,I)

# %%
def forward(W1,W2,B, X):

  Z1=[np.dot(W1[i],X[0])+B[i] for i in range(n)]
 
  A1=[sigmoid(Z1[i]  ) for i in range(n)]

  A2=[sigmoid(A1[i]*W2[i]   ) for i in range(n)]
  O1=A1*W2
  
#######
  O1=np.array(Z1)
  A1=sigmoid(O1)
  O2=np.dot(A1,W2)
  print("O1={}, A1={}, O2={}".format(O1,A1,O2))




  


#########


  return (A1,sum(A2),A2,O2,O1,Z1)

# %%
def sumMat(xup):
  array=[]
  l=([(xup[i][j]) for j in range(len(xup[0])) for i in range(len(xup))])
  for k in range(len(l))[::len(xup)]:
    array.append((np.sum(l[k:k+len(xup)],axis=0)))
#    print("---------")
  return array

# %%
# A,I=forward2(W,B,[[1,2]])
# print("B:",B)
# print("Bx:",Bx)
#X
#Wx=copy.deepcopy(W); Bx=copy.deepcopy(B)
#print("A={}, I={}".format(A,I))

W
# Out:
# [array([[ 0.40142669, -0.39204875],
#         [-0.73413783,  1.06554516],
#         [-0.09032022,  2.24089139],
#         [-2.02377492,  1.6034136 ],
#         [ 0.44917924, -0.61905768],
#         [ 0.31863759,  0.03110064],
#         [-1.17199182, -0.4730101 ],
#         [ 1.12265302, -0.88587803],
#         [-0.1797226 ,  0.07348262],
#         [ 0.62678197,  0.98638971],
#         [ 0.66157535, -0.77627665],
#         [ 1.68211765, -0.0702617 ]]),
#  array([[-0.67292264,  0.18749239,  0.13691813,  1.39369326, -0.47515811,
#           0.66363665,  0.90440676, -2.30527771,  0.82298459,  1.66591605,
#           1.08055719, -0.72414761],
#         [ 1.100332  , -0.02889234,  0.66230561,  0.58750868, -1.82684343,
#           0.97090512,  0.22658476,  1.13067439, -0.23074664, -0.4606439 ,
#           0.38095046, -2.66494315]]),
#  array([[ 0.96873479, -0.89556726],
#         [ 0.78620246,  0.10080607],
#         [ 0.53168733,  1.43037733]]),
#  array([[ 0.99227583,  0.09551322,  1.3428002 ],
#         [ 0.40488504, -0.53429319,  0.29130041],
#         [-0.24840422,  0.7506052 ,  1.93710922],
#         [ 0.90757537, -0.99842384,  0.71333716]]),
#  array([[ 1.82238656, -1.02212258, -0.95534398, -0.07774308],
#         [ 1.52015528,  0.56185008,  0.58593449,  2.18833008],
#         [-0.96531999, -0.64404839,  1.48282274, -1.18808652],
#         [-0.04768827, -0.42103041, -1.79311278, -0.38439993],
#         [-0.87134187,  1.3912663 , -0.43906986,  0.67041182],
#         [-1.54686557, -1.0301897 ,  1.3203298 , -1.86504229],
#         [-1.38821278, -0.45696397, -1.25779095, -1.07709538]]),
#  array([[ 1.1280343 , -0.15057728,  0.71673605,  0.31643547, -0.06209029,
#           0.74526142,  1.43543168],
#         [-1.4541284 ,  1.86825206, -1.01300324, -0.38498109, -0.23994497,
#           1.31322048, -0.01188637]]),
#  array([-0.59457761,  0.63194252])]

# %%
  I=[]
  A=[]
  #I.append(X[0])
  I.append(np.dot(Wx[0],X[0])+B[0])  #12x2*2*1+12 => 12x1

  for i in range(1, len(N)-1):
    #print(i)
    A.append(sigmoid(I[i-1])) #12x1
    #print(A[i-1])
    I.append(np.dot(Wx[i],A[i-1])+B[i]) #12x1*2x12
  A.append(sigmoid(I[-1]))
  I.append(np.dot(Wx[-1],A[-1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-847482175196> in <module>()
#      10   I.append(np.dot(Wx[i],A[i-1])+B[i]) #12x1*2x12
#      11 A.append(sigmoid(I[-1]))
# ---> 12 I.append(np.dot(Wx[-1],A[-1]))
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (4,) and (12,) not aligned: 4 (dim 0) != 12 (dim 0)

# %%
N
# Out:
# [2, 12]

# %%
A,I=forward2(W,B,X)
#a1,b1=forward2(W,B,X)
#a,b,c,d,e,f=forward(W1,W2,B[0],X)
X
# Out:
# [[1, 2]]

# %%
  O2=I[1]
  O1=I[0]
  W1=W[0]
  W2=W[1]
  A1=A[0]
  Bx=B
# print(A1)
# A[0]
# print(B[1])

# %%
def dA_dI(I):
  da_di=np.exp(-I)/(1+np.exp(-I))**2
  return da_di

# %%
from IPython.display import clear_output
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
class Initialize:
    def __init__(self, data, N,testfrac=0.90):
      self.data=data
      self.N=N
      self.testfrac=testfrac
      self.z=1
      
    def generateWandB(self):
      #lx=len(X) # = 2


      W=[]; B=[]
      N=self.N
      for i in range(1,len(N)):
        #W.append(np.array(np.random.normal(0, 1, N[i]*N[i-1]) ).reshape(N[i],N[i-1]))
        
        #---He et al weight initialization
        W.append(np.array(np.random.normal(0, 1, N[i]*N[i-1])*np.sqrt(2/N[i-1]) ).reshape(N[i],N[i-1]))
        #----

        B.append(np.random.normal(0, 1, N[i]))
      W.append(np.random.normal(0, 1, N[-1]))
      
      W=[np.array(W[i]) for i in range(len(W))]
      B=[np.array(B[i])*0 for i in range(len(B))]
      self.W=W
      self.B=B
      #return (self.W,self.B)

    def trainAndTest(self):
      df=self.df.sample(frac=1).reset_index(drop=True)
      
      thresh=int(len(df)*self.testfrac)
      self.test=df[:thresh]
      self.train=df[thresh:]
      
    def generateData(self, show=True):
      self.show=show

      ##################


      # #Circle
      if self.data=='circle':
          r=65
          a,b=-12,10
          n=500
          rng=np.linspace(-6,6,n)
          rngy=np.linspace(a,-a,n)
          rngx=np.linspace(-a,a,n)
          p=[]
          xy_1=[]
          for x in rngx:
              for y in rngy:

                  z=x**2+y**2-r
                  xy_1.append(z)
                  r1=np.random.randint(-7,7)*0.17
                  r2=np.random.randint(-7,7)*0.17
                  if z<0.1 and z>-0.1:
                    p.append((x+r1,y+r2))


          r=4.25
          a,b=-6,6
          a=-12
          n=500
          rng=np.linspace(-6,6,n)
          rngy=np.linspace(a,-a,n)
          rngx=np.linspace(-a,a,n)
          p_2=[]
          xy_2=[]
          for x in rngx:
              for y in rngy:

                  z=x**2+y**2-r
                  xy_2.append(z)
                  r1=np.random.randint(-5,5)*0.43
                  r2=np.random.randint(-5,5)*0.43
                  if z<0.1 and z>-0.1:
                    p_2.append((x+r1,y+r2))
                    #p_2.append((x,y))         
          xs=[i[0] for i in p]
          ys=[i[1] for i in p]


          xs_2=[i[0] for i in p_2]
          ys_2=[i[1] for i in p_2]

          #####################



      if self.data=="square":

        ####################################################
      #SQUARE
        #r=65
        a,b=-12,10
        n=100
        a=12
        p=.051
        #rng=np.linspace(-6,6,n)
        rngy=np.linspace(a,-a,n)
        rngx=np.linspace(-a,a,n)
        psq=[]; psq2=[]
        xy_1=[]
        a2=11.0
        rr=1.0

        for x in rngx:
            for y in rngy:

              if np.random.choice([1,-1],p=[p,1-p])>0:
                if (x<-rr and x>-(a2) and y<(a2) and y>rr) \
                or ( x>rr and x<(a2) and y<-rr and y>-(a2)):
                  psq.append((x,y))
                if (x<(a2) and x>rr and y>rr and y<(a2) ) or ( x<-rr and x>-(a2) and y<-rr and y>-(a2)) :# or ( x>rr and x<(a) and y<-rr and y>-(a)):
                  psq2.append((x,y))


        xs=[i[0] for i in psq]
        ys=[i[1] for i in psq]


        xs_2=[i[0] for i in psq2]
        ys_2=[i[1] for i in psq2]

      if show:
        axes = plt.gca()
        axes.set_xlim([a,-a])
        axes.set_ylim([a,-a])

        plt.scatter(xs,ys,color='k') 
        #plt.scatter(xs_2,ys_2, color='g') 
        plt.scatter(xs_2,ys_2, color='g')

        plt.show()


      ss=[(xs[i],ys[i],1) for i in range(len(xs))]
      ss_2=[(xs_2[i],ys_2[i],0) for i in range(len(xs_2))]
      df=pd.concat([pd.DataFrame(ss), pd.DataFrame(ss_2)])
      self.df=df




##################

# %%
class PropagateEpoch:
    def __init__(self, train, test, W,B,activation,N, BATCH=10):
      self.train=train
      self.test=test
      self.W=W
      self.B=B
      self.activation=activation
      self.N=N
      self.BATCH=BATCH

      #self.X=
    def batchDescent(self):
      for j in   list(range(0,len(self.train),self.BATCH)):
        Loss=[] 
        Wup=[]; Bup=[]; 
        batch=self.train[j:j+self.BATCH]
        count=0
        for row in batch.iterrows():
          #TODO
          count+=1
          
          Wupx=[]; Bupx=[]
          
          x1=row[1][0]; x2=row[1][1]; y=row[1][2]
          
          x1=np.array(x1)
          x2=np.array(x2)
          X=[[x1,x2]]
          y=np.array(y)
          self.forward(self.W,self.B,X) 

    def relu(self,z):

      #return np.array([max(0,e) for e in z ])
      #leaky
      return np.array([e if e>0 else 0.01*e for e in z ])


    def sigmoid(self,z):
      #print(z)
      # if z<-200:
      #     return 0
      try:
        sig= 1/(1+np.exp(-z))
      except:
        sig= 1/(1+np.exp(-z*0))

      return sig


    def softmax(self,z):
      res=np.exp(z)/np.sum(np.exp(z))
      return res

    def forward(self, X):
      self.X=X
      self.I=[]; self.A=[]
      
      self.I.append(np.dot(self.W[0],self.X[0])+self.B[0]) 
      for i in range(1, len(self.N)):

         if self.activation=='sigmoid':

         #---sigmoid
           self.A.append(self.sigmoid(self.I[i-1])) #12x1
         #----

         if self.activation=='relu':
           #---relu sep 9 20
           self.A.append(self.relu(self.I[i-1]))
           #print("A:",A)
           #----

         if i<len(self.N)-1:
           self.I.append(np.dot(self.W[i],self.A[i-1])+self.B[i]) #12x1*2x12
         else:
           self.I.append(np.dot(self.W[i],self.A[i-1]))
      self.A.append(self.sigmoid(self.I[-1]))
      return(self.A,self.I)

# %%
N=[2,8,8,18,8,8,7,10]
obj=Initialize("square",N,0.5)

# %%
import numpy as np
import pandas as pd
obj.generateData(True)

# %%
#obj.generateWandB()
obj.W
# Out:
# [array([[-0.08315741, -0.40016646],
#         [-0.77365254, -1.99201302],
#         [ 0.75000554, -0.96999176],
#         [ 0.46263397, -0.03590813],
#         [ 0.02904804, -0.33121838],
#         [ 1.63392809, -0.10558611],
#         [-0.0489765 ,  0.06680486],
#         [-0.13968267, -1.21087592]]),
#  array([[ 0.48985573, -1.12804782,  0.02470798,  0.12552901,  1.09801747,
#           0.53927266,  0.7574703 , -0.60636301],
#         [-0.64189907, -0.11148729,  0.49297038, -0.47436588,  0.53654767,
#          -0.75540914, -0.17691979, -0.3711892 ],
#         [ 0.47223148, -0.06062106, -1.01831049,  0.37293875, -0.09377813,
#           0.00133441,  0.10592249,  0.37241449],
#         [-0.31989298, -0.82171357,  0.50546931, -0.11414374, -0.81267134,
#          -0.15943902,  0.15363049, -0.07748286],
#         [-0.59902486, -0.64865069,  0.2931916 , -1.18553594,  0.12724131,
#          -0.39319836,  0.38831856, -0.32882901],
#         [ 0.24303402, -0.48062011,  0.13609528, -0.11857266, -0.78509478,
#          -0.02792723, -0.74507648,  0.81038444],
#         [-0.19890671, -0.30085124, -0.10834189, -0.47307834,  0.32116471,
#           0.53779075,  0.25529207,  0.01391102],
#         [-0.0168955 , -0.4786601 ,  0.139313  , -0.55402656, -0.37022789,
#           1.0650195 , -0.24174326,  0.1186073 ]]),
#  array([[-1.93964139e-01,  4.63750773e-02,  2.66780983e-01,
#           1.75558228e-01,  1.92729906e-01, -1.39662448e+00,
#           1.14066655e+00, -2.48552426e-01],
#         [-2.04157573e-01, -9.87523370e-02,  9.39368711e-02,
#           5.80435301e-01, -4.58616194e-01, -1.41550038e-01,
#          -3.98649276e-01, -2.60811401e-01],
#         [-2.08181865e-01,  4.90665407e-02, -6.83974185e-01,
#           5.09257254e-02, -1.00336975e+00,  1.57476425e-01,
#          -5.16581600e-01,  4.59563060e-01],
#         [-2.45506370e-01,  2.99794574e-01, -2.68422701e-01,
#          -7.97748898e-02,  3.35174501e-01, -1.83036487e-01,
#           1.09481081e-01, -7.85941622e-01],
#         [-7.11776896e-01,  9.38583951e-02, -1.03268558e-01,
#          -1.82119728e-01, -4.23472847e-01, -1.93196150e-01,
#           4.00948790e-01,  1.67242036e-01],
#         [ 1.79041497e-01, -4.23999526e-01, -4.11221734e-01,
#          -1.07142384e+00, -1.38176306e-01, -3.48307878e-01,
#           2.88262446e-01, -1.27287749e+00],
#         [ 6.30732307e-01, -2.36608234e-01,  2.63328966e-01,
#           5.14520892e-01, -2.71616260e-01,  1.02743009e-01,
#           8.47601996e-02, -5.57088134e-01],
#         [-7.18468526e-01,  8.88714666e-02,  4.80615381e-01,
#          -2.99197525e-01,  6.58303748e-01,  3.27628558e-01,
#           1.35664715e+00,  1.89535074e-02],
#         [ 7.39707146e-01,  6.26509167e-01, -8.47168056e-02,
#          -4.36564866e-01, -4.78362360e-01, -8.09266301e-01,
#           2.69651821e-01,  2.15111195e-01],
#         [-3.88911896e-01,  4.73963498e-01,  2.33141878e-01,
#          -2.70543677e-01, -4.97384236e-02, -3.82520042e-01,
#          -5.40267914e-01, -1.92405949e-01],
#         [-2.37013862e-01,  1.69650446e-01, -3.57204915e-01,
#           1.26025560e-02,  6.02292004e-01, -4.46039272e-01,
#          -3.17305100e-01, -6.82175600e-01],
#         [-4.41173604e-02, -3.80505987e-01, -2.53778387e-01,
#          -4.43381715e-01,  2.51669388e-02,  7.65932693e-02,
#           9.26074286e-01, -9.50137122e-02],
#         [-1.50650019e-01, -1.05414142e+00, -2.96221451e-01,
#           1.83477805e-02, -8.14091708e-01,  1.09337599e-01,
#          -4.74356341e-01,  3.21298900e-01],
#         [ 4.31937513e-02, -4.57120067e-01,  4.11833059e-02,
#           8.61228879e-02, -8.05998378e-01,  7.32345518e-01,
#          -6.04124361e-01,  7.82751955e-01],
#         [-1.09176576e+00, -5.29922671e-01,  3.09467282e-01,
#          -7.40350701e-01, -2.61903695e-01,  6.48386475e-01,
#           5.08365981e-01, -1.14606814e+00],
#         [ 5.42358733e-01, -6.61478213e-01, -3.29826249e-01,
#           6.61182073e-04,  2.25765338e-02,  2.33835072e-02,
#           4.57740869e-01,  8.18653310e-01],
#         [-1.77971807e-01, -4.36508979e-01, -5.59173067e-03,
#          -2.66053529e-02, -4.83893304e-01, -1.51587657e-01,
#           3.96494753e-01, -4.37100617e-01],
#         [-1.34061051e-01, -2.35670257e-01,  4.74101070e-01,
#           2.42663725e-01,  7.82180145e-01, -9.23837956e-01,
#          -4.67488235e-01,  5.34157183e-01]]),
#  array([[-7.76886110e-02,  5.32047929e-01, -3.39692854e-01,
#           3.32407445e-01, -2.21600408e-01, -4.89954944e-01,
#           3.57834658e-01, -3.25064162e-01,  1.92223444e-02,
#          -7.74321329e-01, -6.71492116e-01, -3.63611233e-02,
#          -2.83779907e-01,  3.06151025e-02, -7.69629218e-05,
#          -1.00148395e-01, -7.41207885e-01, -1.70064280e-01],
#         [ 2.30535253e-02, -4.11228142e-01,  3.14908228e-01,
#           4.02624154e-01,  8.11096982e-01,  1.54426998e-01,
#          -3.04952749e-01, -9.56658102e-04,  1.04185524e-01,
#          -2.18815125e-01, -5.80451501e-01,  1.83924424e-01,
#          -2.56571384e-01, -6.60563674e-02, -5.71468309e-01,
#          -2.52919906e-02,  1.56547942e-01, -8.80257136e-02],
#         [-1.60383281e-01,  4.47262557e-02, -3.19011721e-01,
#           2.33328226e-01, -3.49286607e-01,  1.10730621e-02,
#           1.20011046e-01,  2.79006082e-01, -8.45884009e-02,
#           3.72935472e-01,  3.53668285e-02, -2.93122801e-01,
#           6.13330707e-02,  2.04037244e-01,  4.23617178e-01,
#           3.32935391e-01, -1.00238100e-01,  4.34690689e-01],
#         [ 1.40661439e-01, -3.52368334e-01, -1.37239752e-01,
#          -3.02228226e-01, -4.13183933e-01,  2.22780001e-01,
#          -3.87794141e-01,  4.73786121e-01, -1.29956406e-01,
#           2.99961280e-02, -3.45245873e-01,  2.35562489e-01,
#           1.56783692e-01, -4.92861831e-02, -2.69336195e-01,
#          -3.35338741e-01, -7.88138334e-02, -2.27545661e-01],
#         [-8.96034275e-01, -3.89038734e-01, -4.14397411e-01,
#           3.70183357e-01, -4.11045474e-01, -1.68836936e-01,
#          -9.22839949e-02, -7.22919369e-01, -8.46534160e-02,
#           5.60121555e-01,  4.44714937e-01, -1.07157070e-02,
#          -2.66176596e-01,  7.70307386e-01, -1.81587090e-02,
#           1.80265516e-01,  4.15271456e-01,  4.40306484e-01],
#         [ 3.03487598e-01, -3.20955078e-01,  3.64095345e-01,
#          -9.85679539e-02,  6.03031308e-01, -3.85609074e-02,
#           2.67961016e-01, -4.22878663e-01,  1.33864858e-01,
#          -3.11996632e-01,  4.41213353e-01, -1.42307197e-01,
#          -4.88138577e-01, -3.61739204e-01, -2.47569942e-01,
#           4.44468370e-01,  4.32877630e-01, -2.68256511e-02],
#         [-1.60660987e-01,  1.33562873e-01,  4.96627988e-01,
#          -4.55586528e-01,  2.36468072e-01,  5.23152705e-01,
#           6.59479557e-01,  1.95125980e-01,  1.49637599e-01,
#          -2.51356847e-01,  1.18524449e-01, -2.47407607e-01,
#          -4.76735380e-02, -2.39449295e-01,  2.73308382e-01,
#          -7.61117479e-02,  2.22874547e-01, -6.22222065e-01],
#         [ 1.55377005e-01,  1.74624611e-01,  4.55579669e-01,
#          -9.44495167e-02,  4.28255974e-02, -2.28091099e-03,
#          -1.50749843e-01,  6.70613840e-03, -1.41122178e-01,
#           3.31385078e-01,  1.35762658e-01,  4.25851852e-01,
#          -1.71115354e-01, -1.50632686e-01, -2.19724197e-01,
#          -3.50558251e-01,  2.55839222e-01, -2.02563330e-01]]),
#  array([[-0.20354656, -0.65961283, -0.49608254,  0.01233922,  0.07357017,
#          -0.35471133,  0.01427907,  0.61322504],
#         [ 0.77267158, -0.52035251, -0.15484426, -0.67316176,  0.08335507,
#          -0.46162584, -0.41051596, -1.21109555],
#         [ 0.01628526,  0.31229086,  0.5920918 ,  0.07632225, -0.15266135,
#          -0.06890667, -0.49360859, -0.10274484],
#         [-0.02559383, -0.48857189, -0.23652315, -0.26703962, -0.27856613,
#          -0.09315207, -0.03998305,  0.33717003],
#         [-0.0462948 ,  0.63003411, -0.28053672, -0.8065336 , -0.40763756,
#           0.31899291,  0.1946479 , -0.29951934],
#         [ 0.4723849 , -0.62687496, -0.12895715,  0.5624888 ,  0.52367284,
#          -0.19819692,  0.08045857, -0.3147543 ],
#         [-0.60775381,  0.25509832, -0.10120552, -0.44767744,  0.38645952,
#          -0.70596887, -0.28728176,  1.02354373],
#         [ 0.08504462, -0.29003019, -0.43985948,  0.39355433, -1.18038827,
#          -0.21746168, -0.38215147, -0.33687871]]),
#  array([[-0.22338792, -0.37836628,  0.01120245,  0.27730703,  1.19569423,
#           0.05080931, -1.11020588,  0.24735278],
#         [ 0.3420383 , -0.02559827,  0.29372728,  0.1986027 , -0.47284213,
#          -0.57243088, -0.28595648, -0.09866487],
#         [-0.8984649 ,  0.16088917, -0.026472  ,  0.05249111, -0.30168268,
#          -0.33701192,  0.44455469, -0.01871456],
#         [ 0.22137544, -0.78107067, -0.64936027,  0.44169703,  0.20107093,
#          -0.47954189, -0.56034198,  0.71208675],
#         [-0.35660312,  0.29019496, -0.18749255,  0.78731776, -0.58764236,
#          -0.45874558,  0.00169692,  0.08637016],
#         [-0.54233398,  0.10568803, -0.50138129, -0.37728241, -0.42755134,
#           1.03972649,  0.46257865,  0.67685531],
#         [-0.05577737, -0.22580362,  0.24453916, -0.11928892, -0.13667792,
#           0.55828474,  0.14341451, -0.24039176]]),
#  array([[ 0.38785626,  0.09402715, -0.45045558,  0.23531788,  0.66451559,
#           0.31171748, -0.31078789],
#         [ 0.69138411, -0.20500761,  0.73741831,  0.60244072,  0.01134291,
#           0.1875744 , -0.78872593],
#         [-0.16179889, -0.62441746, -0.83388731, -0.12332143,  1.29286221,
#           0.2601403 ,  0.04210668],
#         [ 0.14219363, -0.21774857,  0.19499714, -0.33454369,  0.04077161,
#           0.14124901, -0.07391854],
#         [-0.00328819, -0.24063155, -0.38054911, -0.2291964 ,  0.26370024,
#          -0.14165078,  0.58564646],
#         [ 0.56419654, -0.06794403, -0.07708298,  0.69965655, -0.1649809 ,
#           0.08189873, -0.42691684],
#         [-0.61523717, -0.77087866, -0.62110324,  0.3386805 , -0.29676318,
#          -0.15587407,  1.1055039 ],
#         [-0.69416464, -0.04473667,  0.32271157,  0.44626883, -0.33569045,
#           0.03025153, -0.50659808],
#         [ 0.01839337,  0.20958119,  1.12151093,  0.63010831, -0.89752446,
#           0.04621678,  0.61354931],
#         [ 0.32260564, -0.36588129, -0.99291023,  0.65764316,  0.4124606 ,
#           0.05140984, -0.78012172]]),
#  array([-0.36081727,  0.16661096,  0.02301404,  0.27141158,  0.23277485,
#         -0.25966214, -0.32253974, -1.43865946,  0.34625862,  1.15096193])]

# %%
obj.trainAndTest()

# %%
obj.train
# Out:
#              0         1  2
# 167  -9.333333  9.818182  1
# 168   7.393939  6.666667  0
# 169   7.151515  7.636364  0
# 170  -8.848485  2.060606  1
# 171 -10.303030  5.212121  1
# ..         ...       ... ..
# 329   9.818182 -2.787879  1
# 330   3.272727 -1.818182  1
# 331   4.969697 -6.424242  1
# 332  -1.575758 -8.606061  0
# 333  -2.060606  2.787879  1
#
# [167 rows x 3 columns]

# %%
W,B=obj.generateWandB()

# %%
obj2=PropagateEpoch(obj.train, obj.test, obj.W,obj.B,'sigmoid',N, BATCH=10)

# %%
obj2.forward([[0,0]])[0][-1]
#sigmoid(I[0])
# Out:
# 0.506493611518958

# %%
N=[2,8,8,18,8,8,7,10]
obj=Initialize("square",N,0.5)
obj.generateData(False)
obj.generateWandB()
obj.trainAndTest()
test=obj.test


test0=test.iloc[np.where(obj.test[2]==0)]
test1=test.iloc[np.where(obj.test[2]==1)]


obj2=PropagateEpoch(obj.train, obj.test, obj.W,obj.B,'relu',N, BATCH=10)


#pred0=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]
#pred1=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]
pred0=[obj2.forward([[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]
pred1=[obj2.forward([[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]

mp0=np.mean(pred0)+2.5*np.std(pred0)

mp1=np.mean(pred1)#-1.5*np.std(pred1)

#mp0=np.array(.85)
#acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp1)/len(pred1)))/2
acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp0)/len(pred1)))/2
plt.hist(([pred0,pred1])

# %%
import numpy as np
import pandas as pd
N=[2,8,8,18,8,8,7,10]
obj=Initialize("square",N,0.5)
obj.generateData(False)
obj.generateWandB()
obj.trainAndTest()
test=obj.test


test0=test.iloc[np.where(obj.test[2]==0)]
test1=test.iloc[np.where(obj.test[2]==1)]


obj2=PropagateEpoch(obj.train, obj.test, obj.W,obj.B,'relu',N, BATCH=10)


#pred0=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]
#pred1=[forward2(W, B, [[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]
pred0=[obj2.forward([[row[1][0],row[1][1]]])[0][-1] for row in test0.iterrows()]-np.array([0.25])
pred1=[obj2.forward([[row[1][0],row[1][1]]])[0][-1] for row in test1.iterrows()]+np.array([.25])


mp0=np.mean(pred0)+2.5*np.std(pred0)

mp1=np.mean(pred1)#-1.5*np.std(pred1)

#mp0=np.array(.85)
#acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp1)/len(pred1)))/2
acc=((sum(pred0<=mp0)/len(pred0))+(sum(pred1>=mp0)/len(pred1)))/2
#acc
#testAcuracy(test)
# sum(pred0<=mp0)/len(pred0)
# sum(pred1>=mp0)/len(pred1)
a=plt.hist([pred0,pred1])
# plt.axvline(mp0, 0, 1, label='pyplot vertical line',color='b')
# plt.axvline(mp1, 0, 1, label='pyplot vertical line',color='r')
#np.mean(pred0)

# %%
pred0+np.array([5])
# Out:
# array([5.46112023, 5.50030485, 5.49706189, 5.28619583, 5.46736435,
#        5.37019507, 5.51283264, 5.41274738, 5.49816472, 5.51174775,
#        5.42212526, 5.472282  , 5.49350641, 5.52014598, 5.33689387,
#        5.34506573, 5.49639135, 5.24369874, 5.35421976, 5.51813979,
#        5.37207563, 5.4834022 , 5.48933697, 5.36028068, 5.46245598,
#        5.47792308, 5.34456061, 5.49649786, 5.28640499, 5.37812348,
#        5.49902062, 5.43514545, 5.49203745, 5.50008771, 5.49353858,
#        5.48375501, 5.49449031, 5.40828199, 5.50810893, 5.4902174 ,
#        5.45937301, 5.45792468, 5.47677128, 5.3935444 , 5.49215171,
#        5.4171727 , 5.27428263, 5.49760099, 5.50079432, 5.45714354,
#        5.4922295 , 5.47470501, 5.50968029, 5.50521101, 5.4848641 ,
#        5.32242651, 5.42238903, 5.32876206, 5.49348391, 5.34577475,
#        5.45995055, 5.37721284, 5.27456437, 5.50045229, 5.25463522,
#        5.47373845, 5.29103432, 5.38967938, 5.46133229, 5.49116723,
#        5.36387122, 5.36308166, 5.50016102, 5.47539646, 5.41238955,
#        5.46738287, 5.30644035, 5.46858082, 5.48927898, 5.44633308,
#        5.51708144, 5.37386568, 5.36696344, 5.49603727])
